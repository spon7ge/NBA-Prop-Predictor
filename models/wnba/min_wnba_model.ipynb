# %%
import pandas as pd
import numpy as np
import warnings
from pathlib import Path
import sys
import os

project_root = Path.cwd().resolve()
# Notebook lives at models/wnba/ — climb to repo root if needed
if not (project_root / "data").exists():
    project_root = project_root.parent.parent

project_root_str = str(project_root)
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)
os.chdir(project_root_str)

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
from src.pipeline.features.context_features import ContextFeatureEngineer

seasons = [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]
frames = []
for yr in seasons:
    path = f"data/processed/wnba_{yr}_Regular_Season_training_data.parquet"
    season_df = pd.read_parquet(path)
    season_df = ContextFeatureEngineer(league="wnba").enrich(season_df)
    frames.append(season_df)

df = pd.concat(frames, ignore_index=True)
df.sample(10)
# Out:
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2018_players.csv (season=2018)
#   pos filled on 4,359 / 4,418 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (229 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 138 / 4,418 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2019_players.csv (season=2019)
#   pos filled on 4,213 / 4,288 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (64 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,821 / 4,288 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 145 positions from wnba_2020_players.csv (season=2020)
#   pos filled on 2,775 / 2,796 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (57 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 2,363 / 2,796 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 155 positions from wnba_2021_players.csv (season=2021)
#   pos filled on 3,853 / 3,885 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (9 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,433 / 3,885 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 166 positions from wnba_2022_players.csv (season=2022)
#   pos filled on 4,494 / 4,519 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (104 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,030 / 4,519 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 156 positions from wnba_2023_players.csv (season=2023)
#   pos filled on 4,826 / 4,898 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (83 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,436 / 4,898 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2024_players.csv (season=2024)
#   pos filled on 4,914 / 4,914 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (211 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,450 / 4,914 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 182 positions from wnba_2025_players.csv (season=2025)
#   pos filled on 5,829 / 5,853 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (268 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 5,316 / 5,853 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 219 positions from wnba_2026_players.csv (season=2026)
#   pos filled on 3,926 / 4,011 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (105 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,371 / 4,011 rows
#           game_id  player_id     team_id        player_name  game_date  \
# 12665  1022100133     203849  1611661322  Theresa Plaisance 2021-08-19
# 22673  1022300152    1629484  1611661317    Megan Gustafson 2023-08-01
# 38830  1022600081    1643420  1611661332     Laura Juskaite 2026-06-07
# 22805  1022300021    1629497  1611661329      Marina Mabrey 2023-05-30
# 36823  1022600032    1629482  1611661325  Sophie Cunningham 2026-05-20
# 8592   1021900199    1629546  1611661313    Marine Johannes 2019-09-08
# 31644  1022500171    1628280  1611661330      Brionna Jones 2025-07-30
# 18611  1022200131    1629524  1611661324   Bridget Carleton 2022-07-06
# 31980  1022500014    1628922  1611661320      Azura Stevens 2025-05-21
# 28237  1022400183    1630442  1611661317       Natasha Mack 2024-08-28
#
#       season_year      matchup    minutes  pts_per_min  fga_per_min  \
# 12665        2021    WAS @ PHO  13.683333     0.073082     0.219245
# 22673        2023    PHO @ IND  27.083333     0.627692     0.553846
# 38830        2026  TOR vs. CHI  22.456667     0.445302     0.445302
# 22805        2023    CHI @ ATL  25.683333     0.389358     0.389358
# 36823        2026  IND vs. PDX  15.193333     0.131637     0.329092
# 8592         2019    NYL @ ATL  16.250000     0.307692     0.369231
# 31644        2025    ATL @ DAL  26.763333     0.523104     0.373646
# 18611        2022  MIN vs. CHI  13.215000     0.000000     0.302686
# 31980        2025    LAS @ PHX  29.983333     0.767093     0.400222
# 28237        2024  PHO vs. MIN  13.633333     0.293399     0.293399
#
#        fg3a_per_min  fta_per_min  oreb_per_min  dreb_per_min  reb_per_min  \
# 12665      0.000000     0.146163      0.146163      0.146163     0.292326
# 22673      0.110769     0.147692      0.110769      0.036923     0.147692
# 38830      0.133591     0.311711      0.044530      0.133591     0.178121
# 22805      0.077872     0.038936      0.000000      0.116807     0.116807
# 36823      0.263273     0.000000      0.000000      0.131637     0.131637
# 8592       0.246154     0.000000      0.000000      0.123077     0.123077
# 31644      0.037365     0.074729      0.074729      0.149458     0.224187
# 18611      0.075672     0.000000      0.075672      0.000000     0.075672
# 31980      0.133407     0.266815      0.033352      0.533630     0.566982
# 28237      0.000000     0.000000      0.293399      0.220049     0.513447
#
#        ast_per_min  tov_per_min  stl_per_min  blk_per_min  blka_per_min  \
# 12665     0.146163     0.146163     0.000000     0.146163      0.073082
# 22673     0.000000     0.110769     0.000000     0.000000      0.073846
# 38830     0.044530     0.000000     0.000000     0.000000      0.044530
# 22805     0.155743     0.077872     0.000000     0.000000      0.038936
# 36823     0.065818     0.000000     0.000000     0.000000      0.000000
# 8592      0.061538     0.061538     0.061538     0.000000      0.000000
# 31644     0.112094     0.074729     0.074729     0.074729      0.000000
# 18611     0.075672     0.000000     0.075672     0.000000      0.075672
# 31980     0.000000     0.033352     0.000000     0.033352      0.033352
# 28237     0.000000     0.073350     0.146699     0.073350      0.000000
#
#        games_played  base_min_ewm_hl5  base_min_roll5  base_min_ewm_hl10  \
# 12665            20         22.560620       23.400000          21.553447
# 22673            19         15.107562       16.664667          13.732509
# 38830            10         21.350147       22.666333          20.975512
# 22805             3         28.173969       27.645000          27.909153
# 36823             4         24.339802       24.480417          24.407753
# 8592             18         20.422110       22.134667          19.342174
# 31644            26         25.997684       22.541000          27.055554
# 18611            22         17.301937       15.513667          17.906033
# 31980             2               NaN             NaN                NaN
# 28237            31         12.248209       11.689000          13.449126
#
#        base_min_roll10  base_min_ewm_hl20  base_min_roll20  base_min_lag1  \
# 12665        27.807000          20.737098        19.781167      10.516667
# 22673        13.204000          13.055424        12.398684      27.433333
# 38830        20.495667          20.748011        20.495667      19.915000
# 22805        27.645000          27.776914        27.645000      33.950000
# 36823        24.480417          24.443560        24.480417      24.980000
# 8592         20.844000          18.802965        18.289630      28.406667
# 31644        26.300000          27.632521        27.102167      27.676667
# 18611        18.578500          18.279969        18.217750      16.776667
# 31980              NaN                NaN              NaN      34.200000
# 28237        13.211167          14.335979        11.775250       6.633333
#
#        base_min_season_avg  base_fg_pct_ewm_hl5  base_fg_pct_roll5  \
# 12665            19.781167             0.362762             0.3652
# 22673            12.398684             0.452827             0.4218
# 38830            20.495667             0.465488             0.4654
# 22805            27.645000             0.397293             0.3890
# 36823            24.480417             0.503462             0.5030
# 8592             18.289630             0.359945             0.3386
# 31644            28.211923             0.492011             0.4474
# 18611            18.701742             0.384795             0.3668
# 31980            33.300000                  NaN                NaN
# 28237            15.410806             0.642563             0.7000
#
#        base_fg_pct_ewm_hl10  base_fg_pct_roll10  base_fg_pct_ewm_hl20  \
# 12665              0.341684              0.3859              0.329140
# 22673              0.430220              0.4359              0.416203
# 38830              0.454989              0.4416              0.448626
# 22805              0.393271              0.3890              0.391166
# 36823              0.503166              0.5030              0.503067
# 8592               0.358911              0.3012              0.364690
# 31644              0.504417              0.5174              0.508028
# 18611              0.403988              0.4488              0.409798
# 31980                   NaN                 NaN                   NaN
# 28237              0.577696              0.6668              0.549744
#
#        base_fg_pct_roll20  base_fg_pct_lag1  base_fg_pct_season_avg  \
# 12665            0.315750             0.500                0.315750
# 22673            0.400474             0.500                0.400474
# 38830            0.441600             0.333                0.441600
# 22805            0.389000             0.412                0.389000
# 36823            0.503000             0.556                0.503000
# 8592             0.375000             0.455                0.375000
# 31644            0.522950             0.308                0.509308
# 18611            0.432650             0.167                0.412818
# 31980                 NaN             0.583                0.577000
# 28237            0.548400             1.000                0.528677
#
#        base_fg3_pct_ewm_hl5  base_fg3_pct_roll5  base_fg3_pct_ewm_hl10  \
# 12665              0.228886            0.187200               0.232490
# 22673              0.278677            0.200000               0.247236
# 38830              0.440088            0.460000               0.418398
# 22805              0.342621            0.328667               0.335627
# 36823              0.441824            0.483250               0.462182
# 8592               0.295532            0.280800               0.291422
# 31644              0.316983            0.500000               0.264184
# 18611              0.370581            0.390000               0.356147
# 31980                   NaN                 NaN                    NaN
# 28237              0.000000            0.000000               0.000000
#
#        base_fg3_pct_roll10  base_fg3_pct_ewm_hl20  base_fg3_pct_roll20  \
# 12665             0.283000               0.229318             0.222750
# 22673             0.300000               0.229255             0.210526
# 38830             0.396700               0.407443             0.396700
# 22805             0.328667               0.332140             0.328667
# 36823             0.483250               0.472636             0.483250
# 8592              0.240400               0.294038             0.300222
# 31644             0.250000               0.234659             0.241650
# 18611             0.481700               0.340782             0.340800
# 31980                  NaN                    NaN                  NaN
# 28237             0.000000               0.000000             0.000000
#
#        base_fg3_pct_lag1  base_fg3_pct_season_avg  base_ft_pct_ewm_hl5  \
# 12665              0.000                 0.222750             0.239835
# 22673              0.667                 0.210526             0.544588
# 38830              0.333                 0.396700             0.525057
# 22805              0.500                 0.328667             0.657261
# 36823              0.200                 0.483250             0.568874
# 8592               0.333                 0.300222             0.404651
# 31644              0.000                 0.205115             0.448568
# 18611              0.200                 0.321182             0.168854
# 31980              0.571                 0.285500                  NaN
# 28237              0.000                 0.000000             0.133057
#
#        base_ft_pct_roll5  base_ft_pct_ewm_hl10  base_ft_pct_roll10  \
# 12665             0.2000              0.266001              0.2500
# 22673             0.6666              0.516549              0.4333
# 38830             0.5000              0.553876              0.5800
# 22805             0.6190              0.638480              0.6190
# 36823             0.5000              0.534602              0.5000
# 8592              0.3934              0.374808              0.3467
# 31644             0.4000              0.534633              0.4133
# 18611             0.1000              0.202821              0.1500
# 31980                NaN                   NaN                 NaN
# 28237             0.1000              0.136354              0.2000
#
#        base_ft_pct_ewm_hl20  base_ft_pct_roll20  base_ft_pct_lag1  \
# 12665              0.272962            0.275000             0.000
# 22673              0.507607            0.502632             0.750
# 38830              0.567377            0.580000             0.500
# 22805              0.628822            0.619000             0.857
# 36823              0.517322            0.500000             1.000
# 8592               0.364936            0.359278             0.800
# 31644              0.579047            0.560800             0.000
# 18611              0.217298            0.250000             0.000
# 31980                   NaN                 NaN             1.000
# 28237              0.138872            0.125000             0.000
#
#        base_ft_pct_season_avg  base_plus_minus_ewm_hl5  base_plus_minus_roll5  \
# 12665                0.275000                -2.802765              -5.800000
# 22673                0.502632                -1.959684              -0.400000
# 38830                0.580000                 0.799789              -3.000000
# 22805                0.619000                 3.644082               3.333333
# 36823                0.500000                 3.439990               3.250000
# 8592                 0.359278                -3.450070              -5.200000
# 31644                0.620385                 3.042917               5.400000
# 18611                0.227273                 4.416499               7.200000
# 31980                0.875000                      NaN                    NaN
# 28237                0.145161                 0.946794               1.800000
#
#        base_plus_minus_ewm_hl10  base_plus_minus_roll10  \
# 12665                 -1.830453               -1.500000
# 22673                 -2.051517               -0.500000
# 38830                  1.353933                1.900000
# 22805                  3.492006                3.333333
# 36823                  3.353705                3.250000
# 8592                  -3.108740               -5.600000
# 31644                  3.254985                3.900000
# 18611                  2.989787                4.700000
# 31980                       NaN                     NaN
# 28237                  0.059257                2.400000
#
#        base_plus_minus_ewm_hl20  base_plus_minus_roll20  base_plus_minus_lag1  \
# 12665                 -1.380836               -1.000000                  -7.0
# 22673                 -2.130114               -2.210526                 -13.0
# 38830                  1.628814                1.900000                 -21.0
# 22805                  3.413451                3.333333                   5.0
# 36823                  3.304075                3.250000                   4.0
# 8592                  -2.649528               -2.000000                   5.0
# 31644                  3.431917                2.750000                   4.0
# 18611                  2.237897                2.550000                  17.0
# 31980                       NaN                     NaN                 -14.0
# 28237                 -0.454956               -0.400000                  -2.0
#
#        base_plus_minus_season_avg  base_pts_per_min_ewm_hl5  \
# 12665                   -1.000000                  0.321091
# 22673                   -2.210526                  0.519697
# 38830                    1.900000                  0.365229
# 22805                    3.333333                  0.559734
# 36823                    3.250000                  0.423853
# 8592                    -2.000000                  0.398088
# 31644                    3.653846                  0.410809
# 18611                    1.500000                  0.243272
# 31980                   -1.500000                       NaN
# 28237                   -0.903226                  0.250780
#
#        base_pts_per_min_roll5  base_pts_per_min_ewm_hl10  \
# 12665                0.297522                   0.322249
# 22673                0.632840                   0.471399
# 38830                0.338673                   0.360155
# 22805                0.539313                   0.549691
# 36823                0.396309                   0.410120
# 8592                 0.447910                   0.370097
# 31644                0.409523                   0.426459
# 18611                0.226747                   0.250266
# 31980                     NaN                        NaN
# 28237                0.222043                   0.237141
#
#        base_pts_per_min_roll10  base_pts_per_min_ewm_hl20  \
# 12665                 0.359304                   0.319312
# 22673                 0.464784                   0.447740
# 38830                 0.356055                   0.357975
# 22805                 0.539313                   0.544541
# 36823                 0.396309                   0.403219
# 8592                  0.324741                   0.361933
# 31644                 0.421914                   0.433473
# 18611                 0.265103                   0.252615
# 31980                      NaN                        NaN
# 28237                 0.287163                   0.228999
#
#        base_pts_per_min_roll20  base_pts_per_min_lag1  \
# 12665                 0.314027               0.190174
# 22673                 0.425639               0.619684
# 38830                 0.356055               0.401707
# 22805                 0.539313               0.677467
# 36823                 0.396309               0.680544
# 8592                  0.358561               0.563248
# 31644                 0.443847               0.289052
# 18611                 0.262945               0.178820
# 31980                      NaN               0.614035
# 28237                 0.238781               0.301508
#
#        base_pts_per_min_season_avg  base_fga_per_min_ewm_hl5  \
# 12665                     0.314027                  0.347849
# 22673                     0.425639                  0.363532
# 38830                     0.356055                  0.280567
# 22805                     0.539313                  0.493524
# 36823                     0.396309                  0.266990
# 8592                      0.358561                  0.314166
# 31644                     0.439225                  0.347718
# 18611                     0.254193                  0.222302
# 31980                     0.476771                       NaN
# 28237                     0.221105                  0.175154
#
#        base_fga_per_min_roll5  base_fga_per_min_ewm_hl10  \
# 12665                0.347611                   0.356132
# 22673                0.453715                   0.330530
# 38830                0.273594                   0.274941
# 22805                0.489093                   0.491376
# 36823                0.254155                   0.260675
# 8592                 0.325336                   0.302473
# 31644                0.376886                   0.343688
# 18611                0.226284                   0.214512
# 31980                     NaN                        NaN
# 28237                0.129410                   0.182556
#
#        base_fga_per_min_roll10  base_fga_per_min_ewm_hl20  \
# 12665                 0.366389                   0.359636
# 22673                 0.338200                   0.314062
# 38830                 0.271474                   0.272925
# 22805                 0.489093                   0.490251
# 36823                 0.254155                   0.257439
# 8592                  0.297040                   0.297626
# 31644                 0.340440                   0.342873
# 18611                 0.226008                   0.211880
# 31980                      NaN                        NaN
# 28237                 0.189962                   0.184812
#
#        base_fga_per_min_roll20  base_fga_per_min_lag1  \
# 12665                 0.362827               0.190174
# 22673                 0.298401               0.437424
# 38830                 0.271474               0.451921
# 22805                 0.489093               0.500736
# 36823                 0.254155               0.360288
# 8592                  0.293632               0.387233
# 31644                 0.344160               0.469710
# 18611                 0.211154               0.357640
# 31980                      NaN               0.350877
# 28237                 0.193175               0.150754
#
#        base_fga_per_min_season_avg  base_fg3a_per_min_ewm_hl5  \
# 12665                     0.362827                   0.185586
# 22673                     0.298401                   0.090875
# 38830                     0.271474                   0.129490
# 22805                     0.489093                   0.218875
# 36823                     0.254155                   0.150367
# 8592                      0.293632                   0.187518
# 31644                     0.342820                   0.048226
# 18611                     0.210595                   0.166221
# 31980                     0.283463                        NaN
# 28237                     0.185608                   0.004322
#
#        base_fg3a_per_min_roll5  base_fg3a_per_min_ewm_hl10  \
# 12665                 0.192368                    0.191651
# 22673                 0.090513                    0.084578
# 38830                 0.134432                    0.128354
# 22805                 0.221087                    0.220013
# 36823                 0.142860                    0.146681
# 8592                  0.181759                    0.184928
# 31644                 0.063517                    0.047571
# 18611                 0.178193                    0.153034
# 31980                      NaN                         NaN
# 28237                 0.000000                    0.005675
#
#        base_fg3a_per_min_roll10  base_fg3a_per_min_ewm_hl20  \
# 12665                  0.197356                    0.193624
# 22673                  0.093867                    0.081627
# 38830                  0.127642                    0.127944
# 22805                  0.221087                    0.220558
# 36823                  0.142860                    0.144786
# 8592                   0.166177                    0.184260
# 31644                  0.041229                    0.048062
# 18611                  0.171241                    0.146412
# 31980                       NaN                         NaN
# 28237                  0.000000                    0.005965
#
#        base_fg3a_per_min_roll20  base_fg3a_per_min_lag1  \
# 12665                  0.194961                0.000000
# 22673                  0.078933                0.109356
# 38830                  0.127642                0.150640
# 22805                  0.221087                0.176730
# 36823                  0.142860                0.200160
# 8592                   0.183949                0.211218
# 31644                  0.045623                0.072263
# 18611                  0.141046                0.298033
# 31980                       NaN                0.204678
# 28237                  0.007213                0.000000
#
#        base_fg3a_per_min_season_avg  base_fta_per_min_ewm_hl5  \
# 12665                      0.194961                  0.022941
# 22673                      0.078933                  0.153961
# 38830                      0.127642                  0.064793
# 22805                      0.221087                  0.090974
# 36823                      0.142860                  0.099271
# 8592                       0.183949                  0.068372
# 31644                      0.049100                  0.079619
# 18611                      0.140367                  0.024863
# 31980                      0.133203                       NaN
# 28237                      0.005854                  0.028429
#
#        base_fta_per_min_roll5  base_fta_per_min_ewm_hl10  \
# 12665                0.012378                   0.026766
# 22673                0.161281                   0.153896
# 38830                0.045249                   0.069167
# 22805                0.081338                   0.086133
# 36823                0.084811                   0.091987
# 8592                 0.074620                   0.058040
# 31644                0.061832                   0.094288
# 18611                0.024643                   0.028556
# 31980                     NaN                        NaN
# 28237                0.025887                   0.027289
#
#        base_fta_per_min_roll10  base_fta_per_min_ewm_hl20  \
# 12665                 0.021943                   0.028119
# 22673                 0.141709                   0.154575
# 38830                 0.074013                   0.071552
# 22805                 0.081338                   0.083728
# 36823                 0.084811                   0.088381
# 8592                  0.059127                   0.053534
# 31644                 0.082346                   0.102176
# 18611                 0.015150                   0.030525
# 31980                      NaN                        NaN
# 28237                 0.035286                   0.026039
#
#        base_fta_per_min_roll20  base_fta_per_min_lag1  \
# 12665                 0.028942               0.000000
# 22673                 0.155491               0.145808
# 38830                 0.074013               0.100427
# 22805                 0.081338               0.206186
# 36823                 0.084811               0.240192
# 8592                  0.049720               0.176015
# 31644                 0.096094               0.000000
# 18611                 0.035448               0.000000
# 31980                      NaN               0.087719
# 28237                 0.030441               0.000000
#
#        base_fta_per_min_season_avg  base_oreb_per_min_ewm_hl5  \
# 12665                     0.028942                   0.037198
# 22673                     0.155491                   0.073283
# 38830                     0.074013                   0.041658
# 22805                     0.081338                   0.022413
# 36823                     0.084811                   0.016326
# 8592                      0.049720                   0.031042
# 31644                     0.110299                   0.097975
# 18611                     0.032225                   0.022426
# 31980                     0.105588                        NaN
# 28237                     0.024588                   0.089165
#
#        base_oreb_per_min_roll5  base_oreb_per_min_ewm_hl10  \
# 12665                 0.028935                    0.039193
# 22673                 0.074794                    0.076036
# 38830                 0.035199                    0.041739
# 22805                 0.019637                    0.021012
# 36823                 0.018978                    0.017645
# 8592                  0.043962                    0.027413
# 31644                 0.097087                    0.099179
# 18611                 0.023843                    0.019869
# 31980                      NaN                         NaN
# 28237                 0.067737                    0.094514
#
#        base_oreb_per_min_roll10  base_oreb_per_min_ewm_hl20  \
# 12665                  0.032158                    0.041218
# 22673                  0.067931                    0.078160
# 38830                  0.042132                    0.041904
# 22805                  0.019637                    0.020321
# 36823                  0.018978                    0.018310
# 8592                   0.034481                    0.025394
# 31644                  0.085290                    0.100986
# 18611                  0.016235                    0.019269
# 31980                       NaN                         NaN
# 28237                  0.085732                    0.096411
#
#        base_oreb_per_min_roll20  base_oreb_per_min_lag1  \
# 12665                  0.043828                0.095087
# 22673                  0.080547                0.109356
# 38830                  0.042132                0.100427
# 22805                  0.019637                0.058910
# 36823                  0.018978                0.000000
# 8592                   0.023328                0.035203
# 31644                  0.101735                0.144526
# 18611                  0.018652                0.119213
# 31980                       NaN                0.000000
# 28237                  0.097911                0.000000
#
#        base_oreb_per_min_season_avg  base_dreb_per_min_ewm_hl5  \
# 12665                      0.043828                   0.229801
# 22673                      0.080547                   0.221889
# 38830                      0.042132                   0.138000
# 22805                      0.019637                   0.147411
# 36823                      0.018978                   0.123989
# 8592                       0.023328                   0.058729
# 31644                      0.103566                   0.143919
# 18611                      0.019121                   0.112568
# 31980                      0.000000                        NaN
# 28237                      0.097930                   0.278003
#
#        base_dreb_per_min_roll5  base_dreb_per_min_ewm_hl10  \
# 12665                 0.265738                    0.209476
# 22673                 0.246651                    0.205906
# 38830                 0.115824                    0.140190
# 22805                 0.151631                    0.149546
# 36823                 0.126863                    0.125433
# 8592                  0.046204                    0.060754
# 31644                 0.163560                    0.149347
# 18611                 0.113608                    0.108313
# 31980                      NaN                         NaN
# 28237                 0.342831                    0.246955
#
#        base_dreb_per_min_roll10  base_dreb_per_min_ewm_hl20  \
# 12665                  0.231304                    0.199573
# 22673                  0.230323                    0.194945
# 38830                  0.144104                    0.141926
# 22805                  0.151631                    0.150595
# 36823                  0.126863                    0.126151
# 8592                   0.053849                    0.062513
# 31644                  0.155817                    0.152740
# 18611                  0.109581                    0.106290
# 31980                       NaN                         NaN
# 28237                  0.281752                    0.232543
#
#        base_dreb_per_min_roll20  base_dreb_per_min_lag1  \
# 12665                  0.190665                0.380349
# 22673                  0.182302                0.182260
# 38830                  0.144104                0.150640
# 22805                  0.151631                0.088365
# 36823                  0.126863                0.120096
# 8592                   0.064664                0.070406
# 31644                  0.140921                0.072263
# 18611                  0.106591                0.238426
# 31980                       NaN                0.175439
# 28237                  0.215788                0.301508
#
#        base_dreb_per_min_season_avg  base_reb_per_min_ewm_hl5  \
# 12665                      0.190665                  0.266999
# 22673                      0.182302                  0.295172
# 38830                      0.144104                  0.179658
# 22805                      0.151631                  0.169824
# 36823                      0.126863                  0.140316
# 8592                       0.064664                  0.089771
# 31644                      0.156855                  0.241894
# 18611                      0.104294                  0.134993
# 31980                      0.164880                       NaN
# 28237                      0.221451                  0.367168
#
#        base_reb_per_min_roll5  base_reb_per_min_ewm_hl10  \
# 12665                0.294673                   0.248669
# 22673                0.321446                   0.281941
# 38830                0.151023                   0.181929
# 22805                0.171267                   0.170558
# 36823                0.145841                   0.143077
# 8592                 0.090165                   0.088167
# 31644                0.260646                   0.248526
# 18611                0.137451                   0.128182
# 31980                     NaN                        NaN
# 28237                0.410567                   0.341469
#
#        base_reb_per_min_roll10  base_reb_per_min_ewm_hl20  \
# 12665                 0.263462                   0.240791
# 22673                 0.298255                   0.273105
# 38830                 0.186236                   0.183830
# 22805                 0.171267                   0.170916
# 36823                 0.145841                   0.144461
# 8592                  0.088329                   0.087907
# 31644                 0.241107                   0.253727
# 18611                 0.125816                   0.125559
# 31980                      NaN                        NaN
# 28237                 0.367484                   0.328954
#
#        base_reb_per_min_roll20  base_reb_per_min_lag1  \
# 12665                 0.234494               0.475436
# 22673                 0.262849               0.291616
# 38830                 0.186236               0.251067
# 22805                 0.171267               0.147275
# 36823                 0.145841               0.120096
# 8592                  0.087992               0.105609
# 31644                 0.242656               0.216789
# 18611                 0.125243               0.357640
# 31980                      NaN               0.175439
# 28237                 0.313699               0.301508
#
#        base_reb_per_min_season_avg  base_ast_per_min_ewm_hl5  \
# 12665                     0.234494                  0.086353
# 22673                     0.262849                  0.029846
# 38830                     0.186236                  0.062532
# 22805                     0.171267                  0.165341
# 36823                     0.145841                  0.058287
# 8592                      0.087992                  0.154139
# 31644                     0.260421                  0.105051
# 18611                     0.123414                  0.055689
# 31980                     0.164880                       NaN
# 28237                     0.319381                  0.064385
#
#        base_ast_per_min_roll5  base_ast_per_min_ewm_hl10  \
# 12665                0.099226                   0.083907
# 22673                0.037644                   0.031837
# 38830                0.071457                   0.059630
# 22805                0.158549                   0.161947
# 36823                0.063349                   0.060822
# 8592                 0.182344                   0.140998
# 31644                0.130404                   0.099340
# 18611                0.051469                   0.059033
# 31980                     NaN                        NaN
# 28237                0.053052                   0.067097
#
#        base_ast_per_min_roll10  base_ast_per_min_ewm_hl20  \
# 12665                 0.092285                   0.081626
# 22673                 0.018822                   0.034760
# 38830                 0.056524                   0.058100
# 22805                 0.158549                   0.160248
# 36823                 0.063349                   0.062087
# 8592                  0.155144                   0.134328
# 31644                 0.120388                   0.095161
# 18611                 0.054971                   0.060406
# 31980                      NaN                        NaN
# 28237                 0.099356                   0.069270
#
#        base_ast_per_min_roll20  base_ast_per_min_lag1  \
# 12665                 0.078694               0.000000
# 22673                 0.039185               0.036452
# 38830                 0.056524               0.100427
# 22805                 0.158549               0.235641
# 36823                 0.063349               0.000000
# 8592                  0.128000               0.246421
# 31644                 0.092083               0.000000
# 18611                 0.060932               0.059607
# 31980                      NaN               0.029240
# 28237                 0.061000               0.000000
#
#        base_ast_per_min_season_avg  base_tov_per_min_ewm_hl5  \
# 12665                     0.078694                  0.049285
# ...
# 36823                 72.4            -0.103758                     0.020635
# 8592                  52.6             1.619145                     0.036155
# 31644                 67.0            -1.634837                    -0.022664
# 18611                 31.9            -0.978032                    -0.009343
# 31980                 66.6                  NaN                          NaN
# 28237                 26.2            -2.087770                     0.021781
#
#        adv_ts_pct_trend_5v20  adv_usg_pct_trend_5v20  \
# 12665               0.029354               -0.002141
# 22673               0.019103                0.025080
# 38830               0.020659                0.001788
# 22805               0.009804                0.001493
# 36823              -0.001210                0.007338
# 8592               -0.007990                0.014227
# 31644              -0.020944                0.002220
# 18611              -0.023862                0.005808
# 31980                    NaN                     NaN
# 28237               0.089073                0.007019
#
#        base_ast_per_min_trend_5v20  base_oreb_per_min_trend_5v20  \
# 12665                     0.004727                     -0.004020
# 22673                    -0.004914                     -0.004877
# 38830                     0.004432                     -0.000246
# 22805                     0.005093                      0.002092
# 36823                    -0.003800                     -0.001984
# 8592                      0.019811                      0.005648
# 31644                     0.009891                     -0.003012
# 18611                    -0.004717                      0.003157
# 31980                          NaN                           NaN
# 28237                    -0.004886                     -0.007246
#
#        base_dreb_per_min_trend_5v20  team_pts_per_min_rank_l10  \
# 12665                      0.030228                        4.0
# 22673                      0.026944                        2.0
# 38830                     -0.003926                        4.0
# 22805                     -0.003184                        1.0
# 36823                     -0.002162                        3.0
# 8592                      -0.003784                        5.0
# 31644                     -0.008821                        3.0
# 18611                      0.006277                        9.0
# 31980                           NaN                        NaN
# 28237                      0.045460                        7.0
#
#        team_ast_per_min_rank_l10  team_oreb_per_min_rank_l10  \
# 12665                        5.0                         5.0
# 22673                        8.0                         2.0
# 38830                        5.0                         4.0
# 22805                        1.0                         6.0
# 36823                        6.0                         7.0
# 8592                         3.0                         9.0
# 31644                        3.0                         1.0
# 18611                        8.0                         6.0
# 31980                        NaN                         NaN
# 28237                        5.0                         1.0
#
#        team_dreb_per_min_rank_l10  team_ts_pct_rank_l10  \
# 12665                         2.0                   8.0
# 22673                         1.0                   4.0
# 38830                         1.0                   2.0
# 22805                         4.0                   2.0
# 36823                         5.0                   2.0
# 8592                         11.0                   7.0
# 31644                         4.0                   3.0
# 18611                         6.0                   5.0
# 31980                         NaN                   NaN
# 28237                         1.0                   2.0
#
#        team_usg_pct_rank_l10  team_min_rank_l10  pts_per_min_roll10  \
# 12665                    4.0                7.0            0.359304
# 22673                    3.0                8.0            0.464784
# 38830                    5.0                6.0            0.356055
# 22805                    2.0                4.0                 NaN
# 36823                    6.0                3.0                 NaN
# 8592                     5.0                6.0            0.324741
# 31644                    3.0                2.0            0.421914
# 18611                    9.0                7.0            0.265103
# 31980                    NaN                NaN                 NaN
# 28237                    7.0                7.0            0.287163
#
#        team_pts_per_min_rank_roll10  minutes_roll5_std  minutes_roll5_var  \
# 12665                           4.0             9.6102            92.3556
# 22673                           2.0             9.2155            84.9247
# 38830                           4.0             3.0130             9.0783
# 22805                           NaN             5.7955            33.5881
# 36823                           NaN             3.0196             9.1177
# 8592                            6.0             9.7955            95.9516
# 31644                           3.0             4.9321            24.3253
# 18611                           9.0             2.0700             4.2849
# 31980                           NaN             1.2728             1.6200
# 28237                           6.0             4.8747            23.7626
#
#        minutes_roll10_std  minutes_roll10_var  minutes_roll15_std  \
# 12665              8.2215             67.5931             11.6765
# 22673              7.7202             59.6022              6.8298
# 38830              5.6750             32.2051              5.6750
# 22805                 NaN                 NaN                 NaN
# 36823                 NaN                 NaN                 NaN
# 8592               7.1444             51.0418              6.9635
# 31644              5.5967             31.3235              5.4331
# 18611              6.7241             45.2141              6.2055
# 31980                 NaN                 NaN                 NaN
# 28237              7.0588             49.8264              7.1456
#
#        minutes_roll15_var  pts_per_min_roll5_std  pts_per_min_roll5_var  \
# 12665            136.3412                 0.0637                 0.0041
# 22673             46.6466                 0.3940                 0.1553
# 38830             32.2051                 0.1524                 0.0232
# 22805                 NaN                 0.2758                 0.0761
# 36823                 NaN                 0.2330                 0.0543
# 8592              48.4901                 0.4271                 0.1824
# 31644             29.5185                 0.1732                 0.0300
# 18611             38.5079                 0.1654                 0.0274
# 31980                 NaN                 0.1941                 0.0377
# 28237             51.0594                 0.1332                 0.0177
#
#        pts_per_min_roll10_std  pts_per_min_roll10_var  pts_per_min_roll15_std  \
# 12665                  0.1495                  0.0223                  0.2226
# 22673                  0.3825                  0.1463                  0.3151
# 38830                  0.1879                  0.0353                  0.1879
# 22805                     NaN                     NaN                     NaN
# 36823                     NaN                     NaN                     NaN
# 8592                   0.3281                  0.1077                  0.3545
# 31644                  0.1663                  0.0277                  0.1461
# 18611                  0.1454                  0.0211                  0.1369
# 31980                     NaN                     NaN                     NaN
# 28237                  0.1236                  0.0153                  0.1428
#
#        pts_per_min_roll15_var  ast_per_min_roll5_std  ast_per_min_roll5_var  \
# 12665                  0.0496                 0.0762                 0.0058
# 22673                  0.0993                 0.0434                 0.0019
# 38830                  0.0353                 0.0260                 0.0007
# 22805                     NaN                 0.0737                 0.0054
# 36823                     NaN                 0.0546                 0.0030
# 8592                   0.1256                 0.0587                 0.0034
# 31644                  0.0214                 0.0765                 0.0058
# 18611                  0.0187                 0.0510                 0.0026
# 31980                     NaN                 0.0207                 0.0004
# 28237                  0.0204                 0.0549                 0.0030
#
#        ast_per_min_roll10_std  ast_per_min_roll10_var  ast_per_min_roll15_std  \
# 12665                  0.0553                  0.0031                  0.0741
# 22673                  0.0351                  0.0012                  0.0309
# 38830                  0.0518                  0.0027                  0.0518
# 22805                     NaN                     NaN                     NaN
# 36823                     NaN                     NaN                     NaN
# 8592                   0.0595                  0.0035                  0.0776
# 31644                  0.0606                  0.0037                  0.0758
# 18611                  0.0444                  0.0020                  0.0622
# 31980                     NaN                     NaN                     NaN
# 28237                  0.0866                  0.0075                  0.0847
#
#        ast_per_min_roll15_var  oreb_per_min_roll5_std  oreb_per_min_roll5_var  \
# 12665                  0.0055                  0.0428                  0.0018
# 22673                  0.0010                  0.0745                  0.0055
# 38830                  0.0027                  0.0490                  0.0024
# 22805                     NaN                  0.0340                  0.0012
# 36823                     NaN                  0.0219                  0.0005
# 8592                   0.0060                  0.0599                  0.0036
# 31644                  0.0058                  0.0483                  0.0023
# 18611                  0.0039                  0.0533                  0.0028
# 31980                     NaN                  0.0000                  0.0000
# 28237                  0.0072                  0.0697                  0.0049
#
#        oreb_per_min_roll10_std  oreb_per_min_roll10_var  \
# 12665                   0.0388                   0.0015
# 22673                   0.0853                   0.0073
# 38830                   0.0410                   0.0017
# 22805                      NaN                      NaN
# 36823                      NaN                      NaN
# 8592                    0.0555                   0.0031
# 31644                   0.0440                   0.0019
# 18611                   0.0386                   0.0015
# 31980                      NaN                      NaN
# 28237                   0.0702                   0.0049
#
#        oreb_per_min_roll15_std  oreb_per_min_roll15_var  \
# 12665                   0.0364                   0.0013
# 22673                   0.0818                   0.0067
# 38830                   0.0410                   0.0017
# 22805                      NaN                      NaN
# 36823                      NaN                      NaN
# 8592                    0.0489                   0.0024
# 31644                   0.0485                   0.0023
# 18611                   0.0343                   0.0012
# 31980                      NaN                      NaN
# 28237                   0.1255                   0.0157
#
#        dreb_per_min_roll5_std  dreb_per_min_roll5_var  \
# 12665                  0.0744                  0.0055
# 22673                  0.0759                  0.0058
# 38830                  0.0613                  0.0038
# 22805                  0.0551                  0.0030
# 36823                  0.0703                  0.0049
# 8592                   0.0525                  0.0028
# 31644                  0.1414                  0.0200
# 18611                  0.0742                  0.0055
# 31980                  0.0149                  0.0002
# 28237                  0.1083                  0.0117
#
#        dreb_per_min_roll10_std  dreb_per_min_roll10_var  \
# 12665                   0.0774                   0.0060
# 22673                   0.1148                   0.0132
# 38830                   0.0807                   0.0065
# 22805                      NaN                      NaN
# 36823                      NaN                      NaN
# 8592                    0.0522                   0.0027
# 31644                   0.1033                   0.0107
# 18611                   0.0659                   0.0043
# 31980                      NaN                      NaN
# 28237                   0.1544                   0.0238
#
#        dreb_per_min_roll15_std  dreb_per_min_roll15_var  \
# 12665                   0.1095                   0.0120
# 22673                   0.1003                   0.0101
# 38830                   0.0807                   0.0065
# 22805                      NaN                      NaN
# 36823                      NaN                      NaN
# 8592                    0.0499                   0.0025
# 31644                   0.0914                   0.0084
# 18611                   0.0720                   0.0052
# 31980                      NaN                      NaN
# 28237                   0.1530                   0.0234
#
#        reb_per_min_roll5_std  reb_per_min_roll5_var  reb_per_min_roll10_std  \
# 12665                 0.1166                 0.0136                  0.1062
# 22673                 0.1327                 0.0176                  0.1538
# 38830                 0.0704                 0.0050                  0.0948
# 22805                 0.0216                 0.0005                     NaN
# 36823                 0.0864                 0.0075                     NaN
# 8592                  0.0719                 0.0052                  0.0718
# 31644                 0.1042                 0.0109                  0.0866
# 18611                 0.1256                 0.0158                  0.0993
# 31980                 0.0149                 0.0002                     NaN
# 28237                 0.1330                 0.0177                  0.1555
#
#        reb_per_min_roll10_var  reb_per_min_roll15_std  reb_per_min_roll15_var  \
# 12665                  0.0113                  0.1357                  0.0184
# 22673                  0.0236                  0.1466                  0.0215
# 38830                  0.0090                  0.0948                  0.0090
# 22805                     NaN                     NaN                     NaN
# 36823                     NaN                     NaN                     NaN
# 8592                   0.0052                  0.0666                  0.0044
# 31644                  0.0075                  0.0876                  0.0077
# 18611                  0.0099                  0.0966                  0.0093
# 31980                     NaN                     NaN                     NaN
# 28237                  0.0242                  0.2165                  0.0469
#
#        starter_roll10_pct
# 12665                0.80
# 22673                0.10
# 38830                0.70
# 22805                1.00
# 36823                0.75
# 8592                 0.00
# 31644                1.00
# 18611                0.10
# 31980                 NaN
# 28237                0.00

# %%
print(f"Total number of duplicates: {df.duplicated(subset=['game_id', 'player_id']).sum()}")
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
df[['minutes', 'pts_per_min', 'ast_per_min', 'reb_per_min']].describe()
# Out:
# Total number of duplicates: 0
# Rows: 39582
# Columns: 722
#             minutes   pts_per_min   ast_per_min   reb_per_min
# count  39582.000000  39580.000000  39580.000000  39580.000000
# mean      21.023363      0.365265      0.089548      0.168043
# std       10.416752      0.270993      0.093807      0.142947
# min        0.000000      0.000000      0.000000      0.000000
# 25%       12.800000      0.176991      0.000000      0.067467
# 50%       21.833333      0.350599      0.071986      0.144052
# 75%       29.833333      0.526010      0.135048      0.240630
# max       52.550000     12.500000      2.469136      2.702703

# %%
# ── Prop-specific config (WNBA MIN) ───────────────────────────────────────────
MIN_FEATURES = [
    "starting",
    "starter_roll10_pct",
    "team_min_rank_l10",
    "team_usg_pct_rank_l10",
    "base_min_season_avg", # new
    "track_minutes_ewm_hl10",
    "base_min_trend_5v20",
    "base_min_lag1",
]

HOLDOUT_SEASON = "2026"
ID_COLS = ["game_id", "player_id", "season_year", "player_name", "game_date"]
TARGET_COL = "minutes"
ROLE_COL = "starting"

# Frozen naive baselines for the MIN hypothesis test (leakage-safe).
NAIVE_PRIMARY = "base_min_season_avg"
NAIVE_SECONDARY = "base_min_lag1"
NAIVE_COLS = [NAIVE_PRIMARY, NAIVE_SECONDARY]
ALPHA = 0.05

QUANTILES = [0.10, 0.50, 0.90]

XGB_PARAMS = dict(
    objective="reg:quantileerror",
    n_estimators=1695,
    max_depth=3,
    learning_rate=0.052852647946832816,
    subsample=0.5916232263322159,
    colsample_bytree=0.6284413523882679,
    reg_alpha=0.022871045941195746,
    reg_lambda=2.0960269065270034,
    min_child_weight=8,
    n_jobs=-1,
    random_state=42,
    early_stopping_rounds=50,
)

MIN_TIERS = {
    "<12.8 min": lambda a: a < 12.8,
    "12.8-21.8 min": lambda a: (a >= 12.8) & (a < 21.8),
    "21.8-30 min": lambda a: (a >= 21.8) & (a < 31.5),
    "30+ min": lambda a: a >= 31.5,
}

ARTIFACT_STEM = "min_wnba_model"

# ── Shared train/eval helpers ─────────────────────────────────────────────────
from models.shared.splits import prepare_splits
from models.shared.train import run_timeseries_cv, run_walk_forward, evaluate_holdout
from models.shared.baselines import (
    run_naive_comparison,
    evaluate_holdout_vs_naive,
    run_quantile_linear_baseline,
)
from models.shared.analysis import run_feature_ablation, analyze_correlations
from models.shared.artifacts import save_model_bundle, load_model_bundle, predict_quantiles
from models.shared.metrics import pinball_50

print(f"Number of features: {len(MIN_FEATURES)}")
MIN_FEATURES
# Out:
# Number of features: 8
# ['starting',
#  'starter_roll10_pct',
#  'team_min_rank_l10',
#  'team_usg_pct_rank_l10',
#  'base_min_season_avg',
#  'track_minutes_ewm_hl10',
#  'base_min_trend_5v20',
#  'base_min_lag1']

# %%
df = df[(df['minutes'] > 12)]
print(f"After filtering minutes: {df[MIN_FEATURES].shape[0]} rows")
# Out:
# After filtering minutes: 30427 rows

# %%
splits = prepare_splits(
    df,
    holdout_season=HOLDOUT_SEASON,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    id_cols=ID_COLS,
    role_col=ROLE_COL,
    extra_keep=["minutes"],
)
ppm_df = splits["ppm_df"]
ppm_holdout = splits["ppm_holdout"]
X = splits["X"]
y = splits["y"]
# Out:
# Train pool (excl. 2026) : 27,375 rows
# Holdout   (2026)        : 3,052 rows
# Date range (train)   : 2018-05-18 → 2025-10-10
# Date range (holdout) : 2026-05-08 → 2026-07-22

# %%
# import importlib
# import models.shared.train as train

# importlib.reload(train)
# tune_xgb_quantile = train.tune_xgb_quantile

# result = tune_xgb_quantile(X, y, n_trials=100, n_splits=5)
# XGB_PARAMS = result["best_params"]

# %%
tscv_results = run_timeseries_cv(
    X, y, ppm_df,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    quantiles=QUANTILES,
)
wf = run_walk_forward(
    X, y, ppm_df,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    quantiles=QUANTILES,
)

wf_results = wf["wf_results"]
models_last = wf["models_last"]
preds_last = wf["preds_last"]
X_val_last = wf["X_val_last"]
y_val_last = wf["y_val_last"]
starting_last = wf["starting_last"]
last_fold = wf["last_fold"]
# Out:
# ── Phase 1: TimeSeriesSplit ─────────────────────────────────────────
#
# TSCV fold 1
#   Overall  | n= 4562 | MAE: 4.018 | R²: 0.509 | 80% Coverage: 78.4%
#   Starters   | n= 2994 | MAE: 4.311 | Coverage: 77.4%
#   Bench      | n= 1568 | MAE: 3.458 | Coverage: 80.4%
#   <12.8 min  | n=  111 | MAE: 5.268 | Coverage: 11.7%
#   12.8-21.8 min | n= 1552 | MAE: 4.140 | Coverage: 80.0%
#   21.8-30 min | n= 1846 | MAE: 3.525 | Coverage: 89.3%
#   30+ min    | n= 1053 | MAE: 4.570 | Coverage: 64.0%
#
# TSCV fold 2
#   Overall  | n= 4562 | MAE: 4.097 | R²: 0.506 | 80% Coverage: 78.6%
#   Starters   | n= 3023 | MAE: 4.409 | Coverage: 78.4%
#   Bench      | n= 1539 | MAE: 3.483 | Coverage: 78.9%
#   <12.8 min  | n=  100 | MAE: 5.740 | Coverage: 2.0%
#   12.8-21.8 min | n= 1473 | MAE: 4.188 | Coverage: 79.4%
#   21.8-30 min | n= 1816 | MAE: 3.789 | Coverage: 88.7%
#   30+ min    | n= 1173 | MAE: 4.318 | Coverage: 68.4%
#
# TSCV fold 3
#   Overall  | n= 4562 | MAE: 3.844 | R²: 0.568 | 80% Coverage: 80.7%
#   Starters   | n= 3099 | MAE: 4.039 | Coverage: 81.2%
#   Bench      | n= 1463 | MAE: 3.430 | Coverage: 79.6%
#   <12.8 min  | n=   92 | MAE: 5.147 | Coverage: 12.0%
#   12.8-21.8 min | n= 1390 | MAE: 4.023 | Coverage: 80.0%
#   21.8-30 min | n= 1855 | MAE: 3.553 | Coverage: 88.7%
#   30+ min    | n= 1225 | MAE: 3.983 | Coverage: 74.4%
#
# TSCV fold 4
#   Overall  | n= 4562 | MAE: 3.885 | R²: 0.602 | 80% Coverage: 78.5%
#   Starters   | n= 3170 | MAE: 4.037 | Coverage: 78.7%
#   Bench      | n= 1392 | MAE: 3.541 | Coverage: 78.0%
#   <12.8 min  | n=  106 | MAE: 5.000 | Coverage: 4.7%
#   12.8-21.8 min | n= 1353 | MAE: 4.107 | Coverage: 79.5%
#   21.8-30 min | n= 1640 | MAE: 3.685 | Coverage: 86.6%
#   30+ min    | n= 1463 | MAE: 3.824 | Coverage: 73.7%
#
# TSCV fold 5
#   Overall  | n= 4562 | MAE: 3.932 | R²: 0.524 | 80% Coverage: 80.3%
#   Starters   | n= 3010 | MAE: 4.121 | Coverage: 81.6%
#   Bench      | n= 1552 | MAE: 3.567 | Coverage: 77.7%
#   <12.8 min  | n=  114 | MAE: 5.572 | Coverage: 6.1%
#   12.8-21.8 min | n= 1446 | MAE: 4.150 | Coverage: 79.5%
#   21.8-30 min | n= 1917 | MAE: 3.658 | Coverage: 87.5%
#   30+ min    | n= 1085 | MAE: 3.955 | Coverage: 76.3%
#
# TimeSeriesSplit Summary
#   MAE      : 3.955 ± 0.091
#   R²       : 0.542  ± 0.038
#   Coverage : 79.3% ± 1.0%  (target ~80%)
#
# ── Phase 2: Walk-Forward Validation (date-based) ───────────────────
# Unique game dates in pool : 730
# Training window           : 365 dates (~50%)
# Step size                 : 73 dates (~10%)
#
# WF fold 1  (2022-06-30 → 2023-06-17)
#   Overall  | n= 2617 | MAE: 3.830 | R²: 0.555 | 80% Coverage: 81.0%
#   Starters   | n= 1768 | MAE: 4.043 | Coverage: 81.8%
#   Bench      | n=  849 | MAE: 3.388 | Coverage: 79.3%
#   <12.8 min  | n=   44 | MAE: 5.179 | Coverage: 4.5%
#   12.8-21.8 min | n=  809 | MAE: 3.932 | Coverage: 79.6%
#   21.8-30 min | n= 1081 | MAE: 3.551 | Coverage: 88.8%
#   30+ min    | n=  683 | MAE: 4.065 | Coverage: 75.1%
#
# WF fold 2  (2023-06-17 → 2023-10-01)
#   Overall  | n= 2814 | MAE: 3.924 | R²: 0.581 | 80% Coverage: 77.5%
#   Starters   | n= 1934 | MAE: 4.098 | Coverage: 77.4%
#   Bench      | n=  880 | MAE: 3.541 | Coverage: 77.7%
#   <12.8 min  | n=   67 | MAE: 5.433 | Coverage: 7.5%
#   12.8-21.8 min | n=  845 | MAE: 4.175 | Coverage: 77.2%
#   21.8-30 min | n= 1073 | MAE: 3.646 | Coverage: 88.3%
#   30+ min    | n=  829 | MAE: 3.905 | Coverage: 69.6%
#
# WF fold 3  (2023-10-01 → 2024-08-26)
#   Overall  | n= 2589 | MAE: 3.767 | R²: 0.612 | 80% Coverage: 80.5%
#   Starters   | n= 1789 | MAE: 3.859 | Coverage: 82.0%
#   Bench      | n=  800 | MAE: 3.559 | Coverage: 77.2%
#   <12.8 min  | n=   64 | MAE: 5.076 | Coverage: 3.1%
#   12.8-21.8 min | n=  768 | MAE: 4.056 | Coverage: 79.6%
#   21.8-30 min | n=  954 | MAE: 3.638 | Coverage: 86.7%
#   30+ min    | n=  803 | MAE: 3.539 | Coverage: 80.3%
#
# WF fold 4  (2024-08-26 → 2025-07-06)
#   Overall  | n= 2942 | MAE: 4.039 | R²: 0.558 | 80% Coverage: 77.1%
#   Starters   | n= 1990 | MAE: 4.302 | Coverage: 76.7%
#   Bench      | n=  952 | MAE: 3.490 | Coverage: 78.0%
#   <12.8 min  | n=   73 | MAE: 5.126 | Coverage: 1.4%
#   12.8-21.8 min | n=  945 | MAE: 4.325 | Coverage: 78.3%
#   21.8-30 min | n= 1118 | MAE: 3.708 | Coverage: 85.9%
#   30+ min    | n=  806 | MAE: 4.065 | Coverage: 70.5%
#
# ────────────────────────────────────────────────────────────
# Walk-Forward Summary (4/4 folds)
#   MAE      : 3.890 ± 0.103
#   R²       : 0.577  ± 0.023
#   Coverage : 79.0% ± 1.7%  (target ~80%)
#
# ────────────────────────────────────────────────────────────
# Per-fold coverage breakdown (target 80%):
#   Fold                                            Coverage    Starters       Bench
#   WF fold 1  (2022-06-30 → 2023-06-17)              81.0%      81.8%      79.3%
#   WF fold 2  (2023-06-17 → 2023-10-01)              77.5%      77.4%      77.7%
#   WF fold 3  (2023-10-01 → 2024-08-26)              80.5%      82.0%      77.2%
#   WF fold 4  (2024-08-26 → 2025-07-06)              77.1%      76.7%      78.0%
#
# Per-fold MAE by tier:
#   Fold                                           <12.8 min  12.8-21.8 min  21.8-30 min     30+ min
#   WF fold 1  (2022-06-30 → 2023-06-17)               5.179       3.932       3.551       4.065
#   WF fold 2  (2023-06-17 → 2023-10-01)               5.433       4.175       3.646       3.905
#   WF fold 3  (2023-10-01 → 2024-08-26)               5.076       4.056       3.638       3.539
#   WF fold 4  (2024-08-26 → 2025-07-06)               5.126       4.325       3.708       4.065
#
# MAE over folds (stable = good, rising = model aging):
#   WF fold 1  (2022-06-30 → 2023-06-17)          3.830  ██████████████████
#   WF fold 2  (2023-06-17 → 2023-10-01)          3.924  ███████████████████
#   WF fold 3  (2023-10-01 → 2024-08-26)          3.767  ██████████████████
#   WF fold 4  (2024-08-26 → 2025-07-06)          4.039  ████████████████████

# %% [markdown]
# ### Naive baseline — MIN hypothesis test
#
# **H0:** The minutes model does not predict significantly better than a naive baseline.
# **H1:** The minutes model predicts significantly better than naive.
#
# **Frozen primary naive:** `base_min_season_avg` (season-to-date expanding mean, shift-then-expand — no same-game leakage).
# **Secondary (reported only):** `base_min_lag1` (last-game minutes).
#
# **Decision rule:** on the same player-games, reject H0 if model MAE < naive MAE **and** one-sided Wilcoxon signed-rank on `|y − ŷ|` has p < 0.05 (model errors stochastically smaller).

# %%
naive = run_naive_comparison(
    wf_results,
    ppm_df,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    y_val_last=y_val_last,
    preds_last=preds_last,
    last_fold=last_fold,
    alpha=ALPHA,
)
# Out:
# ── Naive baselines on walk-forward validation folds ─────────────────
#   Primary H0 predictor : base_min_season_avg
#   Secondary (report)   : base_min_lag1
#   Alpha                : 0.05
#
# Primary naive (base_min_season_avg) vs model MAE by fold:
#   Fold                                             Model    Naive     ΔMAE       n
#   WF fold 1  (2022-06-30 → 2023-06-17)             3.830    4.850   -1.019    2514
#   WF fold 2  (2023-06-17 → 2023-10-01)             3.924    4.940   -1.016    2812
#   WF fold 3  (2023-10-01 → 2024-08-26)             3.767    4.803   -1.036    2487
#   WF fold 4  (2024-08-26 → 2025-07-06)             4.039    5.116   -1.077    2826
#
# Secondary naive (base_min_lag1) vs model MAE by fold:
#   Fold                                             Model    Naive     ΔMAE       n
#   WF fold 1  (2022-06-30 → 2023-06-17)             3.830    5.404   -1.573    2514
#   WF fold 2  (2023-06-17 → 2023-10-01)             3.924    5.679   -1.755    2812
#   WF fold 3  (2023-10-01 → 2024-08-26)             3.767    5.272   -1.506    2487
#   WF fold 4  (2024-08-26 → 2025-07-06)             4.039    5.779   -1.740    2826
#
# ────────────────────────────────────────────────────────────
# Walk-forward last-fold hypothesis test (primary naive):
#   n paired        : 2,826
#   MAE model       : 4.032
#   MAE naive       : 5.116
#   ΔMAE (m−n)      : -1.085
#   Wilcoxon p      : 2.963e-49
#   Reject H0?      : YES — model beats naive

# %% [markdown]
# ### Residual Visuals

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error

y_true = y_val_last.values
pred_low = preds_last["q_0.10"]
pred_mid = preds_last["q_0.50"]
pred_high = preds_last["q_0.90"]
preds_plot = {"Q10": pred_low, "Q50": pred_mid, "Q90": pred_high}

fig, axes = plt.subplots(1, 3, figsize=(14, 6), sharex=True, sharey=True)
scatter_metrics = {}

for ax, (name, y_pred) in zip(axes, preds_plot.items()):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    scatter_metrics[name] = {"R2": r2, "MAE": mae}
    ax.scatter(y_true, y_pred, s=12, alpha=0.6, edgecolors="none")
    lims = [0, max(y_true.max(), y_pred.max()) * 1.02]
    ax.plot(lims, lims, "k--", lw=1)
    ax.set_title(f"{name}  |  R²={r2:.3f}  MAE={mae:.2f} min")
    ax.set_xlabel("Actual MIN")
    ax.set_ylabel("Predicted MIN")
    ax.set_aspect("equal", adjustable="box")
    ax.text(
        0.04, 0.96,
        f"R² = {r2:.3f}\nMAE = {mae:.2f}",
        transform=ax.transAxes, ha="left", va="top", fontsize=10,
        bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.85, edgecolor="0.7"),
    )

plt.suptitle(f"Walk-Forward last fold — {last_fold['fold']}", y=1.02)
plt.tight_layout()
plt.show()

print("Per-quantile fit on last validation fold:")
for name, m in scatter_metrics.items():
    print(f"  {name}: R²={m['R2']:+.3f}  MAE={m['MAE']:.3f} min")

print("\nCoverage per quantile (should match quantile value):")
for name, y_pred in preds_plot.items():
    coverage = (y_true <= y_pred).mean()
    q_target = {"Q10": 0.10, "Q50": 0.50, "Q90": 0.90}[name]
    delta = coverage - q_target
    flag = "⚠" if abs(delta) > 0.05 else "✓"
    print(f"  {name}: {coverage:.1%}  (target {q_target:.0%}, delta {delta:+.1%})  {flag}")

interval_width = pred_high - pred_low
print(f"\n80% interval width (Q10→Q90):")
print(f"  mean   : {interval_width.mean():.2f} min")
print(f"  median : {np.median(interval_width):.2f} min")
print(f"  std    : {interval_width.std():.2f} min")

residuals = y_true - pred_mid
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].scatter(pred_mid, residuals, s=12, alpha=0.5, edgecolors="none")
axes[0].axhline(0, color="k", lw=1, linestyle="--")
axes[0].set_xlabel("Predicted MIN (Q50)")
axes[0].set_ylabel("Residual (actual − predicted)")
axes[0].set_title("Residuals vs Predicted")
axes[1].hist(residuals, bins=40, edgecolor="none")
axes[1].axvline(0, color="k", lw=1, linestyle="--")
axes[1].set_xlabel("Residual")
axes[1].set_title("Residual Distribution")
plt.tight_layout()
plt.show()

print(f"\nResidual summary:")
print(f"  mean bias : {residuals.mean():+.3f} min  (close to 0 = unbiased)")
print(f"  std       : {residuals.std():.3f} min")

starting_last = ppm_df.loc[X_val_last.index, "starting"].values
print("\nResiduals by role:")
for role, mask in [("Starters", starting_last == 1), ("Bench", starting_last == 0)]:
    if mask.sum() == 0:
        continue
    r = residuals[mask]
    print(f"  {role:10s} | n={mask.sum():5d} | bias={r.mean():+.3f} | std={r.std():.3f}")

print("\nResiduals by minutes tier:")
for tier, fn in MIN_TIERS.items():
    mask = fn(y_true)
    if mask.sum() == 0:
        continue
    r = residuals[mask]
    print(f"  {tier:10s} | n={mask.sum():5d} | bias={r.mean():+.3f} | std={r.std():.3f}")
# Out:
# Per-quantile fit on last validation fold:
#   Q10: R²=-0.159  MAE=6.897 min
#   Q50: R²=+0.558  MAE=4.039 min
#   Q90: R²=-0.110  MAE=6.691 min
#
# Coverage per quantile (should match quantile value):
#   Q10: 11.7%  (target 10%, delta +1.7%)  ✓
#   Q50: 49.7%  (target 50%, delta -0.3%)  ✓
#   Q90: 88.9%  (target 90%, delta -1.1%)  ✓
#
# 80% interval width (Q10→Q90):
#   mean   : 12.64 min
#   median : 12.31 min
#   std    : 2.08 min
# Residual summary:
#   mean bias : -0.225 min  (close to 0 = unbiased)
#   std       : 5.115 min
#
# Residuals by role:
#   Starters   | n= 1990 | bias=-0.512 | std=5.394
#   Bench      | n=  952 | bias=+0.375 | std=4.417
#
# Residuals by minutes tier:
#   <12.8 min  | n=   73 | bias=-5.126 | std=2.060
#   12.8-21.8 min | n=  945 | bias=-3.394 | std=4.526
#   21.8-30 min | n= 1118 | bias=-0.102 | std=4.627
#   30+ min    | n=  806 | bias=+3.763 | std=3.394

# %%
import shap

for q_key, model in models_last.items():
    explainer = shap.TreeExplainer(model, model_output="raw")
    shap_values = explainer(X_val_last)
    print(f"\n── {q_key} ──")
    shap.plots.beeswarm(shap_values, max_display=30, show=False)
    plt.title(f"SHAP beeswarm — {q_key}")
    plt.tight_layout()
    plt.show()
# Out:
# ── q_0.10 ──
# ── q_0.50 ──
# ── q_0.90 ──

# %%
model = models_last["q_0.50"]
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_val_last)

mean_abs_shap = np.abs(shap_values.values).mean(axis=0)
feat_imp = pd.Series(mean_abs_shap, index=MIN_FEATURES).sort_values(ascending=True)

ax = feat_imp.plot(kind="barh", figsize=(8, 6))
ax.set_title("Mean |SHAP| — q_0.50")
ax.set_xlabel("Mean absolute SHAP value")
plt.tight_layout()
plt.show()

# %%
from sklearn.inspection import permutation_importance
from sklearn.metrics import make_scorer
from scipy import stats as sp_stats

result = permutation_importance(
    models_last["q_0.50"],
    X_val_last,
    y_val_last,
    n_repeats=30,
    random_state=42,
    scoring=make_scorer(pinball_50),
)

pi_df = (
    pd.DataFrame({
        "feature": X_val_last.columns,
        "importance": result.importances_mean,
        "std": result.importances_std,
    })
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)
pi_df.index += 1
pi_df["importance"] = pi_df["importance"].round(5)
pi_df["std"] = pi_df["std"].round(5)
pi_df["p_value"] = sp_stats.ttest_1samp(result.importances, 0.0, axis=1).pvalue.round(4)
pi_df["significant"] = pi_df["p_value"] < 0.05

print("Permutation importance (val set) — higher = more important, significant = p<0.05")
print(pi_df.to_string())
# Out:
# Permutation importance (val set) — higher = more important, significant = p<0.05
#                   feature  importance      std  p_value  significant
# 1                starting     0.66984  0.02437      0.0         True
# 2     base_min_season_avg     0.23339  0.01327      0.0         True
# 3           base_min_lag1     0.11345  0.01039      0.0         True
# 4  track_minutes_ewm_hl10     0.10652  0.00934      0.0         True
# 5       team_min_rank_l10     0.05871  0.00614      0.0         True
# 6      starter_roll10_pct     0.03603  0.00706      0.0         True
# 7     base_min_trend_5v20     0.02290  0.00448      0.0         True
# 8   team_usg_pct_rank_l10     0.01277  0.00324      0.0         True

# %%
train_mask_last = last_fold["train_mask"]
val_mask_last = last_fold["val_mask"]
X_tr_last = X[train_mask_last]
X_va_last = X[val_mask_last]
y_tr_last = y[train_mask_last]
y_va_last = y[val_mask_last]

ablation_df = run_feature_ablation(
    MIN_FEATURES, X_tr_last, y_tr_last, X_va_last, y_va_last,
    xgb_params=XGB_PARAMS,
)
# Out:
# Baseline RMSE (all features): 5.1199
#                   feature  ablated_rmse  delta_rmse
# 1                starting        5.4487      0.3288
# 2      starter_roll10_pct        5.1540      0.0341
# 3     base_min_trend_5v20        5.1428      0.0229
# 4       team_min_rank_l10        5.1357      0.0158
# 5     base_min_season_avg        5.1347      0.0148
# 6   team_usg_pct_rank_l10        5.1341      0.0143
# 7  track_minutes_ewm_hl10        5.1294      0.0095
# 8           base_min_lag1        5.1239      0.0040

# %%
from scipy import stats

model = models_last["q_0.50"]
_shap_expl = shap.TreeExplainer(model, model_output="raw")
_shap_vals = _shap_expl(X_val_last)
_mean_abs_shap = np.abs(_shap_vals.values).mean(axis=0)

shap_table = pd.DataFrame({
    "feature": X_val_last.columns,
    "mean_abs_shap": _mean_abs_shap,
}).assign(shap_rank=lambda d: d["mean_abs_shap"].rank(method="min", ascending=False).astype(int))

perm_table = (
    pi_df.sort_values("importance", ascending=False)
    .reset_index(drop=True)
    .rename(columns={"importance": "perm_importance", "std": "perm_importance_std"})
)
perm_table["perm_rank"] = np.arange(1, len(perm_table) + 1)
perm_table = perm_table[["feature", "perm_rank", "perm_importance", "perm_importance_std"]]

perm_pv = pd.DataFrame({
    "feature": X_val_last.columns,
    "perm_pvalue": stats.ttest_1samp(result.importances, 0.0, axis=1, nan_policy="omit").pvalue,
})

abla = ablation_df[["feature", "delta_rmse"]].rename(columns={"delta_rmse": "ablation_delta"})

feature_audit = (
    pd.DataFrame({"feature": MIN_FEATURES})
    .merge(shap_table, on="feature", how="left")
    .merge(perm_table, on="feature", how="left")
    .merge(perm_pv, on="feature", how="left")
    .merge(abla, on="feature", how="left")
)

_ms = feature_audit["mean_abs_shap"].astype(float)
_mp = feature_audit["perm_importance"].astype(float)
_max_shap = _ms.fillna(0).max()
_max_perm = _mp.fillna(0).max()
feature_audit["shap_norm"] = np.where(_max_shap > 0, _ms.fillna(0) / _max_shap, 0.0)
feature_audit["perm_norm"] = np.where(_max_perm > 0, _mp.fillna(0) / _max_perm, 0.0)
feature_audit["consensus"] = (feature_audit["shap_norm"] + feature_audit["perm_norm"]) / 2
feature_audit = feature_audit.sort_values("consensus", ascending=False).reset_index(drop=True)
feature_audit.index += 1
feature_audit["keep"] = (feature_audit["perm_pvalue"] < 0.05) & (feature_audit["ablation_delta"] > 0)

print(feature_audit.to_string())
# Out:
#                   feature  mean_abs_shap  shap_rank  perm_rank  perm_importance  perm_importance_std   perm_pvalue  ablation_delta  shap_norm  perm_norm  consensus  keep
# 1                starting       2.987823          1          1          0.66984              0.02437  2.666161e-43          0.3288   1.000000   1.000000   1.000000  True
# 2     base_min_season_avg       1.667936          2          2          0.23339              0.01327  1.091256e-37          0.0148   0.558245   0.348426   0.453336  True
# 3           base_min_lag1       0.847117          3          3          0.11345              0.01039  1.031263e-31          0.0040   0.283523   0.169369   0.226446  True
# 4  track_minutes_ewm_hl10       0.834793          4          4          0.10652              0.00934  2.931139e-32          0.0095   0.279398   0.159023   0.219211  True
# 5       team_min_rank_l10       0.454066          5          5          0.05871              0.00614  4.535379e-30          0.0158   0.151972   0.087648   0.119810  True
# 6      starter_roll10_pct       0.442907          6          6          0.03603              0.00706  2.570808e-22          0.0341   0.148237   0.053789   0.101013  True
# 7     base_min_trend_5v20       0.272854          7          7          0.02290              0.00448  2.466972e-22          0.0229   0.091322   0.034187   0.062755  True
# 8   team_usg_pct_rank_l10       0.262836          8          8          0.01277              0.00324  3.121772e-19          0.0143   0.087969   0.019064   0.053517  True

# %%
correlated_features = analyze_correlations(
    df, MIN_FEATURES, title="Feature Correlation Matrix — WNBA MIN"
)
correlated_features
# Out:
# --- High Correlation Report (Threshold > 0.95) ---
# track_minutes_ewm_hl10 <-> base_min_season_avg: 0.9919
# ['track_minutes_ewm_hl10']

# %%
holdout = evaluate_holdout(
    ppm_df,
    ppm_holdout,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    wf_results=wf_results,
    quantiles=QUANTILES,
    fold_label=f"{HOLDOUT_SEASON} Blind Holdout",
)
models_ho = holdout["models_ho"]
preds_ho = holdout["preds_ho"]
ho_metrics = holdout["ho_metrics"]
X_ho = holdout["X_ho"]
y_ho = holdout["y_ho"]
# Out:
# ── 2026 Blind Holdout ─────────────────────────────────────────────────
#   Train pool: 90% rows for fit, remainder for early-stopping only; predict holdout (never in eval_set).
#
# 2026 Blind Holdout
#   Overall  | n= 3052 | MAE: 3.569 | R²: 0.585 | 80% Coverage: 84.9%
#   Starters   | n= 1985 | MAE: 3.754 | Coverage: 86.2%
#   Bench      | n= 1067 | MAE: 3.225 | Coverage: 82.6%
#   <12.8 min  | n=   83 | MAE: 5.085 | Coverage: 1.2%
#   12.8-21.8 min | n= 1068 | MAE: 3.740 | Coverage: 85.0%
#   21.8-30 min | n= 1295 | MAE: 3.224 | Coverage: 92.3%
#   30+ min    | n=  606 | MAE: 3.796 | Coverage: 80.5%
#
# ───────────────────────────────────────────────────────
#   Walk-forward MAE (mean)  : 3.890
#   Holdout MAE              : 3.569
#   Gap                      : -0.321  ✓ acceptable
#
# Holdout quantile calibration (should match target):
#   q_0.10 | actual coverage: 8.9%  target: 10%  delta: -1.1%  ✓
#   q_0.50 | actual coverage: 54.6%  target: 50%  delta: +4.6%  ✓
#   q_0.90 | actual coverage: 93.9%  target: 90%  delta: +3.9%  ✓
#
# Holdout 80% interval width (Q10→Q90):
#   mean: 12.85  |  median: 12.76  |  std: 1.99

# %%
naive_holdout_results = evaluate_holdout_vs_naive(
    ppm_holdout,
    preds_ho,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    naive_wf_primary=naive["naive_wf_primary"],
    wf_test_primary=naive["wf_test_primary"],
    alpha=ALPHA,
    holdout_label=f"{HOLDOUT_SEASON} holdout",
)
# Out:
# ───────────────────────────────────────────────────────
# 2026 holdout — model vs frozen naive baselines
#   H0: model does not beat naive | H1: model beats naive (α=0.05)
#
#   PRIMARY (base_min_season_avg)
#     n paired   : 2,899
#     MAE model  : 3.556
#     MAE naive  : 4.353
#     ΔMAE (m−n) : -0.797
#     Wilcoxon p : 1.789e-33
#     Decision   : REJECT H0 — model significantly better
#
#   secondary (base_min_lag1)
#     n paired   : 2,899
#     MAE model  : 3.556
#     MAE naive  : 5.086
#     ΔMAE (m−n) : -1.529
#     Wilcoxon p : 2.43e-83
#     Decision   : REJECT H0 — model significantly better

# %% [markdown]
# ### Complexity ladder — naive → linear quantile → XGB
#
# Report-only baseline (not shipped). Same `MIN_FEATURES` and walk-forward / holdout masks as XGB.
#
# - **Linear:** `SimpleImputer(median)` → `StandardScaler` → `QuantileRegressor` (Q10/Q50/Q90)
# - Pairwise Wilcoxon on |error|: linear vs naive, XGB vs linear (α = 0.05)
# - Authoritative decision remains XGB vs frozen naive on holdout; this ladder answers “does nonlinearity buy anything?”

# %%
linear = run_quantile_linear_baseline(
    X, y, ppm_df,
    holdout_df=ppm_holdout,
    wf_results=wf_results,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    xgb_preds_last=preds_last,
    xgb_preds_ho=preds_ho,
    last_fold=last_fold,
    role_col=ROLE_COL,
    quantiles=QUANTILES,
    alpha=ALPHA,
    holdout_label=f"{HOLDOUT_SEASON} holdout",
)
# Out:
# ── Quantile linear baseline (report-only) ───────────────────────────
#   Features : 8
#   Quantiles: [0.1, 0.5, 0.9]
#   L1 alpha : 0.0
#
# Three-way MAE by walk-forward fold:
#   Fold                                             Naive   Linear      XGB     ΔL−N     ΔX−L    Cov80
#   WF fold 1  (2022-06-30 → 2023-06-17)             4.850    3.898    3.830   -0.952   -0.068   82.1%
#   WF fold 2  (2023-06-17 → 2023-10-01)             4.940    3.967    3.924   -0.973   -0.044   79.7%
#   WF fold 3  (2023-10-01 → 2024-08-26)             4.803    3.904    3.767   -0.899   -0.137   81.0%
#   WF fold 4  (2024-08-26 → 2025-07-06)             5.116    4.142    4.039   -0.975   -0.102   78.0%
#
# ────────────────────────────────────────────────────────────
# Walk-forward last-fold pairwise tests:
#   WF last fold: linear vs naive
#     MAE challenger=4.132  baseline=5.116  Δ=-0.985  p=9.05e-35  REJECT
#   WF last fold: XGB vs linear
#     MAE challenger=4.039  baseline=4.142  Δ=-0.102  p=3.755e-07  REJECT
#
# Linear | 2026 holdout
#   Overall  | n= 3052 | MAE: 3.730 | R²: 0.557 | 80% Coverage: 84.3%
#   Starters   | n= 1985 | MAE: 3.877 | Coverage: 85.2%
#   Bench      | n= 1067 | MAE: 3.456 | Coverage: 82.7%
#   10-20 min  | n=  925 | MAE: 4.178 | Coverage: 76.2%
#   20-30 min  | n= 1319 | MAE: 3.569 | Coverage: 90.3%
#   30+ min    | n=  808 | MAE: 3.478 | Coverage: 83.8%
#
# 2026 holdout three-way MAE:
#   Naive  : 4.353
#   Linear : 3.730  (cov80=84.3%)
#   XGB    : 3.569
#
# 2026 holdout pairwise tests:
#   2026 holdout: linear vs naive
#     MAE challenger=3.698  baseline=4.353  Δ=-0.655  p=1.79e-21  REJECT
#   2026 holdout: XGB vs linear
#     MAE challenger=3.569  baseline=3.730  Δ=-0.161  p=2.564e-14  REJECT

# %%
from sklearn.metrics import mean_absolute_error

save_path = save_model_bundle(
    models_ho,
    train_df=ppm_df,
    holdout_df=ppm_holdout,
    wf_results=wf_results,
    ho_metrics=ho_metrics,
    features=MIN_FEATURES,
    artifact_stem=ARTIFACT_STEM,
    naive_holdout_results=naive_holdout_results,
)

bundle = load_model_bundle(save_path)
models_loaded = bundle["quantile_models"]
feature_names = bundle["feature_names"]

test_preds = models_loaded["q_0.50"].predict(X_ho)
print(f"Loaded model MAE (holdout): {mean_absolute_error(y_ho, test_preds):.3f}")
print(f"Trained on data up to      : {bundle['train_end'].date()}")
print(f"Holdout through            : {bundle['val_end'].date()}")

predict_quantiles(models_loaded, feature_names, X_ho.head(3))
# Out:
# Saved to /Users/alexgonzalez/Documents/NBA-Prop-Predictor/models/saved_models/min_wnba_model_2026-07-22.joblib
# Loaded /Users/alexgonzalez/Documents/NBA-Prop-Predictor/models/saved_models/min_wnba_model_2026-07-22.joblib
# Loaded model MAE (holdout): 3.569
# Trained on data up to      : 2025-10-10
# Holdout through            : 2026-07-22
#          q10        q50        q90
# 0  13.161235  18.279322  26.113043
# 1  18.729353  27.521181  34.685413
# 2  13.161235  18.279322  26.113043
