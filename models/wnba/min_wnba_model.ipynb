# %%
import pandas as pd
import numpy as np
import warnings
from pathlib import Path
import sys
import os

project_root = Path.cwd().resolve()
# Notebook lives at models/wnba/ — climb to repo root if needed
if not (project_root / "data").exists():
    project_root = project_root.parent.parent

project_root_str = str(project_root)
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)
os.chdir(project_root_str)

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
from src.pipeline.features.context_features import ContextFeatureEngineer

seasons = [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]
frames = []
for yr in seasons:
    path = f"data/processed/wnba_{yr}_Regular_Season_training_data.parquet"
    season_df = pd.read_parquet(path)
    season_df = ContextFeatureEngineer(league="wnba").enrich(season_df)
    frames.append(season_df)

df = pd.concat(frames, ignore_index=True)
df.sample(10)
# Out:
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2018_players.csv (season=2018)
#   pos filled on 4,359 / 4,418 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (229 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 138 / 4,418 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2019_players.csv (season=2019)
#   pos filled on 4,213 / 4,288 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (64 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,821 / 4,288 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 145 positions from wnba_2020_players.csv (season=2020)
#   pos filled on 2,775 / 2,796 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (57 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 2,363 / 2,796 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 155 positions from wnba_2021_players.csv (season=2021)
#   pos filled on 3,853 / 3,885 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (9 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,433 / 3,885 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 166 positions from wnba_2022_players.csv (season=2022)
#   pos filled on 4,494 / 4,519 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (104 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,030 / 4,519 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 156 positions from wnba_2023_players.csv (season=2023)
#   pos filled on 4,826 / 4,898 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (83 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,436 / 4,898 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 157 positions from wnba_2024_players.csv (season=2024)
#   pos filled on 4,914 / 4,914 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (211 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 4,450 / 4,914 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 182 positions from wnba_2025_players.csv (season=2025)
#   pos filled on 5,829 / 5,853 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (268 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 5,316 / 5,853 rows
#
# ============================================================
# Context features (pos, rest, trends, ranks, std/var, games played)
# ============================================================
#
# Merging player positions...
#   loaded 219 positions from wnba_2026_players.csv (season=2026)
#   pos filled on 3,926 / 4,011 rows (1 season file(s))
#
# Adding games_played to date...
#   games_played + season_games_played
#
# Adding rest / back-to-back...
#   days_rest + is_back_to_back (105 B2B rows)
#
# Adding fatigue window features...
#   games_played_last_7/14_days + min_sum_last_7_days (from minutes)
#
# Adding 5v20 trends...
#   added 7 trend cols: ['base_min_trend_5v20', 'base_pts_per_min_trend_5v20', 'adv_ts_pct_trend_5v20', 'adv_usg_pct_trend_5v20', 'base_ast_per_min_trend_5v20', 'base_oreb_per_min_trend_5v20', 'base_dreb_per_min_trend_5v20']
#
# Adding within-team ranks...
#   added 7 rank cols: ['team_pts_per_min_rank_l10', 'team_ast_per_min_rank_l10', 'team_oreb_per_min_rank_l10', 'team_dreb_per_min_rank_l10', 'team_ts_pct_rank_l10', 'team_usg_pct_rank_l10', 'team_min_rank_l10']
#
# Adding rolling team rank for pts_per_min (L10)...
#   pts_per_min_roll10 → team_pts_per_min_rank_roll10
#
# Adding rolling std/var (windows=[5, 10, 15])...
#   ⚠ skip missing col: ts_pct
#   ⚠ skip missing col: usg_pct
#   added 36 cols on 6 stats
#
# Adding starter roll10 features...
#   starter_roll10_pct defined on 3,371 / 4,011 rows
#           game_id  player_id     team_id       player_name  game_date  \
# 3638   1021800160    1628282  1611661320      Sydney Wiese 2018-08-02
# 14943  1022100149    1630119  1611661313     Jazmine Jones 2021-08-27
# 11127  1022001128    1630093  1611661321      Bella Alarie 2020-09-11
# 31493  1022500030    1628277  1611661330      Allisha Gray 2025-05-27
# 67     1021800187     100915  1611661324    Lindsay Whalen 2018-08-12
# 820    1021800130     201896  1611661317    Briann January 2018-07-15
# 5235   1021900014     202650  1611661329   Jantel Lavender 2019-06-01
# 23225  1022300213    1630112  1611661323     Tyasha Harris 2023-08-31
# 32212  1042500303    1628957  1611661317  Kathryn Westbeld 2025-10-08
# 27758  1022400137    1629568  1611661313     Kennedy Burke 2024-07-13
#
#       season_year      matchup    minutes  pts_per_min  fga_per_min  \
# 3638         2018  LAS vs. MIN   2.433333     0.000000     0.000000
# 14943        2021  NYL vs. PHO   9.350000     0.213904     0.427807
# 11127        2020  DAL vs. CHI  19.896667     0.251298     0.301558
# 31493        2025    ATL @ LAS  35.708333     0.700117     0.224037
# 67           2018  MIN vs. SEA  15.050000     0.265781     0.199336
# 820          2018    PHO @ IND  16.950000     0.294985     0.294985
# 5235         2019  CHI vs. SEA  32.266667     0.247934     0.247934
# 23225        2023  CON vs. PHO  19.766667     0.910624     0.354132
# 32212        2025  PHX vs. LVA   6.400000     0.312500     0.312500
# 27758        2024    NYL @ CHI  30.556667     0.229083     0.294535
#
#        fg3a_per_min  fta_per_min  oreb_per_min  dreb_per_min  reb_per_min  \
# 3638       0.000000     0.000000      0.000000      0.410959     0.410959
# 14943      0.000000     0.000000      0.000000      0.213904     0.213904
# 11127      0.050260     0.000000      0.150779      0.050260     0.201039
# 31493      0.056009     0.252042      0.000000      0.140023     0.140023
# 67         0.000000     0.000000      0.000000      0.000000     0.000000
# 820        0.235988     0.000000      0.000000      0.000000     0.000000
# 5235       0.030992     0.000000      0.092975      0.123967     0.216942
# 23225      0.202361     0.101180      0.000000      0.000000     0.000000
# 32212      0.000000     0.000000      0.000000      0.000000     0.000000
# 27758      0.196356     0.000000      0.000000      0.098178     0.098178
#
#        ast_per_min  tov_per_min  stl_per_min  blk_per_min  blka_per_min  \
# 3638      0.000000     0.000000     0.000000     0.000000      0.000000
# 14943     0.000000     0.000000     0.000000     0.000000      0.000000
# 11127     0.000000     0.000000     0.050260     0.000000      0.000000
# 31493     0.168028     0.056009     0.028005     0.000000      0.000000
# 67        0.000000     0.000000     0.066445     0.000000      0.000000
# 820       0.000000     0.000000     0.000000     0.058997      0.000000
# 5235      0.092975     0.123967     0.061983     0.000000      0.030992
# 23225     0.101180     0.000000     0.050590     0.000000      0.000000
# 32212     0.000000     0.000000     0.156250     0.000000      0.000000
# 27758     0.065452     0.032726     0.098178     0.032726      0.000000
#
#        games_played  base_min_ewm_hl5  base_min_roll5  base_min_ewm_hl10  \
# 3638              8          3.801790        4.768333           3.794779
# 14943            22         19.600747       21.170000          19.037761
# 11127            20         11.572825        9.245667          12.307211
# 31493             5         34.442280       34.562333          34.500240
# 67               28         18.875424       17.593667          19.191768
# 820              21         24.830248       21.261000          25.583180
# 5235              1               NaN             NaN                NaN
# 23225            35         18.006536       18.963333          17.161334
# 32212            52         12.705353       12.280000          13.823544
# 27758            22         10.205015       10.160667          10.148557
#
#        base_min_roll10  base_min_ewm_hl20  base_min_roll20  base_min_lag1  \
# 3638          3.742708           3.774172         3.742708       0.751667
# 14943        19.753333          18.637075        18.479667      17.583333
# 11127        11.265167          12.693256        13.048833      14.233333
# 31493        34.562333          34.530781        34.562333      33.180000
# 67           18.358500          19.363425        19.333583      13.956667
# 820          24.402000          25.994894        26.321167      27.700000
# 5235               NaN                NaN              NaN      22.816667
# 23225        19.271667          16.520615        18.571833      20.766667
# 32212        12.527500          15.191020        12.919250      16.833333
# 27758        10.545333          10.062577         9.999167       5.800000
#
#        base_min_season_avg  base_fg_pct_ewm_hl5  base_fg_pct_roll5  \
# 3638              3.742708             0.000000             0.0000
# 14943            18.175000             0.294215             0.2842
# 11127            13.048833             0.304038             0.3200
# 31493            34.562333             0.452891             0.4438
# 67               19.549226             0.264684             0.1834
# 820              26.395556             0.362993             0.3334
# 5235             22.816667                  NaN                NaN
# 23225            15.715381             0.344075             0.3504
# 32212            17.256987             0.364581             0.4166
# 27758             9.945985             0.254941             0.3434
#
#        base_fg_pct_ewm_hl10  base_fg_pct_roll10  base_fg_pct_ewm_hl20  \
# 3638               0.000000              0.0000              0.000000
# 14943              0.321351              0.2879              0.333477
# 11127              0.317656              0.2833              0.325647
# 31493              0.448098              0.4438              0.445881
# 67                 0.286913              0.2695              0.295779
# 820                0.369391              0.4110              0.372098
# 5235                    NaN                 NaN                   NaN
# 23225              0.369193              0.3403              0.382501
# 32212              0.374992              0.4583              0.371780
# 27758              0.257354              0.2146              0.262008
#
#        base_fg_pct_roll20  base_fg_pct_lag1  base_fg_pct_season_avg  \
# 3638              0.00000             0.000                0.000000
# 14943             0.34940             0.000                0.343591
# 11127             0.33330             0.600                0.333300
# 31493             0.44380             0.545                0.443800
# 67                0.31660             0.000                0.302000
# 820               0.36380             0.167                0.375048
# 5235                  NaN             0.500                0.500000
# 23225             0.37525             0.333                0.391571
# 32212             0.40165             0.000                0.366519
# 27758             0.21395             0.000                0.270273
#
#        base_fg3_pct_ewm_hl5  base_fg3_pct_roll5  base_fg3_pct_ewm_hl10  \
# 3638               0.000000              0.0000               0.000000
# 14943              0.277348              0.2858               0.297489
# 11127              0.000000              0.0000               0.000000
# 31493              0.369982              0.3688               0.368717
# 67                 0.212732              0.2000               0.218605
# 820                0.352413              0.3500               0.393230
# 5235                    NaN                 NaN                    NaN
# 23225              0.378826              0.5466               0.369330
# 32212              0.328228              0.4000               0.327776
# 27758              0.095303              0.0666               0.135658
#
#        base_fg3_pct_roll10  base_fg3_pct_ewm_hl20  base_fg3_pct_roll20  \
# 3638                0.0000               0.000000              0.00000
# 14943               0.2762               0.304423              0.28990
# 11127               0.0000               0.000000              0.00000
# 31493               0.3688               0.368586              0.36880
# 67                  0.2000               0.223614              0.20000
# 820                 0.3917               0.415066              0.43420
# 5235                   NaN                    NaN                  NaN
# 23225               0.3566               0.362208              0.40745
# 32212               0.4000               0.317729              0.33750
# 27758               0.0333               0.163943              0.14165
#
#        base_fg3_pct_lag1  base_fg3_pct_season_avg  base_ft_pct_ewm_hl5  \
# 3638                0.00                 0.000000             0.000000
# 14943               0.00                 0.309000             0.487743
# 11127               0.00                 0.000000             0.291524
# 31493               0.50                 0.368800             0.772531
# 67                  0.00                 0.232143             0.311734
# 820                 0.25                 0.437333             0.369499
# 5235                0.00                 0.000000                  NaN
# 23225               0.40                 0.351886             0.094987
# 32212               0.00                 0.306558             0.053986
# 27758               0.00                 0.196955             0.037668
#
#        base_ft_pct_roll5  base_ft_pct_ewm_hl10  base_ft_pct_roll10  \
# 3638              0.0000              0.000000              0.0000
# 14943             0.5834              0.448054              0.4417
# 11127             0.4000              0.263370              0.2000
# 31493             0.7600              0.766438              0.7600
# 67                0.2000              0.357570              0.4000
# 820               0.2000              0.404264              0.4000
# 5235                 NaN                   NaN                 NaN
# 23225             0.0000              0.128195              0.1000
# 32212             0.0000              0.094103              0.0875
# 27758             0.0000              0.052781              0.0000
#
#        base_ft_pct_ewm_hl20  base_ft_pct_roll20  base_ft_pct_lag1  \
# 3638               0.000000             0.00000               0.0
# 14943              0.425777             0.44170               1.0
# 11127              0.254623             0.25000               0.5
# 31493              0.763258             0.76000               0.8
# 67                 0.374975             0.35000               0.0
# 820                0.425196             0.43330               0.0
# 5235                    NaN                 NaN               1.0
# 23225              0.144699             0.17500               0.0
# 32212              0.131368             0.06875               0.0
# 27758              0.060569             0.05000               0.0
#
#        base_ft_pct_season_avg  base_plus_minus_ewm_hl5  base_plus_minus_roll5  \
# 3638                 0.000000                -0.466264                   -1.4
# 14943                0.401545                -3.943698                   -3.0
# 11127                0.250000                -4.287498                   -5.8
# 31493                0.760000                 5.641952                    4.2
# 67                   0.387750                 0.646577                    0.2
# 820                  0.448381                -0.295499                   -4.2
# 5235                 1.000000                      NaN                    NaN
# 23225                0.157143                 0.213587                   -1.2
# 32212                0.176442                -1.217064                   -2.2
# 27758                0.068182                -1.271878                   -0.6
#
#        base_plus_minus_ewm_hl10  base_plus_minus_roll10  \
# 3638                  -0.508333                    -0.5
# 14943                 -4.103379                    -3.7
# 11127                 -2.744553                    -4.1
# 31493                  4.908319                     4.2
# 67                     1.253564                    -0.5
# 820                    1.144744                     1.0
# 5235                        NaN                     NaN
# 23225                  0.530507                     1.2
# 32212                 -0.236233                     0.2
# 27758                 -1.006317                    -2.2
#
#        base_plus_minus_ewm_hl20  base_plus_minus_roll20  base_plus_minus_lag1  \
# 3638                  -0.510720                   -0.50                   0.0
# 14943                 -4.161258                   -5.25                  -6.0
# 11127                 -1.848107                   -0.90                 -18.0
# 31493                  4.550515                    4.20                  20.0
# 67                     1.463151                    2.75                  -7.0
# 820                    1.755010                    1.95                  -5.0
# 5235                        NaN                     NaN                  -7.0
# 23225                  0.656661                    0.90                   5.0
# 32212                  0.441459                   -0.65                 -15.0
# 27758                 -0.801648                   -1.45                  -8.0
#
#        base_plus_minus_season_avg  base_pts_per_min_ewm_hl5  \
# 3638                    -0.500000                  0.000000
# 14943                   -4.181818                  0.365525
# 11127                   -0.900000                  0.197304
# 31493                    4.200000                  0.554773
# 67                       1.571429                  0.238805
# 820                      2.238095                  0.193107
# 5235                    -7.000000                       NaN
# 23225                    0.742857                  0.268344
# 32212                    1.288462                  0.227763
# 27758                   -0.545455                  0.214608
#
#        base_pts_per_min_roll5  base_pts_per_min_ewm_hl10  \
# 3638                 0.000000                   0.000000
# 14943                0.452673                   0.357672
# 11127                0.237840                   0.183233
# 31493                0.554179                   0.554231
# 67                   0.175726                   0.248699
# 820                  0.135568                   0.214352
# 5235                      NaN                        NaN
# 23225                0.294197                   0.278071
# 32212                0.210310                   0.249373
# 27758                0.262137                   0.216848
#
#        base_pts_per_min_roll10  base_pts_per_min_ewm_hl20  \
# 3638                  0.000000                   0.000000
# 14943                 0.352729                   0.349810
# 11127                 0.175266                   0.177570
# 31493                 0.554179                   0.554140
# 67                    0.272022                   0.251478
# 820                   0.214367                   0.226169
# 5235                       NaN                        NaN
# 23225                 0.297817                   0.287301
# 32212                 0.282000                   0.257202
# 27758                 0.165095                   0.220514
#
#        base_pts_per_min_roll20  base_pts_per_min_lag1  \
# 3638                  0.000000               0.000000
# 14943                 0.342179               0.113744
# 11127                 0.172904               0.491803
# 31493                 0.554179               0.542495
# 67                    0.253013               0.000000
# 820                   0.232493               0.108303
# 5235                       NaN               0.438276
# 23225                 0.278322               0.288925
# 32212                 0.267323               0.000000
# 27758                 0.189139               0.000000
#
#        base_pts_per_min_season_avg  base_fga_per_min_ewm_hl5  \
# 3638                      0.000000                  0.112355
# 14943                     0.339690                  0.350404
# 11127                     0.172904                  0.193017
# 31493                     0.554179                  0.389276
# 67                        0.253084                  0.283539
# 820                       0.238500                  0.187295
# 5235                      0.438276                       NaN
# 23225                     0.298784                  0.317514
# 32212                     0.263922                  0.240522
# 27758                     0.226667                  0.282659
#
#        base_fga_per_min_roll5  base_fga_per_min_ewm_hl10  \
# 3638                 0.066325                   0.115602
# 14943                0.375506                   0.341503
# 11127                0.192691                   0.187672
# 31493                0.393191                   0.391331
# 67                   0.268065                   0.277109
# 820                  0.187419                   0.186827
# 5235                      NaN                        NaN
# 23225                0.282659                   0.326504
# 32212                0.245492                   0.245622
# 27758                0.311063                   0.282663
#
#        base_fga_per_min_roll10  base_fga_per_min_ewm_hl20  \
# 3638                  0.117984                   0.116918
# 14943                 0.349695                   0.333512
# 11127                 0.184136                   0.185187
# 31493                 0.393191                   0.392287
# 67                    0.273723                   0.276017
# 820                   0.196588                   0.186751
# 5235                       NaN                        NaN
# 23225                 0.318695                   0.331544
# 32212                 0.225816                   0.252142
# 27758                 0.269952                   0.282277
#
#        base_fga_per_min_roll20  base_fga_per_min_lag1  \
# 3638                  0.117984               0.000000
# 14943                 0.330417               0.113744
# 11127                 0.182702               0.351288
# 31493                 0.393191               0.331525
# 67                    0.268811               0.358252
# 820                   0.187264               0.216606
# 5235                       NaN               0.350621
# 23225                 0.331214               0.288925
# 32212                 0.235861               0.178218
# 27758                 0.283733               0.000000
#
#        base_fga_per_min_season_avg  base_fg3a_per_min_ewm_hl5  \
# 3638                      0.117984                   0.112355
# 14943                     0.323574                   0.120450
# 11127                     0.182702                   0.035024
# 31493                     0.393191                   0.207025
# 67                        0.276489                   0.057611
# 820                       0.186885                   0.099315
# 5235                      0.350621                        NaN
# 23225                     0.337450                   0.140797
# 32212                     0.260460                   0.199095
# 27758                     0.281862                   0.106973
#
#        base_fg3a_per_min_roll5  base_fg3a_per_min_ewm_hl10  \
# 3638                  0.066325                    0.115602
# 14943                 0.141703                    0.113955
# 11127                 0.031097                    0.034478
# 31493                 0.216741                    0.211881
# 67                    0.047289                    0.057453
# 820                   0.102971                    0.096965
# 5235                       NaN                         NaN
# 23225                 0.181090                    0.132655
# 32212                 0.231746                    0.183486
# 27758                 0.126678                    0.109553
#
#        base_fg3a_per_min_roll10  base_fg3a_per_min_ewm_hl20  \
# 3638                   0.117984                    0.116918
# 14943                  0.124434                    0.108863
# 11127                  0.041427                    0.034122
# 31493                  0.216741                    0.214314
# 67                     0.061819                    0.057445
# 820                    0.104347                    0.095716
# 5235                        NaN                         NaN
# 23225                  0.135884                    0.131935
# 32212                  0.185825                    0.176039
# 27758                  0.107149                    0.111190
#
#        base_fg3a_per_min_roll20  base_fg3a_per_min_lag1  \
# 3638                   0.117984                0.000000
# 14943                  0.103613                0.000000
# 11127                  0.033722                0.070258
# 31493                  0.216741                0.120555
# 67                     0.053206                0.000000
# 820                    0.095549                0.144404
# 5235                        NaN                0.000000
# 23225                  0.118756                0.240770
# 32212                  0.181545                0.178218
# 27758                  0.108954                0.000000
#
#        base_fg3a_per_min_season_avg  base_fta_per_min_ewm_hl5  \
# 3638                       0.117984                  0.000000
# 14943                      0.103079                  0.131463
# 11127                      0.033722                  0.066753
# 31493                      0.216741                  0.165318
# 67                         0.057776                  0.047520
# 820                        0.094415                  0.037018
# 5235                       0.000000                       NaN
# 23225                      0.134587                  0.015085
# 32212                      0.171181                  0.021623
# 27758                      0.113141                  0.007887
#
#        base_fta_per_min_roll5  base_fta_per_min_ewm_hl10  \
# 3638                 0.000000                   0.000000
# 14943                0.203819                   0.112439
# 11127                0.106581                   0.054050
# 31493                0.166056                   0.165621
# 67                   0.008464                   0.056585
# 820                  0.009160                   0.045473
# 5235                      NaN                        NaN
# 23225                0.000000                   0.020462
# 32212                0.000000                   0.028309
# 27758                0.000000                   0.012546
#
#        base_fta_per_min_roll10  base_fta_per_min_ewm_hl20  \
# 3638                  0.000000                   0.000000
# 14943                 0.117420                   0.102251
# 11127                 0.053290                   0.048343
# 31493                 0.166056                   0.165820
# 67                    0.066762                   0.059869
# 820                   0.038986                   0.050805
# 5235                       NaN                        NaN
# 23225                 0.017870                   0.023271
# 32212                 0.040134                   0.031006
# 27758                 0.000000                   0.015631
#
#        base_fta_per_min_roll20  base_fta_per_min_lag1  \
# 3638                  0.000000               0.000000
# 14943                 0.101283               0.113744
# 11127                 0.043399               0.140515
# 31493                 0.166056               0.150693
# 67                    0.057064               0.000000
# 820                   0.052520               0.000000
# 5235                       NaN               0.087655
# 23225                 0.026575               0.000000
# 32212                 0.030219               0.000000
# 27758                 0.008942               0.000000
#
#        base_fta_per_min_season_avg  base_oreb_per_min_ewm_hl5  \
# 3638                      0.000000                   0.000000
# 14943                     0.092075                   0.034314
# 11127                     0.043399                   0.035251
# 31493                     0.166056                   0.033260
# 67                        0.062343                   0.020252
# 820                       0.056850                   0.017513
# 5235                      0.087655                        NaN
# 23225                     0.025610                   0.009251
# 32212                     0.032558                   0.046239
# 27758                     0.019268                   0.027202
#
#        base_oreb_per_min_roll5  base_oreb_per_min_ewm_hl10  \
# 3638                  0.000000                    0.000000
# 14943                 0.030124                    0.036705
# 11127                 0.021978                    0.044164
# 31493                 0.034577                    0.033891
# 67                    0.012539                    0.020007
# 820                   0.011917                    0.018296
# 5235                       NaN                         NaN
# 23225                 0.009631                    0.007603
# 32212                 0.047194                    0.045170
# 27758                 0.015408                    0.032019
#
#        base_oreb_per_min_roll10  base_oreb_per_min_ewm_hl20  \
# 3638                   0.000000                    0.000000
# 14943                  0.030601                    0.037637
# 11127                  0.036366                    0.049458
# 31493                  0.034577                    0.034227
# 67                     0.025652                    0.019037
# 820                    0.021891                    0.018438
# 5235                        NaN                         NaN
# 23225                  0.009166                    0.007101
# 32212                  0.054639                    0.042701
# 27758                  0.023195                    0.034135
#
#        base_oreb_per_min_roll20  base_oreb_per_min_lag1  \
# 3638                   0.000000                0.000000
# 14943                  0.038810                0.056872
# 11127                  0.055094                0.000000
# 31493                  0.034577                0.030139
# 67                     0.019620                0.000000
# 820                    0.019332                0.000000
# 5235                        NaN                0.043828
# 23225                  0.006586                0.048154
# 32212                  0.050241                0.000000
# 27758                  0.034799                0.000000
#
#        base_oreb_per_min_season_avg  base_dreb_per_min_ewm_hl5  \
# 3638                       0.000000                   0.049462
# 14943                      0.038143                   0.116032
# 11127                      0.055094                   0.106998
# 31493                      0.034577                   0.125987
# 67                         0.017499                   0.161292
# 820                        0.018412                   0.052754
# 5235                       0.043828                        NaN
# 23225                      0.006944                   0.025324
# 32212                      0.039993                   0.159350
# 27758                      0.035897                   0.080312
#
#        base_dreb_per_min_roll5  base_dreb_per_min_ewm_hl10  \
# 3638                  0.012513                    0.059211
# 14943                 0.090953                    0.125577
# 11127                 0.064348                    0.110079
# 31493                 0.122402                    0.124068
# 67                    0.210341                    0.141402
# 820                   0.048317                    0.055815
# 5235                       NaN                         NaN
# 23225                 0.024610                    0.032744
# 32212                 0.191342                    0.135520
# 27758                 0.057470                    0.087257
#
#        base_dreb_per_min_roll10  base_dreb_per_min_ewm_hl20  \
# 3638                   0.069498                    0.064313
# 14943                  0.121049                    0.129948
# 11127                  0.094216                    0.111360
# 31493                  0.122402                    0.123201
# 67                     0.178731                    0.131053
# 820                    0.053127                    0.057184
# 5235                        NaN                         NaN
# 23225                  0.020703                    0.038202
# 32212                  0.164505                    0.121651
# 27758                  0.091091                    0.090754
#
#        base_dreb_per_min_roll20  base_dreb_per_min_lag1  \
# 3638                   0.069498                0.000000
# 14943                  0.140319                0.000000
# 11127                  0.111870                0.210773
# 31493                  0.122402                0.180832
# 67                     0.123219                0.143301
# 820                    0.055965                0.036101
# 5235                        NaN                0.087655
# 23225                  0.031691                0.000000
# 32212                  0.134868                0.178218
# 27758                  0.086751                0.000000
#
#        base_dreb_per_min_season_avg  base_reb_per_min_ewm_hl5  \
# 3638                       0.069498                  0.049462
# 14943                      0.133587                  0.150346
# 11127                      0.111870                  0.142249
# 31493                      0.122402                  0.159247
# 67                         0.121909                  0.181544
# 820                        0.058423                  0.070266
# 5235                       0.087655                       NaN
# 23225                      0.044568                  0.034574
# 32212                      0.110288                  0.205589
# 27758                      0.094264                  0.107514
#
#        base_reb_per_min_roll5  base_reb_per_min_ewm_hl10  \
# 3638                 0.012513                   0.059211
# 14943                0.121077                   0.162282
# 11127                0.086326                   0.154243
# 31493                0.156979                   0.157959
# 67                   0.222880                   0.161409
# 820                  0.060234                   0.074111
# 5235                      NaN                        NaN
# 23225                0.034240                   0.040346
# 32212                0.238536                   0.180690
# 27758                0.072878                   0.119276
#
#        base_reb_per_min_roll10  base_reb_per_min_ewm_hl20  \
# 3638                  0.069498                   0.064313
# 14943                 0.151650                   0.167585
# 11127                 0.130582                   0.160818
# 31493                 0.156979                   0.157429
# 67                    0.204383                   0.150090
# 820                   0.075018                   0.075622
# 5235                       NaN                        NaN
# 23225                 0.029870                   0.045303
# 32212                 0.219144                   0.164352
# 27758                 0.114286                   0.124888
#
#        base_reb_per_min_roll20  base_reb_per_min_lag1  \
# 3638                  0.069498               0.000000
# 14943                 0.179129               0.056872
# 11127                 0.166964               0.210773
# 31493                 0.156979               0.210970
# 67                    0.142840               0.143301
# 820                   0.075298               0.036101
# 5235                       NaN               0.131483
# 23225                 0.038276               0.048154
# 32212                 0.185110               0.178218
# 27758                 0.121550               0.000000
#
#        base_reb_per_min_season_avg  base_ast_per_min_ewm_hl5  \
# 3638                      0.069498                  0.054449
# 14943                     0.171731                  0.070078
# 11127                     0.166964                  0.039440
# 31493                     0.156979                  0.130379
# 67                        0.139407                  0.128976
# 820                       0.076835                  0.112799
# 5235                      0.131483                       NaN
# 23225                     0.051511                  0.129498
# 32212                     0.150281                  0.072364
# 27758                     0.130161                  0.103453
#
#        base_ast_per_min_roll5  base_ast_per_min_ewm_hl10  \
# 3638                 0.076005                   0.051475
# 14943                0.047597                   0.079204
# 11127                0.014052                   0.041452
# 31493                0.136028                   0.133139
# 67                   0.091377                   0.139288
# 820                  0.097691                   0.121276
# 5235                      NaN                        NaN
# 23225                0.121400                   0.117546
# 32212                0.093952                   0.059101
# 27758                0.107594                   0.089493
#
#        base_ast_per_min_roll10  base_ast_per_min_ewm_hl20  \
# 3638                  0.047503                   0.049601
# 14943                 0.062481                   0.084010
# 11127                 0.045043                   0.042119
# 31493                 0.136028                   0.134568
# 67                    0.121273                   0.144597
# 820                   0.113814                   0.125941
# 5235                       NaN                        NaN
# 23225                 0.138450                   0.110217
# 32212                 0.072834                   0.054206
# 27758                 0.087856                   0.083640
#
#        base_ast_per_min_roll20  base_ast_per_min_lag1  \
# 3638                  0.047503               0.000000
# 14943                 0.090955               0.000000
# 11127                 0.042482               0.070258
# 31493                 0.136028               0.090416
# 67                    0.150012               0.214951
# 820                   0.129930               0.072202
# 5235                       NaN               0.043828
# 23225                 0.117430               0.240770
# 32212                 0.048043               0.000000
# 27758                 0.072607               0.344828
#
#        base_ast_per_min_season_avg  base_tov_per_min_ewm_hl5  \
# 3638                      0.047503                  0.007974
# ...
# 67                    14.0            -0.488001                    -0.012673
# 820                   66.3            -1.164645                    -0.033063
# 5235                  22.8                  NaN                          NaN
# 23225                 51.4             1.485922                    -0.018956
# 32212                 21.8            -2.485667                    -0.029439
# 27758                 28.9             0.142437                    -0.005906
#
#        adv_ts_pct_trend_5v20  adv_usg_pct_trend_5v20  \
# 3638                0.000000               -0.000773
# 14943              -0.020796                0.004094
# 11127              -0.010474                0.009990
# 31493               0.005342               -0.001534
# 67                 -0.035862               -0.000446
# 820                -0.037921               -0.005229
# 5235                     NaN                     NaN
# 23225              -0.025560               -0.013379
# 32212               0.003561               -0.008832
# 27758              -0.017048                0.002947
#
#        base_ast_per_min_trend_5v20  base_oreb_per_min_trend_5v20  \
# 3638                      0.004848                      0.000000
# 14943                    -0.013932                     -0.003323
# 11127                    -0.002679                     -0.014207
# 31493                    -0.004189                     -0.000968
# 67                       -0.015621                      0.001216
# 820                      -0.013141                     -0.000925
# 5235                           NaN                           NaN
# 23225                     0.019281                      0.002150
# 32212                     0.018158                      0.003539
# 27758                     0.019814                     -0.006932
#
#        base_dreb_per_min_trend_5v20  team_pts_per_min_rank_l10  \
# 3638                      -0.014851                       11.0
# 14943                     -0.013916                        5.0
# 11127                     -0.004362                        7.0
# 31493                      0.002786                        1.0
# 67                         0.030239                        6.0
# 820                       -0.004430                        8.0
# 5235                            NaN                        NaN
# 23225                     -0.012878                        6.0
# 32212                      0.037699                        7.0
# 27758                     -0.010442                        8.0
#
#        team_ast_per_min_rank_l10  team_oreb_per_min_rank_l10  \
# 3638                         8.0                        11.0
# 14943                        4.0                         4.0
# 11127                        5.0                         3.0
# 31493                        1.0                         6.0
# 67                           1.0                         7.0
# 820                          3.0                         7.0
# 5235                         NaN                         NaN
# 23225                        2.0                         8.0
# 32212                        5.0                         3.0
# 27758                        5.0                         5.0
#
#        team_dreb_per_min_rank_l10  team_ts_pct_rank_l10  \
# 3638                         11.0                  11.0
# 14943                         5.0                   9.0
# 11127                         4.0                   7.0
# 31493                         4.0                   2.0
# 67                            3.0                   8.0
# 820                          10.0                   4.0
# 5235                          NaN                   NaN
# 23225                         9.0                   6.0
# 32212                         5.0                   4.0
# 27758                         5.0                   8.0
#
#        team_usg_pct_rank_l10  team_min_rank_l10  pts_per_min_roll10  \
# 3638                    11.0               11.0            0.000000
# 14943                    3.0                7.0            0.352729
# 11127                    8.0                6.0            0.175266
# 31493                    2.0                2.0            0.554179
# 67                       7.0                4.0            0.272022
# 820                      9.0                4.0            0.214367
# 5235                     NaN                NaN                 NaN
# 23225                    5.0                6.0            0.297817
# 32212                    7.0                8.0            0.282000
# 27758                    4.0                8.0            0.165095
#
#        team_pts_per_min_rank_roll10  minutes_roll5_std  minutes_roll5_var  \
# 3638                           11.0             6.4448            41.5352
# 14943                           5.0             2.5360             6.4313
# 11127                           7.0             4.5136            20.3724
# 31493                           1.0             2.3575             5.5580
# 67                              5.0             7.4072            54.8666
# 820                             9.0             4.9484            24.4868
# 5235                            NaN                NaN                NaN
# 23225                           5.0             7.4885            56.0781
# 32212                           5.0             4.8514            23.5359
# 27758                           8.0             2.9794             8.8769
#
#        minutes_roll10_std  minutes_roll10_var  minutes_roll15_std  \
# 3638               5.0778             25.7845              5.0778
# 14943              4.3739             19.1314              5.8599
# 11127              5.2213             27.2619              4.7254
# 31493              2.3575              5.5580                 NaN
# 67                 6.1567             37.9047              5.5016
# 820                5.4485             29.6864              5.3192
# 5235                  NaN                 NaN                 NaN
# 23225              8.1612             66.6048              9.0118
# 32212              5.1704             26.7333              4.8783
# 27758              3.2908             10.8292              4.7378
#
#        minutes_roll15_var  pts_per_min_roll5_std  pts_per_min_roll5_var  \
# 3638              25.7845                 0.0000                 0.0000
# 14943             34.3390                 0.2810                 0.0790
# 11127             22.3299                 0.1746                 0.0305
# 31493                 NaN                 0.1597                 0.0255
# 67                30.2672                 0.2409                 0.0580
# 820               28.2940                 0.0312                 0.0010
# 5235                  NaN                    NaN                    NaN
# 23225             81.2134                 0.0874                 0.0076
# 32212             23.7980                 0.2306                 0.0532
# 27758             22.4469                 0.1614                 0.0261
#
#        pts_per_min_roll10_std  pts_per_min_roll10_var  pts_per_min_roll15_std  \
# 3638                   0.0000                  0.0000                  0.0000
# 14943                  0.2456                  0.0603                  0.2533
# 11127                  0.1579                  0.0249                  0.1540
# 31493                  0.1597                  0.0255                     NaN
# 67                     0.2668                  0.0712                  0.2323
# 820                    0.1343                  0.0180                  0.1453
# 5235                      NaN                     NaN                     NaN
# 23225                  0.1660                  0.0275                  0.1775
# 32212                  0.2200                  0.0484                  0.2186
# 27758                  0.1798                  0.0323                  0.2420
#
#        pts_per_min_roll15_var  ast_per_min_roll5_std  ast_per_min_roll5_var  \
# 3638                   0.0000                 0.1377                 0.0190
# 14943                  0.0641                 0.0679                 0.0046
# 11127                  0.0237                 0.0314                 0.0010
# 31493                     NaN                 0.0556                 0.0031
# 67                     0.0540                 0.0826                 0.0068
# 820                    0.0211                 0.0466                 0.0022
# 5235                      NaN                    NaN                    NaN
# 23225                  0.0315                 0.0926                 0.0086
# 32212                  0.0478                 0.1757                 0.0309
# 27758                  0.0585                 0.1568                 0.0246
#
#        ast_per_min_roll10_std  ast_per_min_roll10_var  ast_per_min_roll15_std  \
# 3638                   0.1113                  0.0124                  0.1113
# 14943                  0.0621                  0.0039                  0.1173
# 11127                  0.0777                  0.0060                  0.0689
# 31493                  0.0556                  0.0031                     NaN
# 67                     0.0896                  0.0080                  0.0994
# 820                    0.0929                  0.0086                  0.0782
# 5235                      NaN                     NaN                     NaN
# 23225                  0.1042                  0.0109                  0.1057
# 32212                  0.1242                  0.0154                  0.1048
# 27758                  0.1146                  0.0131                  0.1097
#
#        ast_per_min_roll15_var  oreb_per_min_roll5_std  oreb_per_min_roll5_var  \
# 3638                   0.0124                  0.0000                  0.0000
# 14943                  0.0138                  0.0433                  0.0019
# 11127                  0.0047                  0.0491                  0.0024
# 31493                     NaN                  0.0117                  0.0001
# 67                     0.0099                  0.0280                  0.0008
# 820                    0.0061                  0.0266                  0.0007
# 5235                      NaN                     NaN                     NaN
# 23225                  0.0112                  0.0215                  0.0005
# 32212                  0.0110                  0.0453                  0.0021
# 27758                  0.0120                  0.0345                  0.0012
#
#        oreb_per_min_roll10_std  oreb_per_min_roll10_var  \
# 3638                    0.0000                   0.0000
# 14943                   0.0405                   0.0016
# 11127                   0.0592                   0.0035
# 31493                   0.0117                   0.0001
# 67                      0.0336                   0.0011
# 820                     0.0310                   0.0010
# 5235                       NaN                      NaN
# 23225                   0.0194                   0.0004
# 32212                   0.0537                   0.0029
# 27758                   0.0386                   0.0015
#
#        oreb_per_min_roll15_std  oreb_per_min_roll15_var  \
# 3638                    0.0000                   0.0000
# 14943                   0.0682                   0.0047
# 11127                   0.0517                   0.0027
# 31493                      NaN                      NaN
# 67                      0.0301                   0.0009
# 820                     0.0266                   0.0007
# 5235                       NaN                      NaN
# 23225                   0.0162                   0.0003
# 32212                   0.0567                   0.0032
# 27758                   0.0559                   0.0031
#
#        dreb_per_min_roll5_std  dreb_per_min_roll5_var  \
# 3638                   0.0280                  0.0008
# 14943                  0.0731                  0.0053
# 11127                  0.0949                  0.0090
# 31493                  0.0600                  0.0036
# 67                     0.0647                  0.0042
# 820                    0.0318                  0.0010
# 5235                      NaN                     NaN
# 23225                  0.0339                  0.0011
# 32212                  0.0853                  0.0073
# 27758                  0.0538                  0.0029
#
#        dreb_per_min_roll10_std  dreb_per_min_roll10_var  \
# 3638                    0.1727                   0.0298
# 14943                   0.0730                   0.0053
# 11127                   0.0920                   0.0085
# 31493                   0.0600                   0.0036
# 67                      0.0749                   0.0056
# 820                     0.0250                   0.0006
# 5235                       NaN                      NaN
# 23225                   0.0277                   0.0008
# 32212                   0.0971                   0.0094
# 27758                   0.0759                   0.0058
#
#        dreb_per_min_roll15_std  dreb_per_min_roll15_var  \
# 3638                    0.1727                   0.0298
# 14943                   0.0765                   0.0058
# 11127                   0.0966                   0.0093
# 31493                      NaN                      NaN
# 67                      0.0863                   0.0074
# 820                     0.0297                   0.0009
# 5235                       NaN                      NaN
# 23225                   0.0384                   0.0015
# 32212                   0.0921                   0.0085
# 27758                   0.0845                   0.0071
#
#        reb_per_min_roll5_std  reb_per_min_roll5_var  reb_per_min_roll10_std  \
# 3638                  0.0280                 0.0008                  0.1727
# 14943                 0.0834                 0.0070                  0.0844
# 11127                 0.0888                 0.0079                  0.1101
# 31493                 0.0664                 0.0044                  0.0664
# 67                    0.0654                 0.0043                  0.0624
# 820                   0.0453                 0.0021                  0.0472
# 5235                     NaN                    NaN                     NaN
# 23225                 0.0319                 0.0010                  0.0269
# 32212                 0.1071                 0.0115                  0.0885
# 27758                 0.0433                 0.0019                  0.0685
#
#        reb_per_min_roll10_var  reb_per_min_roll15_std  reb_per_min_roll15_var  \
# 3638                   0.0298                  0.1727                  0.0298
# 14943                  0.0071                  0.1228                  0.0151
# 11127                  0.0121                  0.1116                  0.0125
# 31493                  0.0044                     NaN                     NaN
# 67                     0.0039                  0.0816                  0.0067
# 820                    0.0022                  0.0424                  0.0018
# 5235                      NaN                     NaN                     NaN
# 23225                  0.0007                  0.0373                  0.0014
# 32212                  0.0078                  0.1022                  0.0105
# 27758                  0.0047                  0.0685                  0.0047
#
#        starter_roll10_pct
# 3638                  NaN
# 14943                 0.0
# 11127                 0.0
# 31493                 1.0
# 67                    NaN
# 820                   NaN
# 5235                  NaN
# 23225                 0.0
# 32212                 0.0
# 27758                 0.0

# %%
print(f"Total number of duplicates: {df.duplicated(subset=['game_id', 'player_id']).sum()}")
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
df[['minutes', 'pts_per_min', 'ast_per_min', 'reb_per_min']].describe()
# Out:
# Total number of duplicates: 0
# Rows: 39582
# Columns: 722
#             minutes   pts_per_min   ast_per_min   reb_per_min
# count  39582.000000  39580.000000  39580.000000  39580.000000
# mean      21.023363      0.365265      0.089548      0.168043
# std       10.416752      0.270993      0.093807      0.142947
# min        0.000000      0.000000      0.000000      0.000000
# 25%       12.800000      0.176991      0.000000      0.067467
# 50%       21.833333      0.350599      0.071986      0.144052
# 75%       29.833333      0.526010      0.135048      0.240630
# max       52.550000     12.500000      2.469136      2.702703

# %%
# ── Prop-specific config (WNBA MIN) ───────────────────────────────────────────
MIN_FEATURES = [
    "starting",
    "starter_roll10_pct",
    "team_min_rank_l10",
    "team_usg_pct_rank_l10",
    "base_min_season_avg", #new
    "track_minutes_ewm_hl10",
    "adv_usg_pct_ewm_hl10", #new
    "adv_poss_ewm_hl10", #new
    "base_min_trend_5v20",
    "base_min_lag1",
]

HOLDOUT_SEASON = "2026"
ID_COLS = ["game_id", "player_id", "season_year", "player_name", "game_date"]
TARGET_COL = "minutes"
ROLE_COL = "starting"

# Frozen naive baselines for the MIN hypothesis test (leakage-safe).
NAIVE_PRIMARY = "base_min_season_avg"
NAIVE_SECONDARY = "base_min_lag1"
NAIVE_COLS = [NAIVE_PRIMARY, NAIVE_SECONDARY]
ALPHA = 0.05

QUANTILES = [0.10, 0.50, 0.90]

XGB_PARAMS = dict(
    objective="reg:quantileerror",
    n_estimators=1695,
    max_depth=3,
    learning_rate=0.052852647946832816,
    subsample=0.5916232263322159,
    colsample_bytree=0.6284413523882679,
    reg_alpha=0.022871045941195746,
    reg_lambda=2.0960269065270034,
    min_child_weight=8,
    n_jobs=-1,
    random_state=42,
    early_stopping_rounds=50,
)

MIN_TIERS = {
    "<12.8 min": lambda a: a < 12.8,
    "12.8-21.8 min": lambda a: (a >= 12.8) & (a < 21.8),
    "21.8-30 min": lambda a: (a >= 21.8) & (a < 31.5),
    "30+ min": lambda a: a >= 31.5,
}

ARTIFACT_STEM = "min_wnba_model"

# ── Shared train/eval helpers ─────────────────────────────────────────────────
from models.shared.splits import prepare_splits
from models.shared.train import run_timeseries_cv, run_walk_forward, evaluate_holdout
from models.shared.baselines import (
    run_naive_comparison,
    evaluate_holdout_vs_naive,
    run_quantile_linear_baseline,
)
from models.shared.analysis import run_feature_ablation, analyze_correlations
from models.shared.artifacts import save_model_bundle, load_model_bundle, predict_quantiles
from models.shared.metrics import pinball_50

print(f"Number of features: {len(MIN_FEATURES)}")
MIN_FEATURES
# Out:
# Number of features: 10
# ['starting',
#  'starter_roll10_pct',
#  'team_min_rank_l10',
#  'team_usg_pct_rank_l10',
#  'base_min_season_avg',
#  'track_minutes_ewm_hl10',
#  'adv_usg_pct_ewm_hl10',
#  'adv_poss_ewm_hl10',
#  'base_min_trend_5v20',
#  'base_min_lag1']

# %%
df = df[(df['minutes'] > 12)]
print(f"After filtering minutes: {df[MIN_FEATURES].shape[0]} rows")
# Out:
# After filtering minutes: 30427 rows

# %%
splits = prepare_splits(
    df,
    holdout_season=HOLDOUT_SEASON,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    id_cols=ID_COLS,
    role_col=ROLE_COL,
    extra_keep=["minutes"],
)
ppm_df = splits["ppm_df"]
ppm_holdout = splits["ppm_holdout"]
X = splits["X"]
y = splits["y"]
# Out:
# Train pool (excl. 2026) : 27,375 rows
# Holdout   (2026)        : 3,052 rows
# Date range (train)   : 2018-05-18 → 2025-10-10
# Date range (holdout) : 2026-05-08 → 2026-07-22

# %%
# import importlib
# import models.shared.train as train

# importlib.reload(train)
# tune_xgb_quantile = train.tune_xgb_quantile

# result = tune_xgb_quantile(X, y, n_trials=100, n_splits=5)
# XGB_PARAMS = result["best_params"]

# %%
tscv_results = run_timeseries_cv(
    X, y, ppm_df,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    quantiles=QUANTILES,
)
wf = run_walk_forward(
    X, y, ppm_df,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    quantiles=QUANTILES,
)

wf_results = wf["wf_results"]
models_last = wf["models_last"]
preds_last = wf["preds_last"]
X_val_last = wf["X_val_last"]
y_val_last = wf["y_val_last"]
starting_last = wf["starting_last"]
last_fold = wf["last_fold"]
# Out:
# ── Phase 1: TimeSeriesSplit ─────────────────────────────────────────
#
# TSCV fold 1
#   Overall  | n= 4562 | MAE: 4.021 | R²: 0.505 | 80% Coverage: 78.4%
#   Starters   | n= 2994 | MAE: 4.326 | Coverage: 77.4%
#   Bench      | n= 1568 | MAE: 3.438 | Coverage: 80.3%
#   <12.8 min  | n=  111 | MAE: 5.133 | Coverage: 14.4%
#   12.8-21.8 min | n= 1552 | MAE: 4.167 | Coverage: 80.5%
#   21.8-30 min | n= 1846 | MAE: 3.536 | Coverage: 89.1%
#   30+ min    | n= 1053 | MAE: 4.537 | Coverage: 63.2%
#
# TSCV fold 2
#   Overall  | n= 4562 | MAE: 4.103 | R²: 0.505 | 80% Coverage: 78.3%
#   Starters   | n= 3023 | MAE: 4.400 | Coverage: 77.9%
#   Bench      | n= 1539 | MAE: 3.521 | Coverage: 79.0%
#   <12.8 min  | n=  100 | MAE: 5.902 | Coverage: 3.0%
#   12.8-21.8 min | n= 1473 | MAE: 4.264 | Coverage: 79.4%
#   21.8-30 min | n= 1816 | MAE: 3.768 | Coverage: 87.6%
#   30+ min    | n= 1173 | MAE: 4.267 | Coverage: 69.0%
#
# TSCV fold 3
#   Overall  | n= 4562 | MAE: 3.847 | R²: 0.568 | 80% Coverage: 80.7%
#   Starters   | n= 3099 | MAE: 4.038 | Coverage: 81.2%
#   Bench      | n= 1463 | MAE: 3.443 | Coverage: 79.5%
#   <12.8 min  | n=   92 | MAE: 5.226 | Coverage: 7.6%
#   12.8-21.8 min | n= 1390 | MAE: 4.055 | Coverage: 79.9%
#   21.8-30 min | n= 1855 | MAE: 3.526 | Coverage: 89.1%
#   30+ min    | n= 1225 | MAE: 3.993 | Coverage: 74.3%
#
# TSCV fold 4
#   Overall  | n= 4562 | MAE: 3.888 | R²: 0.602 | 80% Coverage: 78.2%
#   Starters   | n= 3170 | MAE: 4.040 | Coverage: 78.6%
#   Bench      | n= 1392 | MAE: 3.542 | Coverage: 77.2%
#   <12.8 min  | n=  106 | MAE: 5.067 | Coverage: 3.8%
#   12.8-21.8 min | n= 1353 | MAE: 4.111 | Coverage: 79.3%
#   21.8-30 min | n= 1640 | MAE: 3.670 | Coverage: 85.9%
#   30+ min    | n= 1463 | MAE: 3.840 | Coverage: 73.9%
#
# TSCV fold 5
#   Overall  | n= 4562 | MAE: 3.931 | R²: 0.526 | 80% Coverage: 80.5%
#   Starters   | n= 3010 | MAE: 4.119 | Coverage: 81.6%
#   Bench      | n= 1552 | MAE: 3.566 | Coverage: 78.3%
#   <12.8 min  | n=  114 | MAE: 5.549 | Coverage: 7.0%
#   12.8-21.8 min | n= 1446 | MAE: 4.142 | Coverage: 80.3%
#   21.8-30 min | n= 1917 | MAE: 3.655 | Coverage: 87.6%
#   30+ min    | n= 1085 | MAE: 3.969 | Coverage: 75.9%
#
# TimeSeriesSplit Summary
#   MAE      : 3.958 ± 0.093
#   R²       : 0.541  ± 0.038
#   Coverage : 79.2% ± 1.1%  (target ~80%)
#
# ── Phase 2: Walk-Forward Validation (date-based) ───────────────────
# Unique game dates in pool : 730
# Training window           : 365 dates (~50%)
# Step size                 : 73 dates (~10%)
#
# WF fold 1  (2022-06-30 → 2023-06-17)
#   Overall  | n= 2617 | MAE: 3.845 | R²: 0.554 | 80% Coverage: 81.1%
#   Starters   | n= 1768 | MAE: 4.052 | Coverage: 81.7%
#   Bench      | n=  849 | MAE: 3.414 | Coverage: 79.7%
#   <12.8 min  | n=   44 | MAE: 5.217 | Coverage: 4.5%
#   12.8-21.8 min | n=  809 | MAE: 3.988 | Coverage: 80.0%
#   21.8-30 min | n= 1081 | MAE: 3.543 | Coverage: 88.8%
#   30+ min    | n=  683 | MAE: 4.066 | Coverage: 75.1%
#
# WF fold 2  (2023-06-17 → 2023-10-01)
#   Overall  | n= 2814 | MAE: 3.922 | R²: 0.581 | 80% Coverage: 77.9%
#   Starters   | n= 1934 | MAE: 4.103 | Coverage: 78.0%
#   Bench      | n=  880 | MAE: 3.523 | Coverage: 77.7%
#   <12.8 min  | n=   67 | MAE: 5.417 | Coverage: 7.5%
#   12.8-21.8 min | n=  845 | MAE: 4.202 | Coverage: 78.1%
#   21.8-30 min | n= 1073 | MAE: 3.580 | Coverage: 88.4%
#   30+ min    | n=  829 | MAE: 3.958 | Coverage: 69.8%
#
# WF fold 3  (2023-10-01 → 2024-08-26)
#   Overall  | n= 2589 | MAE: 3.772 | R²: 0.612 | 80% Coverage: 80.6%
#   Starters   | n= 1789 | MAE: 3.864 | Coverage: 82.3%
#   Bench      | n=  800 | MAE: 3.568 | Coverage: 77.0%
#   <12.8 min  | n=   64 | MAE: 5.066 | Coverage: 4.7%
#   12.8-21.8 min | n=  768 | MAE: 4.080 | Coverage: 79.6%
#   21.8-30 min | n=  954 | MAE: 3.597 | Coverage: 86.9%
#   30+ min    | n=  803 | MAE: 3.583 | Coverage: 80.3%
#
# WF fold 4  (2024-08-26 → 2025-07-06)
#   Overall  | n= 2942 | MAE: 4.032 | R²: 0.560 | 80% Coverage: 77.1%
#   Starters   | n= 1990 | MAE: 4.292 | Coverage: 76.6%
#   Bench      | n=  952 | MAE: 3.487 | Coverage: 78.2%
#   <12.8 min  | n=   73 | MAE: 5.026 | Coverage: 4.1%
#   12.8-21.8 min | n=  945 | MAE: 4.282 | Coverage: 78.3%
#   21.8-30 min | n= 1118 | MAE: 3.755 | Coverage: 85.3%
#   30+ min    | n=  806 | MAE: 4.031 | Coverage: 71.0%
#
# ────────────────────────────────────────────────────────────
# Walk-Forward Summary (4/4 folds)
#   MAE      : 3.893 ± 0.096
#   R²       : 0.577  ± 0.023
#   Coverage : 79.2% ± 1.7%  (target ~80%)
#
# ────────────────────────────────────────────────────────────
# Per-fold coverage breakdown (target 80%):
#   Fold                                            Coverage    Starters       Bench
#   WF fold 1  (2022-06-30 → 2023-06-17)              81.1%      81.7%      79.7%
#   WF fold 2  (2023-06-17 → 2023-10-01)              77.9%      78.0%      77.7%
#   WF fold 3  (2023-10-01 → 2024-08-26)              80.6%      82.3%      77.0%
#   WF fold 4  (2024-08-26 → 2025-07-06)              77.1%      76.6%      78.2%
#
# Per-fold MAE by tier:
#   Fold                                           <12.8 min  12.8-21.8 min  21.8-30 min     30+ min
#   WF fold 1  (2022-06-30 → 2023-06-17)               5.217       3.988       3.543       4.066
#   WF fold 2  (2023-06-17 → 2023-10-01)               5.417       4.202       3.580       3.958
#   WF fold 3  (2023-10-01 → 2024-08-26)               5.066       4.080       3.597       3.583
#   WF fold 4  (2024-08-26 → 2025-07-06)               5.026       4.282       3.755       4.031
#
# MAE over folds (stable = good, rising = model aging):
#   WF fold 1  (2022-06-30 → 2023-06-17)          3.845  ███████████████████
#   WF fold 2  (2023-06-17 → 2023-10-01)          3.922  ███████████████████
#   WF fold 3  (2023-10-01 → 2024-08-26)          3.772  ██████████████████
#   WF fold 4  (2024-08-26 → 2025-07-06)          4.032  ████████████████████

# %% [markdown]
# ### Naive baseline — MIN hypothesis test
#
# **H0:** The minutes model does not predict significantly better than a naive baseline.
# **H1:** The minutes model predicts significantly better than naive.
#
# **Frozen primary naive:** `base_min_season_avg` (season-to-date expanding mean, shift-then-expand — no same-game leakage).
# **Secondary (reported only):** `base_min_lag1` (last-game minutes).
#
# **Decision rule:** on the same player-games, reject H0 if model MAE < naive MAE **and** one-sided Wilcoxon signed-rank on `|y − ŷ|` has p < 0.05 (model errors stochastically smaller).

# %%
naive = run_naive_comparison(
    wf_results,
    ppm_df,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    y_val_last=y_val_last,
    preds_last=preds_last,
    last_fold=last_fold,
    alpha=ALPHA,
)
# Out:
# ── Naive baselines on walk-forward validation folds ─────────────────
#   Primary H0 predictor : base_min_season_avg
#   Secondary (report)   : base_min_lag1
#   Alpha                : 0.05
#
# Primary naive (base_min_season_avg) vs model MAE by fold:
#   Fold                                             Model    Naive     ΔMAE       n
#   WF fold 1  (2022-06-30 → 2023-06-17)             3.845    4.850   -1.005    2514
#   WF fold 2  (2023-06-17 → 2023-10-01)             3.922    4.940   -1.018    2812
#   WF fold 3  (2023-10-01 → 2024-08-26)             3.772    4.803   -1.031    2487
#   WF fold 4  (2024-08-26 → 2025-07-06)             4.032    5.116   -1.085    2826
#
# Secondary naive (base_min_lag1) vs model MAE by fold:
#   Fold                                             Model    Naive     ΔMAE       n
#   WF fold 1  (2022-06-30 → 2023-06-17)             3.845    5.404   -1.559    2514
#   WF fold 2  (2023-06-17 → 2023-10-01)             3.922    5.679   -1.757    2812
#   WF fold 3  (2023-10-01 → 2024-08-26)             3.772    5.272   -1.500    2487
#   WF fold 4  (2024-08-26 → 2025-07-06)             4.032    5.779   -1.748    2826
#
# ────────────────────────────────────────────────────────────
# Walk-forward last-fold hypothesis test (primary naive):
#   n paired        : 2,826
#   MAE model       : 4.025
#   MAE naive       : 5.116
#   ΔMAE (m−n)      : -1.091
#   Wilcoxon p      : 2.258e-47
#   Reject H0?      : YES — model beats naive

# %% [markdown]
# ### Residual Visuals

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error

y_true = y_val_last.values
pred_low = preds_last["q_0.10"]
pred_mid = preds_last["q_0.50"]
pred_high = preds_last["q_0.90"]
preds_plot = {"Q10": pred_low, "Q50": pred_mid, "Q90": pred_high}

fig, axes = plt.subplots(1, 3, figsize=(14, 6), sharex=True, sharey=True)
scatter_metrics = {}

for ax, (name, y_pred) in zip(axes, preds_plot.items()):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    scatter_metrics[name] = {"R2": r2, "MAE": mae}
    ax.scatter(y_true, y_pred, s=12, alpha=0.6, edgecolors="none")
    lims = [0, max(y_true.max(), y_pred.max()) * 1.02]
    ax.plot(lims, lims, "k--", lw=1)
    ax.set_title(f"{name}  |  R²={r2:.3f}  MAE={mae:.2f} min")
    ax.set_xlabel("Actual MIN")
    ax.set_ylabel("Predicted MIN")
    ax.set_aspect("equal", adjustable="box")
    ax.text(
        0.04, 0.96,
        f"R² = {r2:.3f}\nMAE = {mae:.2f}",
        transform=ax.transAxes, ha="left", va="top", fontsize=10,
        bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.85, edgecolor="0.7"),
    )

plt.suptitle(f"Walk-Forward last fold — {last_fold['fold']}", y=1.02)
plt.tight_layout()
plt.show()

print("Per-quantile fit on last validation fold:")
for name, m in scatter_metrics.items():
    print(f"  {name}: R²={m['R2']:+.3f}  MAE={m['MAE']:.3f} min")

print("\nCoverage per quantile (should match quantile value):")
for name, y_pred in preds_plot.items():
    coverage = (y_true <= y_pred).mean()
    q_target = {"Q10": 0.10, "Q50": 0.50, "Q90": 0.90}[name]
    delta = coverage - q_target
    flag = "⚠" if abs(delta) > 0.05 else "✓"
    print(f"  {name}: {coverage:.1%}  (target {q_target:.0%}, delta {delta:+.1%})  {flag}")

interval_width = pred_high - pred_low
print(f"\n80% interval width (Q10→Q90):")
print(f"  mean   : {interval_width.mean():.2f} min")
print(f"  median : {np.median(interval_width):.2f} min")
print(f"  std    : {interval_width.std():.2f} min")

residuals = y_true - pred_mid
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].scatter(pred_mid, residuals, s=12, alpha=0.5, edgecolors="none")
axes[0].axhline(0, color="k", lw=1, linestyle="--")
axes[0].set_xlabel("Predicted MIN (Q50)")
axes[0].set_ylabel("Residual (actual − predicted)")
axes[0].set_title("Residuals vs Predicted")
axes[1].hist(residuals, bins=40, edgecolor="none")
axes[1].axvline(0, color="k", lw=1, linestyle="--")
axes[1].set_xlabel("Residual")
axes[1].set_title("Residual Distribution")
plt.tight_layout()
plt.show()

print(f"\nResidual summary:")
print(f"  mean bias : {residuals.mean():+.3f} min  (close to 0 = unbiased)")
print(f"  std       : {residuals.std():.3f} min")

starting_last = ppm_df.loc[X_val_last.index, "starting"].values
print("\nResiduals by role:")
for role, mask in [("Starters", starting_last == 1), ("Bench", starting_last == 0)]:
    if mask.sum() == 0:
        continue
    r = residuals[mask]
    print(f"  {role:10s} | n={mask.sum():5d} | bias={r.mean():+.3f} | std={r.std():.3f}")

print("\nResiduals by minutes tier:")
for tier, fn in MIN_TIERS.items():
    mask = fn(y_true)
    if mask.sum() == 0:
        continue
    r = residuals[mask]
    print(f"  {tier:10s} | n={mask.sum():5d} | bias={r.mean():+.3f} | std={r.std():.3f}")
# Out:
# Per-quantile fit on last validation fold:
#   Q10: R²=-0.153  MAE=6.859 min
#   Q50: R²=+0.560  MAE=4.032 min
#   Q90: R²=-0.113  MAE=6.699 min
#
# Coverage per quantile (should match quantile value):
#   Q10: 11.9%  (target 10%, delta +1.9%)  ✓
#   Q50: 50.0%  (target 50%, delta +0.0%)  ✓
#   Q90: 89.0%  (target 90%, delta -1.0%)  ✓
#
# 80% interval width (Q10→Q90):
#   mean   : 12.60 min
#   median : 12.38 min
#   std    : 2.15 min
# Residual summary:
#   mean bias : -0.209 min  (close to 0 = unbiased)
#   std       : 5.107 min
#
# Residuals by role:
#   Starters   | n= 1990 | bias=-0.550 | std=5.382
#   Bench      | n=  952 | bias=+0.503 | std=4.393
#
# Residuals by minutes tier:
#   <12.8 min  | n=   73 | bias=-5.026 | std=1.976
#   12.8-21.8 min | n=  945 | bias=-3.290 | std=4.558
#   21.8-30 min | n= 1118 | bias=-0.100 | std=4.677
#   30+ min    | n=  806 | bias=+3.688 | std=3.422

# %%
import shap

for q_key, model in models_last.items():
    explainer = shap.TreeExplainer(model, model_output="raw")
    shap_values = explainer(X_val_last)
    print(f"\n── {q_key} ──")
    shap.plots.beeswarm(shap_values, max_display=30, show=False)
    plt.title(f"SHAP beeswarm — {q_key}")
    plt.tight_layout()
    plt.show()
# Out:
# ── q_0.10 ──
# ── q_0.50 ──
# ── q_0.90 ──

# %%
model = models_last["q_0.50"]
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_val_last)

mean_abs_shap = np.abs(shap_values.values).mean(axis=0)
feat_imp = pd.Series(mean_abs_shap, index=MIN_FEATURES).sort_values(ascending=True)

ax = feat_imp.plot(kind="barh", figsize=(8, 6))
ax.set_title("Mean |SHAP| — q_0.50")
ax.set_xlabel("Mean absolute SHAP value")
plt.tight_layout()
plt.show()

# %%
from sklearn.inspection import permutation_importance
from sklearn.metrics import make_scorer
from scipy import stats as sp_stats

result = permutation_importance(
    models_last["q_0.50"],
    X_val_last,
    y_val_last,
    n_repeats=30,
    random_state=42,
    scoring=make_scorer(pinball_50),
)

pi_df = (
    pd.DataFrame({
        "feature": X_val_last.columns,
        "importance": result.importances_mean,
        "std": result.importances_std,
    })
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)
pi_df.index += 1
pi_df["importance"] = pi_df["importance"].round(5)
pi_df["std"] = pi_df["std"].round(5)
pi_df["p_value"] = sp_stats.ttest_1samp(result.importances, 0.0, axis=1).pvalue.round(4)
pi_df["significant"] = pi_df["p_value"] < 0.05

print("Permutation importance (val set) — higher = more important, significant = p<0.05")
print(pi_df.to_string())
# Out:
# Permutation importance (val set) — higher = more important, significant = p<0.05
#                    feature  importance      std  p_value  significant
# 1                 starting     0.71854  0.02544      0.0         True
# 2      base_min_season_avg     0.16392  0.01086      0.0         True
# 3   track_minutes_ewm_hl10     0.11148  0.01000      0.0         True
# 4            base_min_lag1     0.09358  0.01054      0.0         True
# 5       starter_roll10_pct     0.06432  0.00906      0.0         True
# 6        team_min_rank_l10     0.06238  0.00656      0.0         True
# 7      base_min_trend_5v20     0.03026  0.00571      0.0         True
# 8        adv_poss_ewm_hl10     0.02564  0.00503      0.0         True
# 9    team_usg_pct_rank_l10     0.01016  0.00372      0.0         True
# 10    adv_usg_pct_ewm_hl10     0.00399  0.00196      0.0         True

# %%
train_mask_last = last_fold["train_mask"]
val_mask_last = last_fold["val_mask"]
X_tr_last = X[train_mask_last]
X_va_last = X[val_mask_last]
y_tr_last = y[train_mask_last]
y_va_last = y[val_mask_last]

ablation_df = run_feature_ablation(
    MIN_FEATURES, X_tr_last, y_tr_last, X_va_last, y_va_last,
    xgb_params=XGB_PARAMS,
)
# Out:
# Baseline RMSE (all features): 5.1112
#                    feature  ablated_rmse  delta_rmse
# 1                 starting        5.4445      0.3333
# 2       starter_roll10_pct        5.1441      0.0330
# 3      base_min_trend_5v20        5.1379      0.0267
# 4      base_min_season_avg        5.1345      0.0233
# 5        team_min_rank_l10        5.1308      0.0196
# 6    team_usg_pct_rank_l10        5.1264      0.0152
# 7            base_min_lag1        5.1239      0.0128
# 8   track_minutes_ewm_hl10        5.1184      0.0072
# 9        adv_poss_ewm_hl10        5.1132      0.0021
# 10    adv_usg_pct_ewm_hl10        5.1127      0.0015

# %%
from scipy import stats

model = models_last["q_0.50"]
_shap_expl = shap.TreeExplainer(model, model_output="raw")
_shap_vals = _shap_expl(X_val_last)
_mean_abs_shap = np.abs(_shap_vals.values).mean(axis=0)

shap_table = pd.DataFrame({
    "feature": X_val_last.columns,
    "mean_abs_shap": _mean_abs_shap,
}).assign(shap_rank=lambda d: d["mean_abs_shap"].rank(method="min", ascending=False).astype(int))

perm_table = (
    pi_df.sort_values("importance", ascending=False)
    .reset_index(drop=True)
    .rename(columns={"importance": "perm_importance", "std": "perm_importance_std"})
)
perm_table["perm_rank"] = np.arange(1, len(perm_table) + 1)
perm_table = perm_table[["feature", "perm_rank", "perm_importance", "perm_importance_std"]]

perm_pv = pd.DataFrame({
    "feature": X_val_last.columns,
    "perm_pvalue": stats.ttest_1samp(result.importances, 0.0, axis=1, nan_policy="omit").pvalue,
})

abla = ablation_df[["feature", "delta_rmse"]].rename(columns={"delta_rmse": "ablation_delta"})

feature_audit = (
    pd.DataFrame({"feature": MIN_FEATURES})
    .merge(shap_table, on="feature", how="left")
    .merge(perm_table, on="feature", how="left")
    .merge(perm_pv, on="feature", how="left")
    .merge(abla, on="feature", how="left")
)

_ms = feature_audit["mean_abs_shap"].astype(float)
_mp = feature_audit["perm_importance"].astype(float)
_max_shap = _ms.fillna(0).max()
_max_perm = _mp.fillna(0).max()
feature_audit["shap_norm"] = np.where(_max_shap > 0, _ms.fillna(0) / _max_shap, 0.0)
feature_audit["perm_norm"] = np.where(_max_perm > 0, _mp.fillna(0) / _max_perm, 0.0)
feature_audit["consensus"] = (feature_audit["shap_norm"] + feature_audit["perm_norm"]) / 2
feature_audit = feature_audit.sort_values("consensus", ascending=False).reset_index(drop=True)
feature_audit.index += 1
feature_audit["keep"] = (feature_audit["perm_pvalue"] < 0.05) & (feature_audit["ablation_delta"] > 0)

print(feature_audit.to_string())
# Out:
#                    feature  mean_abs_shap  shap_rank  perm_rank  perm_importance  perm_importance_std   perm_pvalue  ablation_delta  shap_norm  perm_norm  consensus  keep
# 1                 starting       3.096754          1          1          0.71854              0.02544  1.214348e-43          0.3333   1.000000   1.000000   1.000000  True
# 2      base_min_season_avg       1.213447          2          2          0.16392              0.01086  9.130228e-36          0.0233   0.391845   0.228129   0.309987  True
# 3   track_minutes_ewm_hl10       1.017183          3          3          0.11148              0.01000  5.558949e-32          0.0072   0.328467   0.155148   0.241808  True
# 4            base_min_lag1       0.849394          4          4          0.09358              0.01054  3.827444e-29          0.0128   0.274285   0.130236   0.202261  True
# 5       starter_roll10_pct       0.588357          5          5          0.06432              0.00906  2.309952e-26          0.0330   0.189991   0.089515   0.139753  True
# 6        team_min_rank_l10       0.493022          6          6          0.06238              0.00656  5.409732e-30          0.0196   0.159206   0.086815   0.123011  True
# 7      base_min_trend_5v20       0.369414          7          7          0.03026              0.00571  8.778559e-23          0.0267   0.119291   0.042113   0.080702  True
# 8        adv_poss_ewm_hl10       0.297657          8          8          0.02564              0.00503  2.681715e-22          0.0021   0.096119   0.035683   0.065901  True
# 9    team_usg_pct_rank_l10       0.252702          9          9          0.01016              0.00372  5.428335e-15          0.0152   0.081602   0.014140   0.047871  True
# 10    adv_usg_pct_ewm_hl10       0.104286         10         10          0.00399              0.00196  7.568495e-12          0.0015   0.033676   0.005553   0.019614  True

# %%
correlated_features = analyze_correlations(
    df, MIN_FEATURES, title="Feature Correlation Matrix — WNBA MIN"
)
correlated_features
# Out:
# --- High Correlation Report (Threshold > 0.95) ---
# adv_poss_ewm_hl10 <-> track_minutes_ewm_hl10: 0.9953
# track_minutes_ewm_hl10 <-> base_min_season_avg: 0.9919
# adv_poss_ewm_hl10 <-> base_min_season_avg: 0.9893
# ['track_minutes_ewm_hl10', 'adv_poss_ewm_hl10']

# %%
holdout = evaluate_holdout(
    ppm_df,
    ppm_holdout,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    xgb_params=XGB_PARAMS,
    role_col=ROLE_COL,
    tiers=MIN_TIERS,
    wf_results=wf_results,
    quantiles=QUANTILES,
    fold_label=f"{HOLDOUT_SEASON} Blind Holdout",
)
models_ho = holdout["models_ho"]
preds_ho = holdout["preds_ho"]
ho_metrics = holdout["ho_metrics"]
X_ho = holdout["X_ho"]
y_ho = holdout["y_ho"]
# Out:
# ── 2026 Blind Holdout ─────────────────────────────────────────────────
#   Train pool: 90% rows for fit, remainder for early-stopping only; predict holdout (never in eval_set).
#
# 2026 Blind Holdout
#   Overall  | n= 3052 | MAE: 3.573 | R²: 0.587 | 80% Coverage: 84.5%
#   Starters   | n= 1985 | MAE: 3.755 | Coverage: 85.9%
#   Bench      | n= 1067 | MAE: 3.236 | Coverage: 82.0%
#   <12.8 min  | n=   83 | MAE: 5.136 | Coverage: 2.4%
#   12.8-21.8 min | n= 1068 | MAE: 3.751 | Coverage: 84.8%
#   21.8-30 min | n= 1295 | MAE: 3.230 | Coverage: 91.8%
#   30+ min    | n=  606 | MAE: 3.780 | Coverage: 79.7%
#
# ───────────────────────────────────────────────────────
#   Walk-forward MAE (mean)  : 3.893
#   Holdout MAE              : 3.573
#   Gap                      : -0.319  ✓ acceptable
#
# Holdout quantile calibration (should match target):
#   q_0.10 | actual coverage: 9.0%  target: 10%  delta: -1.0%  ✓
#   q_0.50 | actual coverage: 54.5%  target: 50%  delta: +4.5%  ✓
#   q_0.90 | actual coverage: 93.6%  target: 90%  delta: +3.6%  ✓
#
# Holdout 80% interval width (Q10→Q90):
#   mean: 12.86  |  median: 12.70  |  std: 2.05

# %%
naive_holdout_results = evaluate_holdout_vs_naive(
    ppm_holdout,
    preds_ho,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    naive_secondary=NAIVE_SECONDARY,
    naive_wf_primary=naive["naive_wf_primary"],
    wf_test_primary=naive["wf_test_primary"],
    alpha=ALPHA,
    holdout_label=f"{HOLDOUT_SEASON} holdout",
)
# Out:
# ───────────────────────────────────────────────────────
# 2026 holdout — model vs frozen naive baselines
#   H0: model does not beat naive | H1: model beats naive (α=0.05)
#
#   PRIMARY (base_min_season_avg)
#     n paired   : 2,899
#     MAE model  : 3.560
#     MAE naive  : 4.353
#     ΔMAE (m−n) : -0.793
#     Wilcoxon p : 1.797e-32
#     Decision   : REJECT H0 — model significantly better
#
#   secondary (base_min_lag1)
#     n paired   : 2,899
#     MAE model  : 3.560
#     MAE naive  : 5.086
#     ΔMAE (m−n) : -1.525
#     Wilcoxon p : 3.649e-82
#     Decision   : REJECT H0 — model significantly better

# %% [markdown]
# ### Complexity ladder — naive → linear quantile → XGB
#
# Report-only baseline (not shipped). Same `MIN_FEATURES` and walk-forward / holdout masks as XGB.
#
# - **Linear:** `SimpleImputer(median)` → `StandardScaler` → `QuantileRegressor` (Q10/Q50/Q90)
# - Pairwise Wilcoxon on |error|: linear vs naive, XGB vs linear (α = 0.05)
# - Authoritative decision remains XGB vs frozen naive on holdout; this ladder answers “does nonlinearity buy anything?”

# %%
linear = run_quantile_linear_baseline(
    X, y, ppm_df,
    holdout_df=ppm_holdout,
    wf_results=wf_results,
    features=MIN_FEATURES,
    target_col=TARGET_COL,
    naive_primary=NAIVE_PRIMARY,
    xgb_preds_last=preds_last,
    xgb_preds_ho=preds_ho,
    last_fold=last_fold,
    role_col=ROLE_COL,
    quantiles=QUANTILES,
    alpha=ALPHA,
    holdout_label=f"{HOLDOUT_SEASON} holdout",
)
# Out:
# ── Quantile linear baseline (report-only) ───────────────────────────
#   Features : 10
#   Quantiles: [0.1, 0.5, 0.9]
#   L1 alpha : 0.0
#
# Three-way MAE by walk-forward fold:
#   Fold                                             Naive   Linear      XGB     ΔL−N     ΔX−L    Cov80
#   WF fold 1  (2022-06-30 → 2023-06-17)             4.850    3.897    3.845   -0.953   -0.052   82.7%
#   WF fold 2  (2023-06-17 → 2023-10-01)             4.940    3.969    3.922   -0.971   -0.048   79.6%
#   WF fold 3  (2023-10-01 → 2024-08-26)             4.803    3.908    3.772   -0.895   -0.136   81.0%
#   WF fold 4  (2024-08-26 → 2025-07-06)             5.116    4.140    4.032   -0.976   -0.108   78.3%
#
# ────────────────────────────────────────────────────────────
# Walk-forward last-fold pairwise tests:
#   WF last fold: linear vs naive
#     MAE challenger=4.130  baseline=5.116  Δ=-0.986  p=7.95e-35  REJECT
#   WF last fold: XGB vs linear
#     MAE challenger=4.032  baseline=4.140  Δ=-0.108  p=5.043e-07  REJECT
#
# Linear | 2026 holdout
#   Overall  | n= 3052 | MAE: 3.721 | R²: 0.559 | 80% Coverage: 84.3%
#   Starters   | n= 1985 | MAE: 3.876 | Coverage: 85.3%
#   Bench      | n= 1067 | MAE: 3.433 | Coverage: 82.6%
#   10-20 min  | n=  925 | MAE: 4.171 | Coverage: 76.1%
#   20-30 min  | n= 1319 | MAE: 3.559 | Coverage: 90.7%
#   30+ min    | n=  808 | MAE: 3.471 | Coverage: 83.4%
#
# 2026 holdout three-way MAE:
#   Naive  : 4.353
#   Linear : 3.721  (cov80=84.3%)
#   XGB    : 3.573
#
# 2026 holdout pairwise tests:
#   2026 holdout: linear vs naive
#     MAE challenger=3.690  baseline=4.353  Δ=-0.663  p=9.995e-22  REJECT
#   2026 holdout: XGB vs linear
#     MAE challenger=3.573  baseline=3.721  Δ=-0.148  p=2.137e-12  REJECT

# %%
from sklearn.metrics import mean_absolute_error

save_path = save_model_bundle(
    models_ho,
    train_df=ppm_df,
    holdout_df=ppm_holdout,
    wf_results=wf_results,
    ho_metrics=ho_metrics,
    features=MIN_FEATURES,
    artifact_stem=ARTIFACT_STEM,
    naive_holdout_results=naive_holdout_results,
)

bundle = load_model_bundle(save_path)
models_loaded = bundle["quantile_models"]
feature_names = bundle["feature_names"]

test_preds = models_loaded["q_0.50"].predict(X_ho)
print(f"Loaded model MAE (holdout): {mean_absolute_error(y_ho, test_preds):.3f}")
print(f"Trained on data up to      : {bundle['train_end'].date()}")
print(f"Holdout through            : {bundle['val_end'].date()}")

predict_quantiles(models_loaded, feature_names, X_ho.head(3))
# Out:
# Saved to /Users/alexgonzalez/Documents/NBA-Prop-Predictor/models/saved_models/min_wnba_model_2026-07-22.joblib
# Loaded /Users/alexgonzalez/Documents/NBA-Prop-Predictor/models/saved_models/min_wnba_model_2026-07-22.joblib
# Loaded model MAE (holdout): 3.569
# Trained on data up to      : 2025-10-10
# Holdout through            : 2026-07-22
#          q10        q50        q90
# 0  13.161235  18.279322  26.113043
# 1  18.729353  27.521181  34.685413
# 2  13.161235  18.279322  26.113043
