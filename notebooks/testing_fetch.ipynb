# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
import sys
import os
from sklearn.preprocessing import LabelEncoder


project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.utils.nbaPlayerLogs import NBAGameLogs
from src.features.feature_engineer.pbp_features import *

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Fetches Player Gamelogs

# %%
os.chdir(project_root)
from src.utils.bronze import fetch_boxscoreplayertrackv3

fetch_boxscoreplayertrackv3(
    "2022-23",
    "Regular Season",
    batch_size=100,
    delay=2.5,
    workers=5
)
# Out:
# fetch_boxscoreplayertrackv3 — 1,230 games (2022-23 Regular Season)
#   checkpoint — 3,941/1,230 done, 1,230 remaining
#
# ── batch 1/13 (100 games) ──
#   … 25/100 games in batch
#   … 50/100 games in batch
#   … 75/100 games in batch
#   … 100/100 games in batch
#     … 2,592/2,592 rows
#   ✓ raw.start_positions — 2,592 rows upserted (postgres)
#   ✓ batch 1 — checkpoint saved (106,762 rows total)
#
# ── batch 2/13 (100 games) ──
#   … 25/100 games in batch
#   … 50/100 games in batch
#   … 75/100 games in batch
#   … 100/100 games in batch
#     … 2,588/2,588 rows
#   ✓ raw.start_positions — 2,588 rows upserted (postgres)
#   ✓ batch 2 — checkpoint saved (109,350 rows total)
#
# ── batch 3/13 (100 games) ──
#   … 25/100 games in batch
#   … 50/100 games in batch
#   … 75/100 games in batch
#   … 100/100 games in batch
#     … 2,547/2,547 rows
#   ✓ raw.start_positions — 2,547 rows upserted (postgres)
#   ✓ batch 3 — checkpoint saved (111,897 rows total)
#
# ...
