# %%
import pandas as pd
import numpy as np
import warnings
import joblib
import json
from pathlib import Path
import sys, os
from datetime import datetime
from glob import glob

project_root = Path.cwd()
while not (project_root / "src").exists():
    project_root = project_root.parent
project_root_str = str(project_root)
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)
os.chdir(project_root_str)

from src.utils.team_info import nameDict
from src.utils.arbitrage import * 
from src.utils.ev_betting import *

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
np.random.seed(42)

today = datetime.today().strftime('%Y%m%d')  
current_date = datetime.now().strftime('%Y-%m-%d')

print("Setup complete.")
print(f"Date: {current_date}")
# Out:
# Setup complete.
# Date: 2026-04-20

# %%
def get_latest_file(pattern):
    files = list(Path('data/raw/player_lines').glob(pattern))
    if not files:
        return None
    return max(files, key=lambda p: p.stat().st_mtime)

nba_us_file = get_latest_file(f'NBA_US_{today}*.csv')

# %%
def get_latest_file(pattern):
    files = list(Path('data/raw/mlb_player_lines').glob(pattern))
    if not files:
        return None
    return max(files, key=lambda p: p.stat().st_mtime)

mlb_us_file = get_latest_file(f'MLB_US_{today}*.csv')

# %%
def get_latest_file(pattern):
    files = list(Path('data/raw/afl_player_lines').glob(pattern))
    if not files:
        return None
    return max(files, key=lambda p: p.stat().st_mtime)

afl_us_file = get_latest_file(f'AFL_AU_{today}*.csv')

# %%
def get_latest_file(pattern):
    files = list(Path('data/raw/soccer_player_lines').glob(pattern))
    if not files:
        return None
    return max(files, key=lambda p: p.stat().st_mtime)

soccer_us_file = get_latest_file(f'SOCCER_US_{today}*.csv')

# %%
def get_latest_file(pattern):
    files = list(Path('data/raw/team_lines').glob(pattern))
    return max(files, key=lambda f: f.stat().st_mtime) if files else None

file = get_latest_file('NBA_*.json')
if file is None:
    raise ValueError("No JSON file found")

# try normal load first
try:
    team_dds = pd.read_json(file)
except ValueError:
    # fallback for nested JSON
    import json
    with open(file) as f:
        data = json.load(f)
    team_dds = pd.json_normalize(data)

print("Loaded:", file.name)
team_dds.head()
# Out:
# Loaded: NBA_20260420_132933.json
#              home_team               away_team             commence_time  \
# 0  Cleveland Cavaliers         Toronto Raptors 2026-04-20 23:10:00+00:00
# 1      New York Knicks           Atlanta Hawks 2026-04-21 00:10:00+00:00
# 2       Denver Nuggets  Minnesota Timberwolves 2026-04-21 02:40:00+00:00
# 3       Boston Celtics      Philadelphia 76ers 2026-04-21 23:10:00+00:00
# 4    San Antonio Spurs  Portland Trail Blazers 2026-04-22 00:00:00+00:00
#
#                                           bookmakers
# 0  [{'bookmaker': 'DraftKings', 'last_updated': '...
# 1  [{'bookmaker': 'DraftKings', 'last_updated': '...
# 2  [{'bookmaker': 'DraftKings', 'last_updated': '...
# 3  [{'bookmaker': 'DraftKings', 'last_updated': '...
# 4  [{'bookmaker': 'FanDuel', 'last_updated': '202...

# %%
nba_prop_arbs = scan_player_props(nba_us_file) if nba_us_file is not None else []
team_arbs = scan_team_odds(team_dds)

nba_all_arbs = pd.DataFrame(nba_prop_arbs + team_arbs).sort_values("margin_%", ascending=False) \
    if (nba_prop_arbs or team_arbs) else pd.DataFrame()

print(f"Player prop arbs: {len(nba_prop_arbs)} | Team odds arbs: {len(team_arbs)}")
nba_all_arbs.head(5)
# Out:
# Player prop arbs: 26 | Team odds arbs: 0
#     type                                             market  \
# 13  prop  Jordan Goodwin player_points_rebounds_assists ...
# 25  prop         Toumani Camara player_rebounds_assists 5.5
# 12  prop         Jordan Goodwin player_points_rebounds 13.5
# 23  prop          Mark Williams player_rebounds_assists 7.5
# 15  prop               Josh Hart player_points_assists 15.5
#
#                   side_a                 side_b  margin_%  stake_a  stake_b  \
# 13  Over @ BetMGM (-115)  Under @ Bovada (+150)     6.512    57.21    42.79
# 25  Over @ BetMGM (-150)  Under @ Bovada (+180)     4.286    62.69    37.31
# 12  Over @ BetMGM (-120)  Under @ Bovada (+140)     3.788    56.69    43.31
# 23  Over @ BetMGM (-120)  Under @ Bovada (+135)     2.901    56.18    43.82
# 15  Over @ BetMGM (-105)  Under @ Bovada (+115)     2.269    52.41    47.59
#
#     profit
# 13    6.97
# 25    4.48
# 12    3.94
# 23    2.99
# 15    2.32

# %%
mlb_prop_arbs = scan_player_props(mlb_us_file) if mlb_us_file is not None else []

mlb_all_arbs = pd.DataFrame(mlb_prop_arbs + team_arbs).sort_values("margin_%", ascending=False) \
    if (mlb_prop_arbs or team_arbs) else pd.DataFrame()

print(f"Player prop arbs: {len(mlb_prop_arbs)}")
mlb_all_arbs
# Out:
# Player prop arbs: 17
#     type                                  market                      side_a  \
# 2   prop  Emmet Sheehan pitcher_hits_allowed 4.5  Over @ BetOnline.ag (+110)
# 15  prop   Shohei Ohtani batter_stolen_bases 0.5        Over @ Bovada (+475)
# 8   prop           JJ Wetherholt batter_hits 0.5        Over @ BetMGM (-135)
# 0   prop   Chase DeLauter batter_runs_scored 0.5        Over @ BetMGM (+275)
# 1   prop         Eloy Jimenez batter_singles 0.5    Over @ DraftKings (+112)
# 10  prop             Myles Straw batter_hits 0.5        Over @ BetMGM (-120)
# 9   prop           Mickey Moniak batter_hits 0.5  Over @ BetOnline.ag (-156)
# 7   prop            Ivan Herrera batter_hits 0.5        Over @ BetMGM (-160)
# 6   prop  Freddie Freeman batter_total_bases 1.5        Over @ BetMGM (-120)
# 11  prop            Ozzie Albies batter_hits 1.5     Over @ BetRivers (+265)
# 4   prop        Ernie Clement batter_doubles 0.5    Over @ DraftKings (+374)
# 16  prop             Trea Turner batter_hits 1.5     Over @ BetRivers (+275)
# 12  prop    Ozzie Albies batter_stolen_bases 0.5       Over @ Bovada (+1200)
# 3   prop    Emmet Sheehan pitcher_strikeouts 6.5     Over @ BetRivers (+123)
# 13  prop        Shohei Ohtani batter_doubles 0.5        Over @ BetMGM (+250)
# 14  prop           Shohei Ohtani batter_hits 1.5        Over @ BetMGM (+135)
# 5   prop  Ezequiel Duran batter_stolen_bases 0.5       Over @ FanDuel (+880)
#
#                          side_b  margin_%  stake_a  stake_b  profit
# 2         Under @ BetMGM (+115)     5.869     5.06     4.94    0.62
# 15    Under @ DraftKings (-372)     3.795     1.81     8.19    0.39
# 8   Under @ BetOnline.ag (+148)     2.231     5.88     4.12    0.23
# 0     Under @ DraftKings (-248)     2.069     2.72     7.28    0.21
# 1         Under @ BetMGM (-105)     1.611     4.79     5.21    0.16
# 10    Under @ DraftKings (+128)     1.595     5.54     4.46    0.16
# 9         Under @ BetMGM (+165)     1.327     6.18     3.82    0.13
# 7   Under @ BetOnline.ag (+169)     1.287     6.23     3.77    0.13
# 6     Under @ DraftKings (+126)     1.207     5.52     4.48    0.12
# 11        Under @ BetMGM (-250)     1.174     2.77     7.23    0.12
# 4         Under @ BetMGM (-350)     1.125     2.13     7.87    0.11
# 16  Under @ BetOnline.ag (-263)     0.882     2.69     7.31    0.09
# 12   Under @ DraftKings (-1080)     0.782     0.78     9.22    0.08
# 3         Under @ BetMGM (-120)     0.611     4.51     5.49    0.06
# 13        Under @ Bovada (-245)     0.414     2.87     7.13    0.04
# 14    Under @ DraftKings (-134)     0.182     4.26     5.74    0.02
# 5     Under @ DraftKings (-870)     0.105     1.02     8.98    0.01

# %%
afl_prop_arbs = scan_player_props(afl_us_file) if afl_us_file is not None else []

afl_all_arbs = pd.DataFrame(afl_prop_arbs).sort_values("margin_%", ascending=False) \
    if (afl_prop_arbs or team_arbs) else pd.DataFrame()

print(f"Player prop arbs: {len(afl_prop_arbs)}")
afl_all_arbs
# Out:
# Player prop arbs: 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
soccer_prop_arbs = scan_player_props(soccer_us_file) if soccer_us_file is not None else []

soccer_all_arbs = pd.DataFrame(soccer_prop_arbs).sort_values("margin_%", ascending=False) \
    if (soccer_prop_arbs or team_arbs) else pd.DataFrame()

print(f"Player prop arbs: {len(soccer_prop_arbs)}")
soccer_all_arbs
# Out:
# Player prop arbs: 9
#    type                                           market  \
# 8  prop           Yeremi Pino player_shots_on_target 0.5
# 1  prop          Daniel Munoz player_shots_on_target 0.5
# 2  prop  Jean-Philippe Mateta player_shots_on_target 1.5
# 6  prop         Morgan Rogers player_shots_on_target 0.5
# 7  prop         Ollie Watkins player_shots_on_target 1.5
# 4  prop           John McGinn player_shots_on_target 0.5
# 0  prop                  Bernardo Silva player_shots 1.5
# 5  prop                      Matty Cash player_shots 1.5
# 3  prop           Jeremy Doku player_shots_on_target 0.5
#
#                     side_a                       side_b  margin_%  stake_a  \
# 8  Over @ BetRivers (+165)  Under @ BetOnline.ag (+110)    14.645     4.42
# 1  Over @ BetRivers (+260)  Under @ BetOnline.ag (-179)     8.065     3.02
# 2  Over @ BetRivers (+210)  Under @ BetOnline.ag (-175)     4.106     3.36
# 6  Over @ BetRivers (-159)  Under @ BetOnline.ag (+175)     2.246     6.28
# 7  Over @ BetRivers (+220)  Under @ BetOnline.ag (-200)     2.083     3.19
# 4  Over @ BetRivers (+190)  Under @ BetOnline.ag (-175)     1.881     3.51
# 0  Over @ BetRivers (+300)  Under @ BetOnline.ag (-278)     1.455     2.54
# 5  Over @ BetRivers (+225)  Under @ BetOnline.ag (-217)     0.777     3.10
# 3  Over @ BetRivers (+155)  Under @ BetOnline.ag (-152)     0.467     3.94
#
#    stake_b  profit
# 8     5.58    1.72
# 1     6.98    0.88
# 2     6.64    0.43
# 6     3.72    0.23
# 7     6.81    0.21
# 4     6.49    0.19
# 0     7.46    0.15
# 5     6.90    0.08
# 3     6.06    0.05

# %%
ev_bets = scan_plus_ev(
    team_file=None,
    props_file=nba_us_file,
    bankroll=1000,
    min_ev=2.0,      # only show bets with >2% EV
)
print_ev_results(ev_bets, bankroll=100)
# Out:
# ============================================================
#   +EV SCANNER  |  bankroll=$100
# ============================================================
#   +EV bets found: 39
#
# [PROP] LeBron James — player_assists Under 8.5
#   Book: Bovada  |  Odds: +140
#   True prob: 45.2%  vs  Implied: 41.7%
#   EV: +8.37%  |  Kelly stake: $14.95
#
# [PROP] Marcus Smart — player_points Under 10.5
#   Book: Bovada  |  Odds: +145
#   True prob: 44.1%  vs  Implied: 40.8%
#   EV: +8.0%  |  Kelly stake: $13.79
#
# [PROP] Stephon Castle — player_threes Over 1.5
#   Book: BetMGM  |  Odds: +130
#   True prob: 46.9%  vs  Implied: 43.5%
#   EV: +7.96%  |  Kelly stake: $15.31
#
# [PROP] Jakob Poeltl — player_points_rebounds_assists Over 16.5
#   Book: BetMGM  |  Odds: +105
#   True prob: 52.3%  vs  Implied: 48.8%
#   EV: +7.14%  |  Kelly stake: $17.01
#
# [PROP] Keldon Johnson — player_points Under 9.5
#   Book: Bovada  |  Odds: +115
#   True prob: 49.7%  vs  Implied: 46.5%
#   EV: +6.95%  |  Kelly stake: $15.1
#
# [PROP] Toumani Camara — player_assists Under 1.5
#   Book: Bovada  |  Odds: +145
#   True prob: 43.5%  vs  Implied: 40.8%
#   EV: +6.51%  |  Kelly stake: $11.23
#
# [PROP] Dillon Brooks — player_threes Under 1.5
#   Book: Bovada  |  Odds: +165
#   True prob: 40.2%  vs  Implied: 37.7%
#   EV: +6.46%  |  Kelly stake: $9.79
#
# [PROP] OG Anunoby — player_assists Under 1.5
#   Book: Bovada  |  Odds: +130
#   True prob: 46.1%  vs  Implied: 43.5%
#   EV: +5.99%  |  Kelly stake: $11.52
#
# [PROP] Toumani Camara — player_assists Under 1.5
#   Book: DraftKings  |  Odds: +143
#   True prob: 43.5%  vs  Implied: 41.2%
#   EV: +5.64%  |  Kelly stake: $9.87
#
# [PROP] Jaylen Brown — player_points Over 25.5
#   Book: BetMGM  |  Odds: -115
#   True prob: 56.3%  vs  Implied: 53.5%
#   EV: +5.34%  |  Kelly stake: $15.37
#
# [PROP] OG Anunoby — player_assists Under 1.5
#   Book: DraftKings  |  Odds: +128
#   True prob: 46.1%  vs  Implied: 43.9%
#   EV: +5.07%  |  Kelly stake: $9.9
#
# [PROP] Jalen Brunson — player_assists Over 7.5
#   Book: Bovada  |  Odds: +125
#   True prob: 46.6%  vs  Implied: 44.4%
#   EV: +4.8%  |  Kelly stake: $9.6
#
# [PROP] Amen Thompson — player_points Under 17.5
#   Book: DraftKings  |  Odds: -102
#   True prob: 52.7%  vs  Implied: 50.5%
#   EV: +4.45%  |  Kelly stake: $11.35
#
# [PROP] Jalen Brunson — player_assists Over 7.5
#   Book: FanDuel  |  Odds: +124
#   True prob: 46.6%  vs  Implied: 44.6%
#   EV: +4.34%  |  Kelly stake: $8.74
#
# [PROP] Luguentz Dort — player_points Over 7.5
#   Book: Bovada  |  Odds: +125
#   True prob: 46.4%  vs  Implied: 44.4%
#   EV: +4.33%  |  Kelly stake: $8.65
#
# [PROP] Quentin Grimes — player_threes Under 0.5
#   Book: Bovada  |  Odds: +200
#   True prob: 34.7%  vs  Implied: 33.3%
#   EV: +4.12%  |  Kelly stake: $5.15
#
# [PROP] Isaiah Stewart II — player_rebounds Under 3.5
#   Book: Bovada  |  Odds: +130
#   True prob: 45.1%  vs  Implied: 43.5%
#   EV: +3.75%  |  Kelly stake: $7.21
#
# [PROP] Dyson Daniels — player_rebounds Under 6.5
#   Book: Bovada  |  Odds: +125
#   True prob: 46.0%  vs  Implied: 44.4%
#   EV: +3.6%  |  Kelly stake: $7.19
#
# [PROP] Jrue Holiday — player_threes Over 2.5
#   Book: Bovada  |  Odds: +155
#   True prob: 40.5%  vs  Implied: 39.2%
#   EV: +3.36%  |  Kelly stake: $5.42
#
# [PROP] Paul George — player_points Under 17.5
#   Book: Bovada  |  Odds: +105
#   True prob: 50.4%  vs  Implied: 48.8%
#   EV: +3.33%  |  Kelly stake: $7.93
#
# [PROP] Luke Kennard — player_assists Over 3.5
#   Book: BetMGM  |  Odds: -120
#   True prob: 56.3%  vs  Implied: 54.5%
#   EV: +3.16%  |  Kelly stake: $9.47
#
# [PROP] Amen Thompson — player_points_rebounds_assists Over 30.5
#   Book: BetRivers  |  Odds: +105
#   True prob: 50.3%  vs  Implied: 48.8%
#   EV: +3.13%  |  Kelly stake: $7.46
#
# [PROP] VJ Edgecombe — player_assists Under 3.5
#   Book: Bovada  |  Odds: +135
#   True prob: 43.9%  vs  Implied: 42.6%
#   EV: +3.11%  |  Kelly stake: $5.75
#
# [PROP] Amen Thompson — player_points Under 17.5
#   Book: Bovada  |  Odds: -105
#   True prob: 52.7%  vs  Implied: 51.2%
#   EV: +2.97%  |  Kelly stake: $7.8
#
# [PROP] Dean Wade — player_points Over 4.5
#   Book: FanDuel  |  Odds: -113
#   True prob: 54.6%  vs  Implied: 53.1%
#   EV: +2.97%  |  Kelly stake: $8.39
#
# [PROP] Jarrett Allen — player_points Under 13.5
#   Book: Bovada  |  Odds: +105
#   True prob: 50.2%  vs  Implied: 48.8%
#   EV: +2.97%  |  Kelly stake: $7.08
#
# [PROP] Dylan Harper — player_rebounds Under 2.5
#   Book: FanDuel  |  Odds: +112
#   True prob: 48.4%  vs  Implied: 47.2%
#   EV: +2.63%  |  Kelly stake: $5.87
#
# [PROP] Immanuel Quickley — player_threes Under 1.5
#   Book: FanDuel  |  Odds: +146
#   True prob: 41.7%  vs  Implied: 40.7%
#   EV: +2.6%  |  Kelly stake: $4.45
#
# [PROP] Donovan Clingan — player_rebounds Under 9.5
#   Book: Bovada  |  Odds: +115
#   True prob: 47.7%  vs  Implied: 46.5%
#   EV: +2.59%  |  Kelly stake: $5.63
#
# [PROP] Donovan Mitchell — player_threes Under 2.5
#   Book: Bovada  |  Odds: +140
#   True prob: 42.7%  vs  Implied: 41.7%
#   EV: +2.54%  |  Kelly stake: $4.53
#
# [PROP] Ja'Kobe Walter — player_rebounds Under 2.5
#   Book: BetRivers  |  Odds: +112
#   True prob: 48.3%  vs  Implied: 47.2%
#   EV: +2.5%  |  Kelly stake: $5.58
#
# [PROP] Josh Hart — player_points_rebounds_assists Over 24.5
#   Book: BetRivers  |  Odds: +100
#   True prob: 51.2%  vs  Implied: 50.0%
#   EV: +2.46%  |  Kelly stake: $6.16
#
# [PROP] LeBron James — player_points Over 24.5
#   Book: Bovada  |  Odds: +105
#   True prob: 49.9%  vs  Implied: 48.8%
#   EV: +2.39%  |  Kelly stake: $5.69
#
# [PROP] Jakob Poeltl — player_rebounds Under 6.5
#   Book: BetRivers  |  Odds: -106
#   True prob: 52.6%  vs  Implied: 51.5%
#   EV: +2.28%  |  Kelly stake: $6.04
#
# [PROP] Dean Wade — player_points Over 4.5
#   Book: Bovada  |  Odds: -115
#   True prob: 54.6%  vs  Implied: 53.5%
#   EV: +2.13%  |  Kelly stake: $6.12
#
# [PROP] Christian Braun — player_points_rebounds_assists Over 19.5
#   Book: BetRivers  |  Odds: +112
#   True prob: 48.1%  vs  Implied: 47.2%
#   EV: +2.08%  |  Kelly stake: $4.64
#
# [PROP] Jalen Johnson — player_points_rebounds_assists Under 37.5
#   Book: BetRivers  |  Odds: +112
#   True prob: 48.1%  vs  Implied: 47.2%
#   EV: +2.08%  |  Kelly stake: $4.64
#
# [PROP] Ausar Thompson — player_rebounds Under 5.5
#   Book: BetMGM  |  Odds: -125
#   True prob: 56.7%  vs  Implied: 55.6%
#   EV: +2.04%  |  Kelly stake: $6.39
#
# [PROP] Christian Braun — player_threes Over 1.5
#   Book: FanDuel  |  Odds: +194
#   True prob: 34.7%  vs  Implied: 34.0%
#   EV: +2.04%  |  Kelly stake: $2.63
