# %%
import pandas as pd
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import LabelEncoder
import warnings
from pathlib import Path
import sys
import os
from datetime import datetime

project_root = Path.cwd().parent.parent
project_root_str = str(project_root)

if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)

os.chdir(project_root_str)

from src.utils.team_info import *
from src.utils.helper_functions import *
from src.pipeline.props_pipeline.ppm_pipeline import *
from src.pipeline.props_pipeline.min_pipeline import *
from src.features.feature_engineer.min_features import min_features

warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# pos = pd.read_csv('data/raw/player_positions/player_positions.csv')
# s24 = pd.read_csv('data/raw/season_stats/S24.csv').sort_values(by='GAME_DATE')
s25 = pd.read_csv('data/raw/season_stats/S25.csv').sort_values(by='GAME_DATE')
s25['STARTING'] = s25['START_POSITION'].notna().astype(int)
s26 = pd.read_csv('data/raw/season_stats/S26.csv').sort_values(by='GAME_DATE')
s26['STARTING'] = s26['START_POSITION'].notna().astype(int)
s26.tail()
# Out:
#     SEASON_YEAR  PLAYER_ID           PLAYER_NAME NICKNAME     TEAM_ID  \
# 132     2025-26    1630536        Sharife Cooper  Sharife  1610612764
# 131     2025-26    1630264          Anthony Gill  Anthony  1610612764
# 130     2025-26    1629021         Moritz Wagner   Moritz  1610612753
# 141     2025-26    1631218  Trayce Jackson-Davis   Trayce  1610612761
# 0       2025-26    1630578        Alperen Sengun  Alperen  1610612745
#
#     TEAM_ABBREVIATION           TEAM_NAME   GAME_ID            GAME_DATE  \
# 132               WAS  Washington Wizards  22501087  2026-03-29T00:00:00
# 131               WAS  Washington Wizards  22501087  2026-03-29T00:00:00
# 130               ORL       Orlando Magic  22501086  2026-03-29T00:00:00
# 141               TOR     Toronto Raptors  22501086  2026-03-29T00:00:00
# 0                 HOU     Houston Rockets  22501088  2026-03-29T00:00:00
#
#          MATCHUP WL        MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 132    WAS @ POR  L  19.000000    4    9   0.444     0     1    0.000    2
# 131    WAS @ POR  L  30.600000    4    7   0.571     0     1    0.000    0
# 130    ORL @ TOR  L  12.000000    3    6   0.500     1     2    0.500    0
# 141  TOR vs. ORL  W  10.633333    2    3   0.667     0     0    0.000    0
# 0      HOU @ NOP  W  31.771667   12   23   0.522     5     7    0.714    7
#
#      FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA  PF  PFD  PTS  \
# 132    2   1.000     0     1    1    2    2    0    0     0   1    2   10
# 131    0   0.000     0     3    3    0    2    1    0     1   4    1    8
# 130    0   0.000     0     4    4    1    0    0    0     1   0    1    7
# 141    0   0.000     0     1    1    2    1    1    1     0   1    0    4
# 0      8   0.875     7     6   13    7    0    3    3     4   2    5   36
#
#      PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  WNBA_FANTASY_PTS  AVAILABLE_FLAG  \
# 132         -11             12.2    0    0              13.0               1
# 131         -34             12.6    0    0              13.0               1
# 130          -7             13.3    0    0              13.0               1
# 141          -1             13.2    0    0              11.0               1
# 0            26             80.1    1    0              73.0               1
#
#     MIN_SEC  TEAM_COUNT  E_OFF_RATING  OFF_RATING  sp_work_OFF_RATING  \
# 132   19:00           1          90.4        90.0                90.0
# 131   30:36           1          77.0        76.5                76.5
# 130   12:00           1          73.1        70.4                70.4
# 141   10:38           1          78.7        78.3                78.3
# 0     31:46           1         148.9       148.5               148.5
#
#      E_DEF_RATING  DEF_RATING  sp_work_DEF_RATING  E_NET_RATING  NET_RATING  \
# 132         121.8       120.5               120.5         -31.4       -30.5
# 131         130.2       128.4               128.4         -53.2       -51.9
# 130         100.5       100.0               100.0         -27.4       -29.6
# 141          82.6        79.2                79.2          -3.9        -0.9
# 0           108.3       107.5               107.5          40.6        41.0
#
#      sp_work_NET_RATING  AST_PCT  AST_TO  AST_RATIO  OREB_PCT  DREB_PCT  \
# 132               -30.5    0.250     1.0       14.3     0.000     0.056
# 131               -51.9    0.000     0.0        0.0     0.000     0.103
# 130               -29.6    0.200     0.0       14.3     0.000     0.333
# 141                -0.9    0.333     2.0       33.3     0.000     0.083
# 0                  41.0    0.333     0.0       20.6     0.189     0.200
#
#      REB_PCT  TM_TOV_PCT  E_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  \
# 132    0.027        14.3       14.4    0.444   0.506    0.279      0.291
# 131    0.049        22.2       22.2    0.571   0.571    0.122      0.126
# 130    0.160         0.0        0.0    0.583   0.583    0.222      0.231
# 141    0.042        16.7       16.7    0.667   0.667    0.167      0.168
# 0      0.194         0.0        0.0    0.630   0.679    0.333      0.328
#
#      E_PACE    PACE  PACE_PER40  sp_work_PACE    PIE  POSS  FGM_PG  FGA_PG  \
# 132   99.08   99.79       83.16         99.79  0.077    40     4.0     9.0
# 131  104.75  105.88       88.24        105.88  0.026    68     4.0     7.0
# 130  103.76  106.00       88.33        106.00  0.162    27     3.0     6.0
# 141  103.55  106.08       88.40        106.08  0.118    23     2.0     3.0
# 0     99.92  100.47       83.72        100.47  0.274    66    12.0    23.0
#
#      TEAM_FGM  TEAM_FGA  TEAM_FG_PCT  TEAM_FG3M  TEAM_FG3A  TEAM_FG3_PCT  \
# 132        32        87        0.368          5         22         0.227
# 131        32        87        0.368          5         22         0.227
# 130        31        82        0.378          9         38         0.237
# 141        54        94        0.574         13         29         0.448
# 0          49       105        0.467         18         44         0.409
#
#      TEAM_FTM  TEAM_FTA  TEAM_FT_PCT  TEAM_OREB  TEAM_DREB  TEAM_REB  \
# 132        19        22        0.864          9         30        39
# 131        19        22        0.864          9         30        39
# 130        16        19        0.842          9         27        36
# 141        18        22        0.818          7         37        44
# 0          18        21        0.857         22         37        59
#
#      TEAM_AST  TEAM_TOV  TEAM_STL  TEAM_BLK  TEAM_BLKA  TEAM_PF  TEAM_PFD  \
# 132        16      16.0         7         2         10       28        24
# 131        16      16.0         7         2         10       28        24
# 130        20      28.0         4         1          3       20        18
# 141        41      11.0        20         3          1       18        20
# 0          33       8.0         9         8          9       17        18
#
#      TEAM_PTS  TEAM_PLUS_MINUS  TEAM_E_OFF_RATING  TEAM_OFF_RATING  \
# 132        88            -35.0               84.9             85.4
# 131        88            -35.0               84.9             85.4
# 130        87            -52.0               79.6             83.7
# 141       139             52.0              129.1            132.4
# 0         134             32.0              133.7            135.4
#
#      TEAM_E_DEF_RATING  TEAM_DEF_RATING  TEAM_E_NET_RATING  TEAM_NET_RATING  \
# 132              119.3            119.4              -34.4            -34.0
# 131              119.3            119.4              -34.4            -34.0
# 130              129.1            132.4              -49.5            -48.7
# 141               79.6             83.7               49.5             48.7
# 0                100.7            102.0               33.0             33.4
#
#      TEAM_AST_PCT  TEAM_AST_TO  TEAM_AST_RATIO  TEAM_OREB_PCT  TEAM_DREB_PCT  \
# 132         0.500         1.00            12.1          0.232          0.696
# 131         0.500         1.00            12.1          0.232          0.696
# 130         0.645         0.71            14.4          0.283          0.705
# 141         0.759         3.73            25.8          0.295          0.717
# 0           0.673         4.13            21.2          0.421          0.769
#
#      TEAM_REB_PCT  TEAM_TM_TOV_PCT  TEAM_EFG_PCT  TEAM_TS_PCT  TEAM_E_PACE  \
# 132         0.441            0.155         0.397        0.455        103.4
# 131         0.441            0.155         0.397        0.455        103.4
# 130         0.474            0.269         0.433        0.481        108.5
# 141         0.526            0.105         0.644        0.670        108.5
# 0           0.587            0.081         0.552        0.586        100.8
#
#      TEAM_PACE  TEAM_PACE_PER40  TEAM_POSS  TEAM_PIE  OPP_TEAM_ID  \
# 132      103.0            85.83        103     0.280   1610612757
# 131      103.0            85.83        103     0.280   1610612757
# 130      104.5            87.08        104     0.195   1610612761
# 141      104.5            87.08        105     0.805   1610612753
# 0         99.5            82.92         99     0.659   1610612740
#
#     OPP_OPP_ABBREVIATION_base       OPP_OPP_NAME_base  OPP_FGM  OPP_FGA  \
# 132                       POR  Portland Trail Blazers       44       86
# 131                       POR  Portland Trail Blazers       44       86
# 130                       TOR         Toronto Raptors       54       94
# 141                       ORL           Orlando Magic       31       82
# 0                         NOP    New Orleans Pelicans       37       86
#
#      OPP_FG_PCT  OPP_FG3M  OPP_FG3A  OPP_FG3_PCT  OPP_FTM  OPP_FTA  \
# 132       0.512        12        36        0.333       23       32
# 131       0.512        12        36        0.333       23       32
# 130       0.574        13        29        0.448       18       22
# 141       0.378         9        38        0.237       16       19
# 0         0.430         9        29        0.310       19       28
#
#      OPP_FT_PCT  OPP_OREB  OPP_DREB  OPP_REB  OPP_AST  OPP_TOV  OPP_STL  \
# 132       0.719        11        38       49       24     14.0        8
# 131       0.719        11        38       49       24     14.0        8
# 130       0.818         7        37       44       41     11.0       20
# 141       0.842         9        27       36       20     28.0        4
# 0         0.679         8        28       36       19     11.0        4
#
#      OPP_BLK  OPP_BLKA  OPP_PF  OPP_PFD  OPP_PTS  OPP_PLUS_MINUS  \
# 132       10         2      24       28      123            35.0
# 131       10         2      24       28      123            35.0
# 130        3         1      18       20      139            52.0
# 141        1         3      20       18       87           -52.0
# 0          9         8      18       17      102           -32.0
#
#      OPP_E_OFF_RATING  OPP_OFF_RATING  OPP_E_DEF_RATING  OPP_DEF_RATING  \
# 132             119.3           119.4              84.9            85.4
# 131             119.3           119.4              84.9            85.4
# 130             129.1           132.4              79.6            83.7
# 141              79.6            83.7             129.1           132.4
# 0               100.7           102.0             133.7           135.4
#
#      OPP_E_NET_RATING  OPP_NET_RATING  OPP_AST_PCT  OPP_AST_TO  OPP_AST_RATIO  \
# 132              34.4            34.0        0.545        1.71           17.0
# 131              34.4            34.0        0.545        1.71           17.0
# 130              49.5            48.7        0.759        3.73           25.8
# 141             -49.5           -48.7        0.645        0.71           14.4
# 0               -33.0           -33.4        0.514        1.73           14.7
#
#      OPP_OREB_PCT  OPP_DREB_PCT  OPP_REB_PCT  OPP_TM_TOV_PCT  OPP_EFG_PCT  \
# 132         0.304         0.768        0.559           0.136        0.581
# 131         0.304         0.768        0.559           0.136        0.581
# 130         0.295         0.717        0.526           0.105        0.644
# 141         0.283         0.705        0.474           0.269        0.433
# 0           0.231         0.579        0.413           0.110        0.483
#
#      OPP_TS_PCT  OPP_E_PACE  OPP_PACE  OPP_PACE_PER40  OPP_POSS  OPP_PIE  \
# 132       0.615       103.4     103.0           85.83       103    0.720
# 131       0.615       103.4     103.0           85.83       103    0.720
# 130       0.670       108.5     104.5           87.08       105    0.805
# 141       0.481       108.5     104.5           87.08       104    0.195
# 0         0.519       100.8      99.5           82.92       100    0.341
#
#     START_POSITION pos   age  STARTING
# 132            NaN  PG  24.0         0
# 131            NaN  PF  33.0         0
# 130            NaN   C  28.0         0
# 141            NaN   C  25.0         0
# 0                C   C  23.0         1

# %%
res = []
for df in [s25, s26]:
    df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])
    df = df.sort_values(["PLAYER_ID", "GAME_DATE"]).reset_index(drop=True)

    # Derived features
    df['MIN'] = df['MIN'].round(2)
    df = min_features(df)
    df['TEAM_PTS_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['PTS_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_PTS_RANK_BY_POS_L5'] = (
    df.groupby(['TEAM_ID', 'GAME_DATE', 'pos'])['PTS_roll5']
    .rank(ascending=False, method='dense'))
    df['TEAM_POSS_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['POSS_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_POSS_RANK_BY_POS_L5'] = (
    df.groupby(['TEAM_ID', 'GAME_DATE', 'pos'])['POSS_roll5']
    .rank(ascending=False, method='dense'))
    df['TEAM_MIN_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['MIN_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_MIN_RANK_BY_POS_L5'] = (
    df.groupby(['TEAM_ID', 'GAME_DATE', 'pos'])['MIN_roll5']
    .rank(ascending=False, method='dense'))
    df['TEAM_USG_RANK_BY_POS_L10'] = (
    df.groupby(['TEAM_ID', 'GAME_DATE', 'pos'])['USG_PCT_roll10']
    .rank(ascending=False, method='dense'))
    df['TEAM_MIN_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['MIN_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_PIE_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['PIE_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_USG_RANK_L5'] = (df.groupby(['TEAM_ID','GAME_DATE'])['USG_PCT_roll5'].rank(ascending=False, method='dense'))
    df['TEAM_USG_RANK_BY_POS_L5'] = (df.groupby(['TEAM_ID', 'GAME_DATE', 'pos'])['USG_PCT_roll5'].rank(ascending=False, method='dense'))
    df['USG_EWM_L12'] = (df.groupby('PLAYER_ID')['USG_PCT'].transform(lambda x: x.shift(1).ewm(span=12, adjust=False).mean()))
    df['USG_EWM_L5'] = (df.groupby('PLAYER_ID')['USG_PCT'].transform(lambda x: x.shift(1).ewm(span=5, adjust=False).mean()))
    df['MIN_EWM_L12'] = (df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).ewm(span=12, adjust=False).mean()))
    df['MIN_EWM_L5'] = (df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).ewm(span=5, adjust=False).mean()))
    df['MIN_EWM_L3'] = (df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).ewm(span=3, adjust=False).mean()))
    df['MEDIAN_MIN_L10'] = (df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).rolling(10).median()))
    df['STARTER_X_MIN_AVG'] = df['STARTING'] * df['MIN_season_avg']
    df['AGE_X_B2B'] = df['age'] * df['IS_B2B']
    df['HOME_X_MIN_AVG'] = df['IS_HOME'] * df['MIN_season_avg']
    df['EXPECTED_MARGIN'] = (df['TEAM_NET_RATING_roll5'] - df['OPP_NET_RATING_roll5']).abs()
    df['MIN_MAX_L5'] = df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).rolling(5).max())
    df['MIN_MIN_L5'] = df.groupby('PLAYER_ID')['MIN'].transform(lambda x: x.shift(1).rolling(5).min())
    df["GP"] = df.groupby("PLAYER_ID").cumcount()
    le = LabelEncoder()
    df['POSITION_ENC'] = le.fit_transform(df['pos'])
    df['PLAYER_ENC'] = le.fit_transform(df['PLAYER_NAME'])
    df['ROLE_LOCK'] = (
    df['STARTER_ROLL10_PCT'] * df['MIN_std10'].apply(lambda x: 1/x))  # high start% + low variance = locked in role = safest bet
    df['ROLE_SHOCK'] = (
    df['MIN_EWM_L5'] - df['MIN_EWM_L12']          # short vs long term gap
    ) / df['MIN_EWM_L12']                            # normalized as % change
    df['PM_PER_MIN']    = df['PLUS_MINUS_lag1'] / df['MIN_lag1'].replace(0, np.nan)
    df['PM_PER_MIN_R10']= df['PM_PER_MIN'].transform(lambda x: x.shift(1).rolling(10).mean())
    player_avgs = df[df['MIN'] > 0].groupby('PLAYER_ID')['MIN'].apply(
    lambda x: (x >= 12).mean())
    eligible = player_avgs[player_avgs >= 0.60].index
    df = df[df['PLAYER_ID'].isin(eligible)]
    res.append(df)

df = pd.concat(res, ignore_index=True)
df.drop(columns=['Unnamed: 0'], inplace=True)
print(df.shape)
df[df['PLAYER_NAME'] == 'LeBron James']
# Out:
# (41107, 323)
#       SEASON_YEAR  PLAYER_ID   PLAYER_NAME NICKNAME     TEAM_ID  \
# 0         2024-25       2544  LeBron James   LeBron  1610612747
# 1         2024-25       2544  LeBron James   LeBron  1610612747
# 2         2024-25       2544  LeBron James   LeBron  1610612747
# 3         2024-25       2544  LeBron James   LeBron  1610612747
# 4         2024-25       2544  LeBron James   LeBron  1610612747
# ...           ...        ...           ...      ...         ...
# 21480     2025-26       2544  LeBron James   LeBron  1610612747
# 21481     2025-26       2544  LeBron James   LeBron  1610612747
# 21482     2025-26       2544  LeBron James   LeBron  1610612747
# 21483     2025-26       2544  LeBron James   LeBron  1610612747
# 21484     2025-26       2544  LeBron James   LeBron  1610612747
#
#       TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  \
# 0                   LAL  Los Angeles Lakers  22400062 2024-10-22  LAL vs. MIN
# 1                   LAL  Los Angeles Lakers  22400085 2024-10-25  LAL vs. PHX
# 2                   LAL  Los Angeles Lakers  22400096 2024-10-26  LAL vs. SAC
# 3                   LAL  Los Angeles Lakers  22400111 2024-10-28    LAL @ PHX
# 4                   LAL  Los Angeles Lakers  22400118 2024-10-30    LAL @ CLE
# ...                 ...                 ...       ...        ...          ...
# 21480               LAL  Los Angeles Lakers  22501010 2026-03-19    LAL @ MIA
# 21481               LAL  Los Angeles Lakers  22501024 2026-03-21    LAL @ ORL
# 21482               LAL  Los Angeles Lakers  22501038 2026-03-23    LAL @ DET
# 21483               LAL  Los Angeles Lakers  22501052 2026-03-25    LAL @ IND
# 21484               LAL  Los Angeles Lakers  22501075 2026-03-27  LAL vs. BKN
#
#       WL    MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0      W  34.65    7   16   0.438     1     4    0.250    1    1   1.000
# 1      W  34.70    7   13   0.538     2     5    0.400    5    8   0.625
# 2      W  33.77   12   22   0.545     4     9    0.444    4    4   1.000
# 3      L  35.80    3   14   0.214     2     5    0.400    3    6   0.500
# 4      L  28.97    9   13   0.692     1     3    0.333    7    7   1.000
# ...   ..    ...  ...  ...     ...   ...   ...      ...  ...  ...     ...
# 21480  W  37.87    8   12   0.667     0     0    0.000    3    5   0.600
# 21481  W  34.38    5   13   0.385     0     2    0.000    2    2   1.000
# 21482  L  38.73    4   10   0.400     1     2    0.500    3    3   1.000
# 21483  W  34.47    9   17   0.529     0     1    0.000    5    5   1.000
# 21484  W  37.48    5   11   0.455     0     1    0.000    4    7   0.571
#
#        OREB  DREB  REB  AST  TOV  STL  BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  \
# 0         0     5    5    4    2    0    2     0   3    4   16          -6
# 1         0     4    4    8    2    0    0     0   1    4   21          14
# 2         0    14   14   10    5    0    1     4   3    5   32          13
# 3         0     5    5    8    2    1    0     1   1    3   11         -17
# 4         1     5    6    3    6    0    0     0   2    5   26         -17
# ...     ...   ...  ...  ...  ...  ...  ...   ...  ..  ...  ...         ...
# 21480     4    11   15   10    3    0    0     1   2    3   19           4
# 21481     0     6    6    4    1    3    0     1   1    3   12           4
# 21482     1     8    9   10    4    0    1     2   2    2   12          -8
# 21483     1     8    9    9    1    1    0     0   1    3   23          24
# 21484     0     6    6    8    1    1    0     1   0    5   14          19
#
#        NBA_FANTASY_PTS  DD2  TD3  WNBA_FANTASY_PTS  AVAILABLE_FLAG MIN_SEC  \
# 0                 32.0    0    0              30.0               1   34:39
# 1                 35.8    0    0              35.0               1   34:42
# 2                 61.8    1    1              62.0               1   33:46
# 3                 30.0    0    0              28.0               1   35:48
# 4                 31.7    0    0              36.0               1   28:58
# ...                ...  ...  ...               ...             ...     ...
# 21480             49.0    1    1              44.0               1   37:52
# 21481             33.2    0    0              28.0               1   34:23
# 21482             36.8    1    0              34.0               1   38:44
# 21483             49.3    0    0              43.0               1   34:28
# 21484             35.2    0    0              30.0               1   37:29
#
#        TEAM_COUNT  E_OFF_RATING  OFF_RATING  sp_work_OFF_RATING  E_DEF_RATING  \
# 0               1         100.6       101.5               101.5         104.3
# 1               1         134.9       132.0               132.0         118.3
# 2               1         121.5       121.5               121.5         107.0
# 3               1          96.7       101.3               101.3         128.1
# 4               1         100.5       103.1               103.1         126.2
# ...           ...           ...         ...                 ...           ...
# 21480           1         133.1       126.8               126.8         125.3
# 21481           1         111.0       114.7               114.7         106.0
# 21482           1         107.7       106.6               106.6         113.8
# 21483           1         127.0       130.8               130.8         103.0
# 21484           1         121.3       123.3               123.3          91.6
#
#        DEF_RATING  sp_work_DEF_RATING  E_NET_RATING  NET_RATING  \
# 0           110.3               110.3          -3.7        -8.8
# 1           114.9               114.9          16.6        17.1
# 2           106.4               106.4          14.5        15.1
# 3           127.4               127.4         -31.4       -26.1
# 4           129.7               129.7         -25.7       -26.6
# ...           ...                 ...           ...         ...
# 21480       123.5               123.5           7.7         3.4
# 21481       104.2               104.2           5.1        10.5
# 21482       120.3               120.3          -6.1       -13.7
# 21483       104.0               104.0          24.0        26.8
# 21484        92.2                92.2          29.7        31.1
#
#        sp_work_NET_RATING  AST_PCT  AST_TO  AST_RATIO  OREB_PCT  DREB_PCT  \
# 0                    -8.8    0.211    2.00       18.2     0.000     0.119
# 1                    17.1    0.320    4.00       29.6     0.000     0.154
# 2                    15.1    0.417    2.00       26.3     0.000     0.400
# 3                   -26.1    0.333    4.00       29.6     0.000     0.161
# 4                   -26.6    0.214    0.50       12.0     0.043     0.179
# ...                   ...      ...     ...        ...       ...       ...
# 21480                 3.4    0.417    3.33       37.0     0.111     0.289
# 21481                10.5    0.167    4.00       21.1     0.000     0.214
# 21482               -13.7    0.400    2.50       40.0     0.030     0.200
# 21483                26.8    0.321    9.00       31.0     0.030     0.235
# 21484                31.1    0.320    8.00       34.8     0.000     0.140
#
#        REB_PCT  TM_TOV_PCT  E_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  \
# 0        0.060         9.1        8.9    0.469   0.487    0.214      0.232
# 1        0.078         7.4        7.5    0.615   0.636    0.232      0.233
# 2        0.215        13.2       12.9    0.636   0.673    0.308      0.327
# 3        0.068         7.4        7.5    0.286   0.331    0.218      0.220
# 4        0.118        24.0       23.9    0.731   0.808    0.310      0.317
# ...        ...         ...        ...      ...     ...      ...        ...
# 21480    0.203        11.1       11.0    0.667   0.669    0.181      0.191
# 21481    0.090         5.3        5.3    0.385   0.432    0.183      0.185
# 21482    0.123        16.0       15.8    0.450   0.530    0.176      0.186
# 21483    0.134         3.4        3.4    0.529   0.599    0.227      0.240
# 21484    0.082         4.3        4.3    0.455   0.497    0.188      0.190
#
#        E_PACE    PACE  PACE_PER40  sp_work_PACE    PIE  POSS  FGM_PG  FGA_PG  \
# 0       97.33   94.20       78.50         94.20  0.107    68     7.0    16.0
# 1      100.45  103.05       85.88        103.05  0.120    75     7.0    13.0
# 2      111.33  111.59       92.99        111.59  0.222    79    12.0    22.0
# 3      101.36   99.22       82.68         99.22  0.052    75     3.0    14.0
# 4      108.90  106.05       88.38        106.05  0.160    64     9.0    13.0
# ...       ...     ...         ...           ...    ...   ...     ...     ...
# 21480  100.12  103.31       86.09        103.31  0.175    82     8.0    12.0
# 21481   97.78   97.02       80.85         97.02  0.114    68     5.0    13.0
# 21482   95.10   92.94       77.45         92.94  0.128    76     4.0    10.0
# 21483  108.65  106.54       88.78        106.54  0.186    78     9.0    17.0
# 21484   97.14   96.04       80.04         96.04  0.138    73     5.0    11.0
#
#        TEAM_FGM  TEAM_FGA  TEAM_FG_PCT  TEAM_FG3M  TEAM_FG3A  TEAM_FG3_PCT  \
# 0            42        95        0.442          5         30         0.167
# 1            40        75        0.533         14         27         0.519
# 2            48        92        0.522         14         34         0.412
# 3            39        94        0.415         14         32         0.438
# 4            38        77        0.494          6         28         0.214
# ...         ...       ...          ...        ...        ...           ...
# 21480        43        81        0.531         14         32         0.438
# 21481        39        87        0.448          8         32         0.250
# 21482        38        79        0.481          8         29         0.276
# 21483        50        89        0.562          9         23         0.391
# 21484        38        70        0.543         11         25         0.440
#
#        TEAM_FTM  TEAM_FTA  TEAM_FT_PCT  TEAM_OREB  TEAM_DREB  TEAM_REB  \
# 0            21        25        0.840         15         31        46
# 1            29        39        0.744          6         31        37
# 2            21        24        0.875         13         32        45
# 3            13        18        0.722         11         35        46
# 4            28        33        0.848          5         32        37
# ...         ...       ...          ...        ...        ...       ...
# 21480        34        45        0.756         13         34        47
# 21481        19        29        0.655         14         29        43
# 21482        26        31        0.839          9         30        39
# 21483        28        34        0.824          7         32        39
# 21484        29        42        0.690          6         42        48
#
#        TEAM_AST  TEAM_TOV  TEAM_STL  TEAM_BLK  TEAM_BLKA  TEAM_PF  TEAM_PFD  \
# 0            22       7.0         7         8          1       22        22
# 1            33      13.0        10         5          4       18        26
# 2            32      19.0         8         3          5       19        19
# 3            25      12.0         5         6         11       19        22
# 4            21      21.0         6         0          2        7        26
# ...         ...       ...       ...       ...        ...      ...       ...
# 21480        23      13.0         8         3          2       20        26
# 21481        19      12.0        11         6          2       20        27
# 21482        27      13.0         6         6          4       18        23
# 21483        30      14.0        15         4          2       22        25
# 21484        18      15.0         9         9          2       16        28
#
#        TEAM_PTS  TEAM_PLUS_MINUS  TEAM_E_OFF_RATING  TEAM_OFF_RATING  \
# 0           110              7.0              112.2            115.8
# 1           123              7.0              124.0            121.8
# 2           131              4.0              120.7            122.4
# 3           105             -4.0              102.0            108.2
# 4           110            -24.0              102.3            104.8
# ...         ...              ...                ...              ...
# 21480       134              8.0              132.9            128.8
# 21481       105              1.0              107.4            110.5
# 21482       110             -3.0              113.8            115.8
# 21483       137              7.0              123.5            126.9
# 21484       116             17.0              119.0            118.4
#
#        TEAM_E_DEF_RATING  TEAM_DEF_RATING  TEAM_E_NET_RATING  TEAM_NET_RATING  \
# 0                  102.1            109.6               10.1              6.2
# 1                  114.3            113.7                9.7              8.1
# 2                  117.6            119.8                3.1              2.6
# 3                  111.5            113.5               -9.4             -5.3
# 4                  125.8            127.6              -23.5            -22.9
# ...                  ...              ...                ...              ...
# 21480              122.7            122.3               10.2              6.5
# 21481              104.9            108.3                2.5              2.2
# 21482              114.7            120.2               -0.8             -4.4
# 21483              119.1            122.6                4.3              4.2
# 21484               94.6            100.0               24.4             18.4
#
#        TEAM_AST_PCT  TEAM_AST_TO  TEAM_AST_RATIO  TEAM_OREB_PCT  \
# 0             0.524         3.14            15.9          0.375
# 1             0.825         2.54            23.4          0.189
# 2             0.667         1.68            20.5          0.378
# 3             0.641         2.08            17.9          0.305
# 4             0.553         1.00            15.7          0.220
# ...             ...          ...             ...            ...
# 21480         0.535         1.77            16.3          0.318
# 21481         0.487         1.58            14.4          0.358
# 21482         0.711         2.08            19.9          0.318
# 21483         0.600         2.14            19.9          0.326
# 21484         0.474         1.20            14.4          0.220
#
#        TEAM_DREB_PCT  TEAM_REB_PCT  TEAM_TM_TOV_PCT  TEAM_EFG_PCT  \
# 0              0.630         0.500            0.074         0.468
# 1              0.800         0.506            0.129         0.627
# 2              0.818         0.596            0.178         0.598
# 3              0.755         0.509            0.124         0.489
# 4              0.810         0.518            0.200         0.532
# ...              ...           ...              ...           ...
# 21480          0.694         0.516            0.125         0.617
# 21481          0.600         0.476            0.126         0.494
# 21482          0.673         0.505            0.137         0.532
# 21483          0.829         0.571            0.130         0.612
# 21484          0.717         0.515            0.153         0.621
#
#        TEAM_TS_PCT  TEAM_E_PACE  TEAM_PACE  TEAM_PACE_PER40  TEAM_POSS  \
# 0            0.519         99.4       94.5            78.75         95
# 1            0.667        100.3      101.5            84.58        101
# 2            0.639        108.3      106.5            88.75        107
# 3            0.515        100.4       96.5            80.42         97
# 4            0.601        107.0      105.0            87.50        105
# ...            ...          ...        ...              ...        ...
# 21480        0.665        101.7      103.5            86.25        104
# 21481        0.526         98.4       95.5            79.58         95
# 21482        0.594         97.6       94.5            78.75         95
# 21483        0.659        110.0      107.0            89.17        108
# 21484        0.656        101.0       98.5            82.08         98
#
#        TEAM_PIE  OPP_TEAM_ID OPP_OPP_ABBREVIATION_base  \
# 0         0.575   1610612750                       MIN
# 1         0.541   1610612756                       PHX
# 2         0.504   1610612758                       SAC
# 3         0.462   1610612756                       PHX
# 4         0.421   1610612739                       CLE
# ...         ...          ...                       ...
# 21480     0.532   1610612748                       MIA
# 21481     0.503   1610612753                       ORL
# 21482     0.510   1610612765                       DET
# 21483     0.539   1610612754                       IND
# 21484     0.645   1610612751                       BKN
#
#             OPP_OPP_NAME_base  OPP_FGM  OPP_FGA  OPP_FG_PCT  OPP_FG3M  \
# 0      Minnesota Timberwolves       35       85       0.412        13
# 1                Phoenix Suns       42       82       0.512        17
# 2            Sacramento Kings       45       88       0.511        15
# 3                Phoenix Suns       40       87       0.460        11
# 4         Cleveland Cavaliers       56       97       0.577        17
# ...                       ...      ...      ...         ...       ...
# 21480              Miami Heat       48       94       0.511        12
# 21481           Orlando Magic       36       83       0.434        11
# 21482         Detroit Pistons       40       88       0.455        11
# 21483          Indiana Pacers       48       86       0.558        16
# 21484           Brooklyn Nets       40       96       0.417        10
#
#        OPP_FG3A  OPP_FG3_PCT  OPP_FTM  OPP_FTA  OPP_FT_PCT  OPP_OREB  \
# 0            41        0.317       20       27       0.741        12
# 1            37        0.459       15       17       0.882         5
# 2            44        0.341       22       25       0.880         5
# 3            36        0.306       18       20       0.900         9
# 4            41        0.415        5        8       0.625         6
# ...         ...          ...      ...      ...         ...       ...
# 21480        38        0.316       18       22       0.818        12
# 21481        37        0.297       21       23       0.913        12
# 21482        26        0.423       22       24       0.917        11
# 21483        39        0.410       18       23       0.783         5
# 21484        39        0.256        9       15       0.600        12
#
#        OPP_DREB  OPP_REB  OPP_AST  OPP_TOV  OPP_STL  OPP_BLK  OPP_BLKA  \
# 0            35       47       17     16.0        4        1         8
# 1            29       34       35     17.0        8        4         5
# 2            27       32       32     14.0       12        5         3
# 3            37       46       21     11.0        7       11         6
# 4            30       36       37     12.0       14        2         0
# ...         ...      ...      ...      ...      ...      ...       ...
# 21480        29       41       31     11.0        4        2         3
# 21481        30       42       27     18.0        9        2         6
# 21482        26       37       31     11.0        6        4         6
# 21483        29       34       35     18.0        7        2         4
# 21484        27       39       24     14.0       11        2         9
#
#        OPP_PF  OPP_PFD  OPP_PTS  OPP_PLUS_MINUS  OPP_E_OFF_RATING  \
# 0          22       22      103            -7.0             102.1
# 1          26       18      116            -7.0             114.3
# 2          19       19      127            -4.0             117.6
# 3          22       19      109             4.0             111.5
# 4          26        7      134            24.0             125.8
# ...       ...      ...      ...             ...               ...
# 21480      26       20      126            -8.0             122.7
# 21481      27       20      104            -1.0             104.9
# 21482      23       18      113             3.0             114.7
# 21483      25       22      130            -7.0             119.1
# 21484      28       16       99           -17.0              94.6
#
#        OPP_OFF_RATING  OPP_E_DEF_RATING  OPP_DEF_RATING  OPP_E_NET_RATING  \
# 0               109.6             112.2           115.8             -10.1
# 1               113.7             124.0           121.8              -9.7
# 2               119.8             120.7           122.4              -3.1
# 3               113.5             102.0           108.2               9.4
# 4               127.6             102.3           104.8              23.5
# ...               ...               ...             ...               ...
# 21480           122.3             132.9           128.8             -10.2
# 21481           108.3             107.4           110.5              -2.5
# 21482           120.2             113.8           115.8               0.8
# 21483           122.6             123.5           126.9              -4.3
# 21484           100.0             119.0           118.4             -24.4
#
#        OPP_NET_RATING  OPP_AST_PCT  OPP_AST_TO  OPP_AST_RATIO  OPP_OREB_PCT  \
# 0                -6.2        0.486        1.06           13.0         0.370
# 1                -8.1        0.833        2.06           24.3         0.200
# 2                -2.6        0.711        2.29           21.9         0.182
# 3                 5.3        0.525        1.91           16.3         0.245
# 4                22.9        0.661        3.08           24.8         0.190
# ...               ...          ...         ...            ...           ...
# 21480            -6.5        0.646        2.82           20.8         0.306
# 21481            -2.2        0.750        1.50           19.0         0.400
# 21482             4.4        0.775        2.82           22.1         0.327
# 21483            -4.2        0.729        1.94           23.6         0.171
# 21484           -18.4        0.600        1.71           17.1         0.283
#
#        OPP_DREB_PCT  OPP_REB_PCT  OPP_TM_TOV_PCT  OPP_EFG_PCT  OPP_TS_PCT  \
# 0             0.625        0.500           0.170        0.488       0.532
# 1             0.811        0.494           0.167        0.616       0.648
# 2             0.622        0.404           0.132        0.597       0.641
# 3             0.695        0.491           0.115        0.523       0.569
# 4             0.780        0.482           0.114        0.665       0.667
# ...             ...          ...             ...          ...         ...
# 21480         0.682        0.484           0.107        0.574       0.608
# 21481         0.642        0.524           0.188        0.500       0.558
# 21482         0.682        0.495           0.117        0.517       0.573
# 21483         0.674        0.429           0.170        0.651       0.676
# 21484         0.780        0.485           0.141        0.469       0.482
#
#        OPP_E_PACE  OPP_PACE  OPP_PACE_PER40  OPP_POSS  OPP_PIE START_POSITION  \
# 0            99.4      94.5           78.75        94    0.425              F
# 1           100.3     101.5           84.58       102    0.459              F
# 2           108.3     106.5           88.75       106    0.496              F
# 3           100.4      96.5           80.42        96    0.538              F
# 4           107.0     105.0           87.50       105    0.579              F
# ...           ...       ...             ...       ...      ...            ...
# 21480       101.7     103.5           86.25       103    0.468              F
# 21481        98.4      95.5           79.58        96    0.497              F
# 21482        97.6      94.5           78.75        94    0.490              F
# 21483       110.0     107.0           89.17       106    0.461              F
# 21484       101.0      98.5           82.08        99    0.355              F
#
#       pos   age  STARTING  MIN_roll3  PTS_roll3  REB_roll3  AST_PCT_roll3  \
# 0      SF  41.0         1        NaN        NaN        NaN            NaN
# 1      SF  41.0         1        NaN        NaN        NaN            NaN
# 2      SF  41.0         1        NaN        NaN        NaN            NaN
# 3      SF  41.0         1      34.37      23.00       7.67           0.32
# 4      SF  41.0         1      34.76      21.33       7.67           0.36
# ...    ..   ...       ...        ...        ...        ...            ...
# 21480  SF  41.0         1      35.90      21.67       5.33           0.18
# 21481  SF  41.0         1      35.11      22.33       8.33           0.26
# 21482  SF  41.0         1      35.45      20.33       8.67           0.23
# 21483  SF  41.0         1      36.99      14.33      10.00           0.33
# 21484  SF  41.0         1      35.86      15.67       8.00           0.30
#
#        OREB_PCT_roll3  DREB_PCT_roll3  TM_TOV_PCT_roll3  PLUS_MINUS_roll3  \
# 0                 NaN             NaN               NaN               NaN
# 1                 NaN             NaN               NaN               NaN
# 2                 NaN             NaN               NaN               NaN
# 3                0.00            0.22              9.90              7.00
# 4                0.00            0.24              9.33              3.33
# ...               ...             ...               ...               ...
# 21480            0.03            0.14             12.03              6.33
# 21481            0.06            0.19              8.80              5.67
# 21482            0.05            0.21              8.97              2.67
# 21483            0.05            0.23             10.80              0.00
# 21484            0.02            0.22              8.23              6.67
#
#        PF_roll3  POSS_roll3  PIE_roll3  USG_PCT_roll3  TS_PCT_roll3  \
# 0           NaN         NaN        NaN            NaN           NaN
# 1           NaN         NaN        NaN            NaN           NaN
# 2           NaN         NaN        NaN            NaN           NaN
# 3          2.33       74.00       0.15           0.25          0.60
# 4          1.67       76.33       0.13           0.25          0.55
# ...         ...         ...        ...            ...           ...
# 21480      3.00       72.67       0.15           0.21          0.73
# 21481      3.00       72.00       0.18           0.21          0.75
# 21482      2.00       72.67       0.16           0.20          0.69
# 21483      1.67       75.33       0.14           0.18          0.54
# 21484      1.33       74.00       0.14           0.20          0.52
#
#        NET_RATING_roll3  OFF_RATING_roll3  DEF_RATING_roll3  MIN_roll5  \
# 0                   NaN               NaN               NaN        NaN
# 1                   NaN               NaN               NaN        NaN
# 2                   NaN               NaN               NaN        NaN
# 3                  7.80            118.33            110.53        NaN
# 4                  2.03            118.27            116.23        NaN
# ...                 ...               ...               ...        ...
# 21480              9.60            118.03            108.43      34.92
# 21481              7.93            121.80            113.90      35.76
# 21482              5.83            122.67            116.87      35.99
# 21483              0.07            116.03            116.00      35.69
# 21484              7.87            117.37            109.50      35.91
#
#        PTS_roll5  REB_roll5  AST_PCT_roll5  OREB_PCT_roll5  DREB_PCT_roll5  \
# 0            NaN        NaN            NaN             NaN             NaN
# 1            NaN        NaN            NaN             NaN             NaN
# 2            NaN        NaN            NaN             NaN             NaN
# 3            NaN        NaN            NaN             NaN             NaN
# 4            NaN        NaN            NaN             NaN             NaN
# ...          ...        ...            ...             ...             ...
# 21480       19.8        5.6           0.22            0.03            0.15
# 21481       20.4        7.6           0.24            0.05            0.17
# 21482       19.2        7.4           0.22            0.04            0.18
# 21483       18.2        8.0           0.27            0.04            0.20
# 21484       19.2        8.8           0.28            0.04            0.21
#
#        TM_TOV_PCT_roll5  PLUS_MINUS_roll5  PF_roll5  POSS_roll5  PIE_roll5  \
# 0                   NaN               NaN       NaN         NaN        NaN
# 1                   NaN               NaN       NaN         NaN        NaN
# 2                   NaN               NaN       NaN         NaN        NaN
# 3                   NaN               NaN       NaN         NaN        NaN
# 4                   NaN               NaN       NaN         NaN        NaN
# ...                 ...               ...       ...         ...        ...
# 21480             11.26               4.2       2.4        72.2       0.15
# 21481             12.52               7.0       2.4        74.6       0.15
# 21482             10.50               5.4       2.4        73.6       0.15
# 21483              9.54               2.6       2.4        72.0       0.15
# 21484              9.26               4.8       1.8        74.4       0.16
#
#        USG_PCT_roll5  TS_PCT_roll5  NET_RATING_roll5  OFF_RATING_roll5  \
# 0                NaN           NaN               NaN               NaN
# 1                NaN           NaN               NaN               NaN
# 2                NaN           NaN               NaN               NaN
# 3                NaN           NaN               NaN               NaN
# 4                NaN           NaN               NaN               NaN
# ...              ...           ...               ...               ...
# 21480           0.21          0.69              6.26            118.30
# 21481           0.21          0.69              9.10            121.66
# 21482           0.20          0.66              8.54            119.12
# 21483           0.20          0.64              4.12            117.34
# 21484           0.20          0.64              6.12            121.08
#
#        DEF_RATING_roll5  MIN_roll10  PTS_roll10  REB_roll10  AST_PCT_roll10  \
# 0                   NaN         NaN         NaN         NaN             NaN
# 1                   NaN         NaN         NaN         NaN             NaN
# 2                   NaN         NaN         NaN         NaN             NaN
# 3                   NaN         NaN         NaN         NaN             NaN
# 4                   NaN         NaN         NaN         NaN             NaN
# ...                 ...         ...         ...         ...             ...
# 21480            112.04       32.98        20.2         5.5            0.26
# 21481            112.58       33.57        20.0         6.4            0.28
# 21482            110.60       33.54        19.7         6.4            0.28
# 21483            113.24       34.58        18.7         6.6            0.27
# 21484            114.98       35.35        18.6         7.4            0.28
#
#        OREB_PCT_roll10  DREB_PCT_roll10  TM_TOV_PCT_roll10  PLUS_MINUS_roll10  \
# 0                  NaN              NaN                NaN                NaN
# 1                  NaN              NaN                NaN                NaN
# 2                  NaN              NaN                NaN                NaN
# 3                  NaN              NaN                NaN                NaN
# 4                  NaN              NaN                NaN                NaN
# ...                ...              ...                ...                ...
# 21480             0.04             0.13              12.57                6.7
# 21481             0.04             0.15              11.60                7.2
# 21482             0.03             0.16              11.70                7.1
# 21483             0.03             0.16              11.87                3.7
# 21484             0.03             0.18              11.06                4.8
#
#        PF_roll10  POSS_roll10  PIE_roll10  USG_PCT_roll10  TS_PCT_roll10  \
# 0            NaN          NaN         NaN             NaN            NaN
# 1            NaN          NaN         NaN             NaN            NaN
# 2            NaN          NaN         NaN             NaN            NaN
# 3            NaN          NaN         NaN             NaN            NaN
# 4            NaN          NaN         NaN             NaN            NaN
# ...          ...          ...         ...             ...            ...
# 21480        1.7         67.9        0.15            0.24           0.67
# 21481        1.7         69.6        0.15            0.23           0.66
# 21482        1.8         70.1        0.15            0.22           0.66
# 21483        1.9         71.6        0.15            0.22           0.64
# 21484        2.0         73.9        0.15            0.20           0.63
#
#        NET_RATING_roll10  OFF_RATING_roll10  DEF_RATING_roll10  MIN_lag1  \
# 0                    NaN                NaN                NaN       NaN
# 1                    NaN                NaN                NaN     34.65
# 2                    NaN                NaN                NaN     34.70
# 3                    NaN                NaN                NaN     33.77
# 4                    NaN                NaN                NaN     35.80
# ...                  ...                ...                ...       ...
# 21480              11.32             117.59             106.27     34.10
# 21481              11.81             119.81             108.00     37.87
# 21482              12.07             118.42             106.36     34.38
# 21483               6.44             116.46             110.03     38.73
# 21484               6.24             117.18             110.95     34.47
#
#        PTS_lag1  PLUS_MINUS_lag1  PIE_lag1  STARTING_lag1  POSS_lag1  \
# 0           NaN              NaN       NaN            NaN        NaN
# 1          16.0             -6.0     0.107            1.0       68.0
# 2          21.0             14.0     0.120            1.0       75.0
# 3          32.0             13.0     0.222            1.0       79.0
# 4          11.0            -17.0     0.052            1.0       75.0
# ...         ...              ...       ...            ...        ...
# 21480      30.0              0.0     0.199            1.0       68.0
# 21481      19.0              4.0     0.175            1.0       82.0
# 21482      12.0              4.0     0.114            1.0       68.0
# 21483      12.0             -8.0     0.128            1.0       76.0
# 21484      23.0             24.0     0.186            1.0       78.0
#
#        USG_PCT_lag1  AST_lag1  REB_lag1  STL_lag1  BLK_lag1  MIN_lag2  \
# 0               NaN       NaN       NaN       NaN       NaN       NaN
# 1             0.214       4.0       5.0       0.0       2.0       NaN
# 2             0.232       8.0       4.0       0.0       0.0     34.65
# 3             0.308      10.0      14.0       0.0       1.0     34.70
# 4             0.218       8.0       5.0       1.0       0.0     33.77
# ...             ...       ...       ...       ...       ...       ...
# 21480         0.227       2.0       5.0       1.0       1.0     33.37
# 21481         0.181      10.0      15.0       0.0       0.0     34.10
# 21482         0.183       4.0       6.0       3.0       0.0     37.87
# 21483         0.176      10.0       9.0       0.0       1.0     34.38
# 21484         0.227       9.0       9.0       1.0       0.0     38.73
#
#        PTS_lag2  PLUS_MINUS_lag2  PIE_lag2  STARTING_lag2  POSS_lag2  \
# 0           NaN              NaN       NaN            NaN        NaN
# 1           NaN              NaN       NaN            NaN        NaN
# 2          16.0             -6.0     0.107            1.0       68.0
# 3          21.0             14.0     0.120            1.0       75.0
# 4          32.0             13.0     0.222            1.0       79.0
# ...         ...              ...       ...            ...        ...
# 21480      18.0             13.0     0.158            1.0       66.0
# 21481      30.0              0.0     0.199            1.0       68.0
# 21482      19.0              4.0     0.175            1.0       82.0
# 21483      12.0              4.0     0.114            1.0       68.0
# 21484      12.0             -8.0     0.128            1.0       76.0
#
#        USG_PCT_lag2  AST_lag2  REB_lag2  STL_lag2  BLK_lag2  MIN_lag3  \
# 0               NaN       NaN       NaN       NaN       NaN       NaN
# 1               NaN       NaN       NaN       NaN       NaN       NaN
# 2             0.214       4.0       5.0       0.0       2.0       NaN
# 3             0.232       8.0       4.0       0.0       0.0     34.65
# 4             0.308      10.0      14.0       0.0       1.0     34.70
# ...             ...       ...       ...       ...       ...       ...
# 21480         0.219       5.0       5.0       2.0       0.0     40.22
# 21481         0.227       2.0       5.0       1.0       1.0     33.37
# 21482         0.181      10.0      15.0       0.0       0.0     34.10
# 21483         0.183       4.0       6.0       3.0       0.0     37.87
# 21484         0.176      10.0       9.0       0.0       1.0     34.38
#
#        PTS_lag3  PLUS_MINUS_lag3  PIE_lag3  STARTING_lag3  POSS_lag3  \
# 0           NaN              NaN       NaN            NaN        NaN
# 1           NaN              NaN       NaN            NaN        NaN
# 2           NaN              NaN       NaN            NaN        NaN
# 3          16.0             -6.0     0.107            1.0       68.0
# 4          21.0             14.0     0.120            1.0       75.0
# ...         ...              ...       ...            ...        ...
# 21480      17.0              6.0     0.091            1.0       84.0
# 21481      18.0             13.0     0.158            1.0       66.0
# 21482      30.0              0.0     0.199            1.0       68.0
# 21483      19.0              4.0     0.175            1.0       82.0
# 21484      12.0              4.0     0.114            1.0       68.0
#
#        USG_PCT_lag3  AST_lag3  REB_lag3  STL_lag3  BLK_lag3  \
# 0               NaN       NaN       NaN       NaN       NaN
# 1               NaN       NaN       NaN       NaN       NaN
# 2               NaN       NaN       NaN       NaN       NaN
# 3             0.214       4.0       5.0       0.0       2.0
# 4             0.232       8.0       4.0       0.0       0.0
# ...             ...       ...       ...       ...       ...
# 21480         0.198       5.0       6.0       2.0       0.0
# 21481         0.219       5.0       5.0       2.0       0.0
# 21482         0.227       2.0       5.0       1.0       1.0
# 21483         0.181      10.0      15.0       0.0       0.0
# 21484         0.183       4.0       6.0       3.0       0.0
#
#        STARTER_ROLL10_PCT  MIN_season_avg  PTS_season_avg  REB_season_avg  \
# 0                     NaN             NaN             NaN             NaN
# 1                     NaN           34.65           16.00            5.00
# 2                     NaN           34.67           18.50            4.50
# 3                     NaN           34.37           23.00            7.67
# 4                     NaN           34.73           20.00            7.00
# ...                   ...             ...             ...             ...
# 21480                 1.0           33.28           21.38            5.65
# 21481                 1.0           33.37           21.33            5.84
# 21482                 1.0           33.39           21.14            5.84
# 21483                 1.0           33.50           20.96            5.90
# 21484                 1.0           33.51           21.00            5.96
#
#        AST_season_avg  STL_season_avg  BLK_season_avg  TOV_season_avg  \
# 0                 NaN             NaN             NaN             NaN
# 1                4.00            0.00            2.00            2.00
# 2                6.00            0.00            1.00            2.00
# 3                7.33            0.00            1.00            3.00
# 4                7.50            0.25            0.75            2.75
# ...               ...             ...             ...             ...
# 21480            6.81            1.15            0.62            3.04
# 21481            6.88            1.12            0.61            3.04
# 21482            6.82            1.16            0.60            3.00
# 21483            6.88            1.14            0.61            3.02
# 21484            6.92            1.13            0.60            2.98
#
#        FGM_season_avg  FGA_season_avg  FG_PCT_season_avg  FG3M_season_avg  \
# 0                 NaN             NaN                NaN              NaN
# 1                7.00           16.00               0.44             1.00
# 2                7.00           14.50               0.49             1.50
# 3                8.67           17.00               0.51             2.33
# 4                7.25           16.25               0.43             2.25
# ...               ...             ...                ...              ...
# 21480            8.08           15.73               0.52             1.40
# 21481            8.08           15.65               0.52             1.37
# 21482            8.02           15.60               0.52             1.34
# 21483            7.94           15.49               0.51             1.33
# 21484            7.96           15.52               0.51             1.31
#
#        FG3A_season_avg  FG3_PCT_season_avg  OREB_season_avg  DREB_season_avg  \
# 0                  NaN                 NaN              NaN              NaN
# 1                 4.00                0.25             0.00             5.00
# 2                 4.50                0.32             0.00             4.50
# 3                 6.00                0.36             0.00             7.67
# 4                 5.75                0.37             0.00             7.00
# ...                ...                 ...              ...              ...
# 21480             4.40                0.32             0.75             4.90
# 21481             4.31                0.32             0.82             5.02
# 21482             4.26                0.31             0.80             5.04
# 21483             4.22                0.31             0.80             5.10
# 21484             4.15                0.31             0.81             5.15
#
#        PLUS_MINUS_season_avg  PF_season_avg  POSS_season_avg  PIE_season_avg  \
# 0                        NaN            NaN              NaN             NaN
# 1                      -6.00           3.00            68.00            0.11
# 2                       4.00           2.00            71.50            0.11
# 3                       7.00           2.33            74.00            0.15
# 4                       1.00           2.00            74.25            0.13
# ...                      ...            ...              ...             ...
# 21480                   0.48           1.44            69.56            0.15
# 21481                   0.55           1.45            69.82            0.15
# 21482                   0.62           1.44            69.78            0.15
# 21483                   0.45           1.45            69.90            0.15
# 21484                   0.90           1.44            70.06            0.15
#
#        USG_PCT_season_avg  TS_PCT_season_avg  NET_RATING_season_avg  \
# 0                     NaN                NaN                    NaN
# 1                    0.21               0.49                  -8.80
# 2                    0.22               0.56                   4.15
# 3                    0.25               0.60                   7.80
# 4                    0.24               0.53                  -0.68
# ...                   ...                ...                    ...
# 21480                0.27               0.59                   0.55
# 21481                0.26               0.60                   0.61
# 21482                0.26               0.59                   0.81
# 21483                0.26               0.59                   0.52
# 21484                0.26               0.59                   1.03
#
#        TEAM_PACE_roll5  TEAM_PTS_roll5  TEAM_NET_RATING_roll5  \
# 0                  NaN             NaN                    NaN
# 1                  NaN             NaN                    NaN
# 2                  NaN             NaN                    NaN
# 3                  NaN             NaN                    NaN
# 4                  NaN             NaN                    NaN
# ...                ...             ...                    ...
# 21480            97.22           122.6                   9.24
# 21481            98.82           125.4                   7.36
# 21482            97.32           118.0                   5.46
# 21483            96.30           114.6                   3.80
# 21484            99.30           122.0                   3.36
#
#        MIN_share_proxy  PTS_share_proxy  TEAM_POSS_roll5  TEAM_POSS_share  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 21480             0.15             0.16             72.2              1.0
# 21481             0.15             0.16             74.6              1.0
# 21482             0.15             0.16             73.6              1.0
# 21483             0.15             0.16             72.0              1.0
# 21484             0.15             0.16             74.4              1.0
#
#        DAYS_REST  IS_B2B  IS_HOME  GAME_NUMBER  MIN_std10  MIN_std5  \
# 0            3.0       0        1            0        NaN       NaN
# 1            3.0       0        1            1        NaN       NaN
# 2            1.0       1        1            2        NaN       NaN
# 3            2.0       0        0            3        NaN       NaN
# 4            2.0       0        0            4        NaN       NaN
# ...          ...     ...      ...          ...        ...       ...
# 21480        1.0       1        0           48       3.63      2.98
# 21481        2.0       0        0           49       3.92      3.13
# 21482        2.0       0        0           50       3.91      2.93
# 21483        2.0       0        0           51       3.75      2.43
# 21484        2.0       0        1           52       2.57      2.21
#
#        MIN_std20  OPP_DEF_RATING_roll5  OPP_DEF_RATING_roll10  OPP_PACE_roll5  \
# 0            NaN                   NaN                    NaN             NaN
# 1            NaN                100.00                 100.00          102.34
# 2            NaN                115.80                 115.80          101.50
# 3            NaN                108.63                 108.63          100.45
# 4            NaN                105.92                 105.92          100.88
# ...          ...                   ...                    ...             ...
# 21480       3.38                113.86                 111.94          105.70
# 21481       3.23                117.96                 112.52          102.43
# 21482       3.09                109.22                 111.81           99.40
# 21483       3.27                134.72                 126.73           97.40
# 21484       3.11                115.44                 116.37          101.20
#
#        OPP_PACE_roll10  OPP_POSS_roll5  OPP_POSS_roll10  OPP_NET_RATING_roll5  \
# 0                  NaN             NaN              NaN                   NaN
# 1               102.34           113.0            113.0                  2.70
# 2               101.50           102.0            102.0                 -3.10
# 3               100.45           104.0            104.0                  2.67
# 4               100.88           101.0            101.0                 16.12
# ...                ...             ...              ...                   ...
# 21480           103.40           105.8            103.4                  0.48
# 21481           100.62           104.8            101.8                 -5.90
# 21482            98.45            99.4             98.4                 10.68
# 21483            98.95            97.2             98.8                -11.46
# 21484            99.85           101.4             99.7                -14.28
#
#        OPP_NET_RATING_roll10  EXPECTED_PACE  PACE_DIFFERENTIAL  \
# 0                        NaN            NaN                NaN
# 1                       2.70            NaN                NaN
# 2                      -3.10            NaN                NaN
# 3                       2.67            NaN                NaN
# 4                      16.12            NaN                NaN
# ...                      ...            ...                ...
# 21480                   5.67         101.46              -8.48
# 21481                   6.15         100.62              -3.61
# 21482                   8.71          98.36              -2.08
# 21483                 -11.64          96.85              -1.10
# 21484                 -13.19         100.25              -1.90
#
#        PLAYER_IS_TEAM_STAR  STAR_SAT_OUT rot_group  exp_min  \
# 0                        0             1         F      NaN
# 1                        0             1         F      NaN
# 2                        0             1         F      NaN
# 3                        0             1         F      NaN
# 4                        0             1         F      NaN
# ...                    ...           ...       ...      ...
# 21480                    0             0         F   32.984
# 21481                    0             0         F   33.574
# 21482                    0             0         F   33.544
# 21483                    0             0         F   34.584
# 21484                    0             0         F   35.354
#
#        active_pos_min_sum  pos_cap  POS_VACANCY  PLAYER_POS_OPPORTUNITY  \
# 0                   0.000     96.0       96.000                     NaN
# 1                   0.000     96.0       96.000                     NaN
# 2                   0.000     96.0       96.000                     NaN
# 3                   0.000     96.0       96.000                     NaN
# 4                   0.000     96.0       96.000                     NaN
# ...                   ...      ...          ...                     ...
# 21480              74.876     96.0       21.124                  54.108
# 21481              74.626     96.0       21.374                  54.948
# 21482              75.841     96.0       20.159                  53.703
# 21483              71.319     96.0       24.681                  59.265
# 21484              90.943     96.0        5.057                  40.411
#
#        TEAM_PTS_RANK_L5  TEAM_PTS_RANK_BY_POS_L5  TEAM_POSS_RANK_L5  \
# 0                   NaN                      NaN                NaN
# 1                   NaN                      NaN                NaN
# 2                   NaN                      NaN                NaN
# 3                   NaN                      NaN                NaN
# 4                   NaN                      NaN                NaN
# ...                 ...                      ...                ...
# 21480               3.0                      1.0                3.0
# 21481               3.0                      1.0                3.0
# 21482               3.0                      1.0                3.0
# 21483               3.0                      1.0                3.0
# 21484               3.0                      1.0                3.0
#
#        TEAM_POSS_RANK_BY_POS_L5  TEAM_MIN_RANK_L5  TEAM_MIN_RANK_BY_POS_L5  \
# 0                           NaN               NaN                      NaN
# 1                           NaN               NaN                      NaN
# 2                           NaN               NaN                      NaN
# 3                           NaN               NaN                      NaN
# 4                           NaN               NaN                      NaN
# ...                         ...               ...                      ...
# 21480                       1.0               3.0                      1.0
# 21481                       1.0               3.0                      1.0
# 21482                       1.0               3.0                      1.0
# 21483                       1.0               3.0                      1.0
# 21484                       1.0               3.0                      1.0
#
#        TEAM_USG_RANK_BY_POS_L10  TEAM_PIE_RANK_L5  TEAM_USG_RANK_L5  \
# 0                           NaN               NaN               NaN
# 1                           NaN               NaN               NaN
# 2                           NaN               NaN               NaN
# 3                           NaN               NaN               NaN
# 4                           NaN               NaN               NaN
# ...                         ...               ...               ...
# 21480                       1.0               2.0               3.0
# 21481                       1.0               2.0               2.0
# 21482                       1.0               3.0               3.0
# 21483                       1.0               2.0               3.0
# 21484                       1.0               2.0               3.0
#
#        TEAM_USG_RANK_BY_POS_L5  USG_EWM_L12  USG_EWM_L5  MIN_EWM_L12  \
# 0                          NaN          NaN         NaN          NaN
# 1                          NaN     0.214000    0.214000    34.650000
# 2                          NaN     0.216769    0.220000    34.657692
# 3                          NaN     0.230805    0.249333    34.521124
# 4                          NaN     0.228835    0.238889    34.717874
# ...                        ...          ...         ...          ...
# 21480                      1.0     0.238921    0.222715    33.755076
# 21481                      1.0     0.230010    0.208810    34.388142
# 21482                      1.0     0.222778    0.200207    34.386889
# 21483                      1.0     0.215581    0.192138    35.055060
# 21484                      1.0     0.217338    0.203759    34.965051
#
#        MIN_EWM_L5  MIN_EWM_L3  MEDIAN_MIN_L10  STARTER_X_MIN_AVG  AGE_X_B2B  \
# 0             NaN         NaN             NaN                NaN        0.0
# 1       34.650000   34.650000             NaN              34.65        0.0
# 2       34.666667   34.675000             NaN              34.67       41.0
# 3       34.367778   34.222500             NaN              34.37        0.0
# 4       34.845185   35.011250             NaN              34.73        0.0
# ...           ...         ...             ...                ...        ...
# 21480   34.370819   34.525266          33.420              33.28       41.0
# 21481   35.537213   36.197633          33.585              33.37        0.0
# 21482   35.151475   35.288816          33.585              33.39        0.0
# 21483   36.344317   37.009408          33.900              33.50        0.0
# 21484   35.719544   35.739704          34.240              33.51        0.0
#
#        HOME_X_MIN_AVG  EXPECTED_MARGIN  MIN_MAX_L5  MIN_MIN_L5  GP  \
# 0                 NaN              NaN         NaN         NaN   0
# 1               34.65              NaN         NaN         NaN   1
# 2               34.67              NaN         NaN         NaN   2
# 3                0.00              NaN         NaN         NaN   3
# 4                0.00              NaN         NaN         NaN   4
# ...               ...              ...         ...         ...  ..
# 21480            0.00             8.76       40.22       33.23  48
# 21481            0.00            13.26       40.22       33.23  49
# 21482            0.00             5.22       40.22       33.37  50
# 21483            0.00            15.26       38.73       33.37  51
# 21484           33.51            17.64       38.73       34.10  52
#
#        POSITION_ENC  PLAYER_ENC  ROLE_LOCK  ROLE_SHOCK  PM_PER_MIN  \
# 0                 3         358        NaN         NaN         NaN
# 1                 3         358        NaN    0.000000   -0.173160
# 2                 3         358        NaN    0.000259    0.403458
# 3                 3         358        NaN   -0.004442    0.384957
# 4                 3         358        NaN    0.003667   -0.474860
# ...             ...         ...        ...         ...         ...
# 21480             3         360   0.275482    0.018241    0.000000
# 21481             3         360   0.255102    0.033415    0.105625
# 21482             3         360   0.255754    0.022235    0.116347
# 21483             3         360   0.266667    0.036778   -0.206558
# 21484             3         360   0.389105    0.021579    0.696258
#
#        PM_PER_MIN_R10
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 21480        0.180300
# 21481        0.220904
# 21482        0.234594
# 21483        0.231811
# 21484        0.119380
#
# [123 rows x 323 columns]

# %%
MIN_FEATURES = [
    # Tier 1 — Core role
    'STARTER_X_MIN_AVG',
    'MIN_EWM_L12',
    'MIN_EWM_L3',
    'STARTING_lag1',
    'STARTER_ROLL10_PCT',
    'ROLE_LOCK',
    'MEDIAN_MIN_L10',
    'MIN_MIN_L5',
    'MIN_MAX_L5',

    # Tier 2 — Team context
    'TEAM_MIN_RANK_L5',
    'TEAM_POSS_RANK_L5',
    'TEAM_PTS_RANK_L5',
    'TEAM_USG_RANK_L5',
    'POSS_roll5',

    # Tier 3 — Situational
    'DAYS_REST',
    'AGE_X_B2B',
    'USG_EWM_L5',
    'PM_PER_MIN_R10',
    'POSITION_ENC',
    'HOME_X_MIN_AVG',
    'MIN_share_proxy',
    'TEAM_POSS_RANK_BY_POS_L5',  # keep ONE by-pos feature
]

# %%
# Drop rows with NaN in features or target
min_df = df[MIN_FEATURES + ["MIN", "GAME_DATE"]].dropna()

# -- TIME-BASED SPLIT --
split_date = min_df["GAME_DATE"].quantile(0.75)  # train on first 75% of season
train_mask = min_df["GAME_DATE"] <= split_date
val_mask   = ~train_mask

X_train_min = min_df.loc[train_mask, MIN_FEATURES]
y_train_min = min_df.loc[train_mask, "MIN"]
X_val_min   = min_df.loc[val_mask, MIN_FEATURES]
y_val_min   = min_df.loc[val_mask, "MIN"]

lgb_min = LGBMRegressor(
    n_estimators=800,
    learning_rate=0.01,
    max_depth=4,
    min_child_samples=20,
    subsample=0.7,
    colsample_bytree=0.7,
    reg_alpha=1.0,
    reg_lambda=5.0,
    objective="regression",
    random_state=42,
    n_jobs=-1,
    verbose=-1,
)

lgb_min.fit(
    X_train_min,
    y_train_min,
    eval_set=[(X_val_min, y_val_min)],
    eval_metric="rmse",
)

min_preds_val = lgb_min.predict(X_val_min)
min_mae = mean_absolute_error(y_val_min, min_preds_val)
min_rmse = np.sqrt(mean_squared_error(y_val_min, min_preds_val))
min_r2 = r2_score(y_val_min, min_preds_val)

print(f"[Minutes Model] Validation R2: {min_r2:.4f}")
print(f"[Minutes Model] Validation RMSE: {min_rmse:.2f} min")
print(f"[Minutes Model] Validation MAE: {min_mae:.2f} min")
# Out:
# [Minutes Model] Validation R2: 0.5714
# [Minutes Model] Validation RMSE: 5.50 min
# [Minutes Model] Validation MAE: 4.27 min

# %%
importance = pd.Series(lgb_min.feature_importances_, index=MIN_FEATURES)
importance = importance.sort_values(ascending=False)

importance[:50]
# Out:
# MIN_EWM_L3                  1049
# MIN_EWM_L12                 1010
# STARTER_X_MIN_AVG            818
# MIN_MAX_L5                   753
# TEAM_USG_RANK_L5             748
# MEDIAN_MIN_L10               742
# ROLE_LOCK                    703
# DAYS_REST                    670
# PM_PER_MIN_R10               612
# USG_EWM_L5                   557
# MIN_MIN_L5                   531
# STARTER_ROLL10_PCT           483
# TEAM_MIN_RANK_L5             428
# POSS_roll5                   415
# TEAM_PTS_RANK_L5             376
# HOME_X_MIN_AVG               353
# TEAM_POSS_RANK_L5            299
# POSITION_ENC                 197
# TEAM_POSS_RANK_BY_POS_L5     180
# STARTING_lag1                166
# AGE_X_B2B                    130
# MIN_share_proxy               93
# dtype: int32

# %%
sub = df[["MIN", "MIN_EWM_L12"]].dropna()
baseline_mae = mean_absolute_error(sub["MIN"], sub["MIN_EWM_L12"])
print(f"Naive baseline MAE: {baseline_mae:.2f}")
print(f"Model MAE: {round(min_mae, 2)}")
print(f"Lift: {baseline_mae - min_mae:.2f} min")
# Out:
# Naive baseline MAE: 4.82
# Model MAE: 4.27
# Lift: 0.54 min

# %%
import matplotlib.pyplot as plt


residuals = y_val_min - min_preds_val

# Distribution of errors
plt.hist(residuals, bins=50)
plt.title('Residual Distribution')
plt.show()

# Are errors random or structured?
plt.scatter(min_preds_val, residuals)
plt.axhline(0, color='red')
plt.xlabel('Predicted MIN')
plt.ylabel('Residual')
plt.title('Residuals vs Predicted')
plt.show()

# %%
y_true = y_val_min
y_pred = min_preds_val

fig, ax = plt.subplots(figsize=(7, 7))
ax.scatter(y_true, y_pred, s=12, edgecolors="none")
lims = [0, max(y_true.max(), y_pred.max()) * 1.02]
ax.plot(lims, lims, "k--", lw=1, label="perfect")
ax.set_xlabel("Actual MIN")
ax.set_ylabel("Predicted MIN")
ax.set_title("Predicted vs actual minutes")
ax.set_aspect("equal", adjustable="box")
ax.legend()
plt.tight_layout()
plt.show()

print("Pred quantiles:", pd.Series(y_pred).quantile([0.5, 0.9, 0.95, 0.99]))
print("Actual quantiles:", pd.Series(y_true).quantile([0.5, 0.9, 0.95, 0.99]))
# Out:
# Pred quantiles: 0.50    26.382699
# 0.90    33.262914
# 0.95    34.349944
# 0.99    35.795525
# dtype: float64
# Actual quantiles: 0.50    25.6550
# 0.90    35.4710
# 0.95    37.5000
# 0.99    40.6662
# Name: MIN, dtype: float64

# %%
# Use quantile regression to get a range instead of a single number
from sklearn.ensemble import GradientBoostingRegressor

lower = GradientBoostingRegressor(loss='quantile', alpha=0.1)
upper = GradientBoostingRegressor(loss='quantile', alpha=0.9)
mid   = GradientBoostingRegressor(loss='quantile', alpha=0.5)

lower.fit(X_train_min, y_train_min)
upper.fit(X_train_min, y_train_min)
mid.fit(X_train_min, y_train_min)

pred_low  = lower.predict(X_val_min)
pred_high = upper.predict(X_val_min)
pred_mid  = mid.predict(X_val_min)

# Coverage — what % of actuals fall within the interval?
coverage = ((y_val_min >= pred_low) & (y_val_min <= pred_high)).mean()
print(f"Coverage: {coverage:.2%}")  # want this close to 80%
# Out:
# Coverage: 80.02%

# %%
results = pd.DataFrame({'actual': y_val_min.values, 'predicted': min_preds_val})

# Bin predictions and compare to actuals
results['bucket'] = pd.cut(results['predicted'], bins=10)
calibration = results.groupby('bucket').agg(
    mean_predicted=('predicted', 'mean'),
    mean_actual=('actual', 'mean'),
    count=('actual', 'count')
)
print(calibration)
# Out:
#                   mean_predicted  mean_actual  count
# bucket
# (5.888, 9.067]          7.883764     7.149583     24
# (9.067, 12.214]        11.003748    10.772057    175
# (12.214, 15.361]       14.055723    14.726214    523
# (15.361, 18.508]       17.077053    17.181100    836
# (18.508, 21.656]       20.056715    20.062676    923
# (21.656, 24.803]       23.227762    22.958502    981
# (24.803, 27.95]        26.518103    26.449347   1317
# (27.95, 31.097]        29.473943    29.282489   1551
# (31.097, 34.244]       32.637558    32.226915   1248
# (34.244, 37.392]       35.225630    35.086312    442

# %%
import shap

explainer   = shap.TreeExplainer(lgb_min)
shap_values = explainer(X_val_min)

# Global feature importance
shap.summary_plot(shap_values, X_val_min, feature_names=MIN_FEATURES)

# Single prediction waterfall
shap.plots.waterfall(shap_values[1154])

# %%
# from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit


# # Drop rows with NaN in features/target and keep GAME_DATE for time split
# min_df = df[MIN_FEATURES + ["MIN", "GAME_DATE"]].dropna()

# # -- TIME-BASED SPLIT (same style as your new notebook) --
# split_date = min_df["GAME_DATE"].quantile(0.75)  # train on first 75% of season
# train_mask = min_df["GAME_DATE"] <= split_date
# val_mask   = ~train_mask

# X_train_min = min_df.loc[train_mask, MIN_FEATURES]
# y_train_min = min_df.loc[train_mask, "MIN"]
# X_val_min   = min_df.loc[val_mask, MIN_FEATURES]
# y_val_min   = min_df.loc[val_mask, "MIN"]

# param_grid = {
#     "n_estimators": [200, 400, 600, 800],
#     "learning_rate": [0.01, 0.03, 0.05, 0.1],
#     "max_depth": [3, 4, 5, 6, 8],
#     "min_child_samples": [10, 20, 40],
#     "subsample": [0.7, 0.8, 0.9, 1.0],
#     "colsample_bytree": [0.7, 0.8, 0.9, 1.0],
#     "reg_alpha": [0.0, 0.1, 1.0],
#     "reg_lambda": [1.0, 2.0, 5.0],
# }

# lgb_min = LGBMRegressor(
#     objective="regression",
#     random_state=42,
#     n_jobs=-1,
#     verbose=-1,
# )

# # Time-aware CV for hyperparameter search on training period only
# tscv = TimeSeriesSplit(n_splits=5)

# search_min = RandomizedSearchCV(
#     estimator=lgb_min,
#     param_distributions=param_grid,
#     n_iter=100,
#     scoring="neg_mean_squared_error",
#     cv=tscv,
#     verbose=1,
#     random_state=42,
#     n_jobs=-1
# )

# search_min.fit(X_train_min, y_train_min)

# print("Best params:", search_min.best_params_)

# min_preds_val = search_min.best_estimator_.predict(X_val_min)

# min_r2 = r2_score(y_val_min, min_preds_val)
# min_rmse = np.sqrt(mean_squared_error(y_val_min, min_preds_val))
# min_mae = mean_absolute_error(y_val_min, min_preds_val)

# print(f"[Minutes Model] Validation R2: {min_r2:.4f}")
# print(f"[Minutes Model] Validation RMSE: {min_rmse:.2f} min")
# print(f"[Minutes Model] Validation MAE: {min_mae:.2f} min")

# %% [markdown]
# ## Model Analysis

# %%
target_date = pd.Timestamp("2026-03-26")
hist = df[df["GAME_DATE"] < target_date].copy()

lines_dfs = pd.read_csv('/Users/alexgonzalez/Documents/NBA-Prop-Predictor/data/raw/player_lines/NBA_DFS_20260326_151151.csv')
lines_dfs = lines_dfs[(lines_dfs['BOOKMAKER'] == 'Underdog') & (lines_dfs['CATEGORY'] == 'player_points')]
names = lines_dfs['NAME'].unique()

# %%
records = []

for name in names:
    try:
        if name in nameDict:
            name = nameDict[name]
        features = min_pipeline(df, name)
        min_arr = np.asarray(features, dtype=float).reshape(1, -1)
        predicted = float(lgb_min.predict(min_arr)[0])
        records.append({"PLAYER_NAME": name, "PRED_MIN": predicted})
    except Exception as e:
        records.append({"PLAYER_NAME": name, "PRED_MIN": np.nan})
        print(f"[SKIP] {name}: {e}")

preds_df = pd.DataFrame(records)
preds_df.head()
# Out:
# [SKIP] Mohamed Diawara: X has 1 features, but LGBMRegressor is expecting 20 features as input.
# [SKIP] Herb Jones: X has 1 features, but LGBMRegressor is expecting 20 features as input.
# [SKIP] Wendell Carter Jr: X has 1 features, but LGBMRegressor is expecting 20 features as input.
# [SKIP] Jamal Cain: X has 1 features, but LGBMRegressor is expecting 20 features as input.
# [SKIP] Devin Carter: X has 1 features, but LGBMRegressor is expecting 20 features as input.
#           PLAYER_NAME   PRED_MIN
# 0  Karl-Anthony Towns  27.769420
# 1     Jordan Clarkson  18.261052
# 2   Mitchell Robinson  20.186719
# 3        Kon Knueppel  31.336352
# 4      Grant Williams  15.560214

# %%
actuals = df[df["GAME_DATE"] == target_date][["PLAYER_NAME", "MIN"]].copy()

analysis = preds_df.merge(actuals, on="PLAYER_NAME", how="left")
analysis.rename(columns={"MIN": "ACTUAL_MIN"}, inplace=True)
analysis["ERROR"]     = analysis["PRED_MIN"] - analysis["ACTUAL_MIN"]
analysis["ABS_ERROR"] = analysis["ERROR"].abs()
analysis["PCT_ERROR"] = (analysis["ABS_ERROR"] / analysis["ACTUAL_MIN"].replace(0, np.nan)) * 100
analysis.sort_values("ABS_ERROR", ascending=False).head()
# Out:
#            PLAYER_NAME   PRED_MIN  ACTUAL_MIN     ERROR  ABS_ERROR  PCT_ERROR
# 11          Yves Missi  24.766646       16.02  8.746646   8.746646  54.598292
# 17       DeMar DeRozan  31.944352       38.48 -6.535648   6.535648  16.984532
# 24      Maxime Raynaud  32.084991       38.58 -6.495009   6.495009  16.835171
# 2    Mitchell Robinson  20.186719       26.16 -5.973281   5.973281  22.833641
# 0   Karl-Anthony Towns  27.769420       21.97  5.799420   5.799420  26.396995

# %%
print(f"\n{'='*55}")
print(f"  Minutes Model Audit — {target_date.date()}")
print(f"{'='*55}")
print(f"  Players predicted : {preds_df['PRED_MIN'].notna().sum()} / {len(names)}")
print(f"  Players w/ actuals: {analysis['ACTUAL_MIN'].notna().sum()}")
print(f"  MAE               : {analysis['ABS_ERROR'].mean():.2f} min")
print(f"  RMSE              : {np.sqrt((analysis['ERROR']**2).mean()):.2f} min")
print(f"  Median Abs Error  : {analysis['ABS_ERROR'].median():.2f} min")
# Out:
# =======================================================
#   Minutes Model Audit — 2026-03-26
# =======================================================
#   Players predicted : 30 / 35
#   Players w/ actuals: 19
#   MAE               : 2.99 min
#   RMSE              : 4.05 min
#   Median Abs Error  : 1.62 min

# %%
MISS_THRESHOLD = 10  # minutes

misses = (
    analysis
    .dropna(subset=["ACTUAL_MIN"])
    .query("ABS_ERROR >= @MISS_THRESHOLD")
    .sort_values("ABS_ERROR", ascending=False)
)

print(f"\n  Players missed by ≥{MISS_THRESHOLD} min: {len(misses)}")
print(f"\n{'─'*55}")
print(f"  {'PLAYER':<25} {'PRED':>6} {'ACTUAL':>7} {'ERROR':>7} {'%ERR':>7}")
print(f"{'─'*55}")

for _, row in misses.iterrows():
    direction = "↑" if row["ERROR"] > 0 else "↓"
    print(
        f"  {row['PLAYER_NAME']:<25} "
        f"{row['PRED_MIN']:>6.1f} "
        f"{row['ACTUAL_MIN']:>7.1f} "
        f"{direction}{row['ABS_ERROR']:>6.1f} "
        f"{row['PCT_ERROR']:>6.1f}%"
    )
# Out:
#   Players missed by ≥10 min: 0
#
# ───────────────────────────────────────────────────────
#   PLAYER                      PRED  ACTUAL   ERROR    %ERR
# ───────────────────────────────────────────────────────

# %%
full_view = (
    analysis
    .dropna(subset=["ACTUAL_MIN"])
    .sort_values("ABS_ERROR", ascending=False)
    [["PLAYER_NAME", "PRED_MIN", "ACTUAL_MIN", "ERROR", "ABS_ERROR", "PCT_ERROR"]]
    .round(2)
).head(20)

print(f"\n{'─'*55}")
print("  Full Results (sorted by abs error):")
print(full_view.to_string(index=False))
# Out:
# ───────────────────────────────────────────────────────
#   Full Results (sorted by abs error):
#        PLAYER_NAME  PRED_MIN  ACTUAL_MIN  ERROR  ABS_ERROR  PCT_ERROR
#         Yves Missi     24.77       16.02   8.75       8.75      54.60
#      DeMar DeRozan     31.94       38.48  -6.54       6.54      16.98
#     Maxime Raynaud     32.08       38.58  -6.50       6.50      16.84
#  Mitchell Robinson     20.19       26.16  -5.97       5.97      22.83
# Karl-Anthony Towns     27.77       21.97   5.80       5.80      26.40
#       Kon Knueppel     31.34       36.94  -5.60       5.60      15.17
#   Precious Achiuwa     28.87       33.75  -4.88       4.88      14.47
#       Goga Bitadze     16.02       12.62   3.40       3.40      26.96
#   Tristan da Silva     29.72       32.27  -2.55       2.55       7.90
#         Sion James     16.08       14.46   1.62       1.62      11.20
#   Ryan Kalkbrenner     19.05       17.71   1.34       1.34       7.57
#     Daniss Jenkins     32.35       33.27  -0.92       0.92       2.77
#        Derik Queen     20.03       20.80  -0.77       0.77       3.70
#         Saddiq Bey     31.49       30.75   0.74       0.74       2.41
#     Grant Williams     15.56       14.98   0.58       0.58       3.87
#     Ausar Thompson     29.34       28.97   0.37       0.37       1.29
#    Dejounte Murray     28.98       29.22  -0.24       0.24       0.81
#    Jordan Clarkson     18.26       18.07   0.19       0.19       1.06
#    Zion Williamson     30.89       30.77   0.12       0.12       0.39

# %%
positions = (
    df.sort_values("GAME_DATE")
    .groupby("PLAYER_NAME")["pos"]
    .last()
    .reset_index()
    .rename(columns={"pos": "Position"})
)

analysis_pos = analysis.merge(positions, on="PLAYER_NAME", how="left").dropna(subset=["ACTUAL_MIN"])

pos_order = ["PG", "SG", "SF", "PF", "C"]

pos_summary = (
    analysis_pos
    .groupby("Position")
    .agg(
        N           = ("PLAYER_NAME", "count"),
        MAE         = ("ABS_ERROR",   "mean"),
        RMSE        = ("ERROR",       lambda x: np.sqrt((x**2).mean())),
        MEDIAN_ERR  = ("ABS_ERROR",   "median"),
        AVG_PRED    = ("PRED_MIN",    "mean"),
        AVG_ACTUAL  = ("ACTUAL_MIN",  "mean"),
        OVER_COUNT  = ("ERROR",       lambda x: (x > 0).sum()),
        UNDER_COUNT = ("ERROR",       lambda x: (x < 0).sum()),
    )
    .reindex(pos_order)
    .dropna(how="all")
    .round(2)
)

print(f"\n{'='*65}")
print(f"  Minutes Model Audit — By Position")
print(f"{'='*65}")
print(f"  {'POS':<6} {'N':>4} {'MAE':>6} {'RMSE':>6} {'MED':>6} {'AVG_PRED':>9} {'AVG_ACT':>8} {'OVER':>5} {'UNDER':>6}")
print(f"{'─'*65}")

for pos, row in pos_summary.iterrows():
    print(
        f"  {pos:<6} {int(row['N']):>4} "
        f"{row['MAE']:>6.2f} {row['RMSE']:>6.2f} {row['MEDIAN_ERR']:>6.2f} "
        f"{row['AVG_PRED']:>9.1f} {row['AVG_ACTUAL']:>8.1f} "
        f"{int(row['OVER_COUNT']):>5} {int(row['UNDER_COUNT']):>6}"
    )

# Biggest miss per position
print(f"\n  Worst miss per position:")
print(f"{'─'*65}")

for pos in pos_order:
    subset = analysis_pos[analysis_pos["Position"] == pos].dropna(subset=["ABS_ERROR"])
    if subset.empty:
        continue
    worst = subset.loc[subset["ABS_ERROR"].idxmax()]
    direction = "↑" if worst["ERROR"] > 0 else "↓"
    print(
        f"  {pos:<5} {worst['PLAYER_NAME']:<25} "
        f"pred={worst['PRED_MIN']:.1f}  actual={worst['ACTUAL_MIN']:.1f}  "
        f"{direction}{worst['ABS_ERROR']:.1f} min"
    )
# Out:
# =================================================================
#   Minutes Model Audit — By Position
# =================================================================
#   POS       N    MAE   RMSE    MED  AVG_PRED  AVG_ACT  OVER  UNDER
# ─────────────────────────────────────────────────────────────────
#   PG        2   0.58   0.67   0.58      30.7     31.2     0      2
#   SG        2   0.91   1.15   0.91      17.2     16.3     2      0
#   SF        3   2.24   3.27   0.74      30.7     32.2     2      1
#   PF        3   2.41   3.79   0.58      26.1     28.1     2      1
#   C         8   4.68   5.31   5.34      23.6     23.4     4      4
#
#   Worst miss per position:
# ─────────────────────────────────────────────────────────────────
#   PG    Daniss Jenkins            pred=32.3  actual=33.3  ↓0.9 min
#   SG    Sion James                pred=16.1  actual=14.5  ↑1.6 min
#   SF    Kon Knueppel              pred=31.3  actual=36.9  ↓5.6 min
#   PF    DeMar DeRozan             pred=31.9  actual=38.5  ↓6.5 min
#   C     Yves Missi                pred=24.8  actual=16.0  ↑8.7 min

# %%
# ── 10. Situational Error Breakdown (B2B, Home, Rest Days) ────────────────

# Pull situational columns from df for target_date
situational_cols = ["PLAYER_NAME", "IS_B2B", "IS_HOME", "DAYS_REST"]
situational = df[df["GAME_DATE"] == target_date][situational_cols].copy()

analysis_sit = analysis.merge(situational, on="PLAYER_NAME", how="left").dropna(subset=["ACTUAL_MIN"])

def situation_breakdown(df, group_col, label):
    summary = (
        df.groupby(group_col)
        .agg(
            N           = ("PLAYER_NAME", "count"),
            MAE         = ("ABS_ERROR",   "mean"),
            RMSE        = ("ERROR",       lambda x: np.sqrt((x**2).mean())),
            AVG_ERROR   = ("ERROR",       "mean"),   # signed — catches directional bias
            AVG_PRED    = ("PRED_MIN",    "mean"),
            AVG_ACTUAL  = ("ACTUAL_MIN",  "mean"),
            OVER_COUNT  = ("ERROR",       lambda x: (x > 0).sum()),
            UNDER_COUNT = ("ERROR",       lambda x: (x < 0).sum()),
        )
        .round(2)
    )

    print(f"\n{'='*70}")
    print(f"  {label}")
    print(f"{'='*70}")
    print(f"  {'GROUP':<12} {'N':>4} {'MAE':>6} {'RMSE':>6} {'AVG_ERR':>8} {'AVG_PRED':>9} {'AVG_ACT':>8} {'OVER':>5} {'UNDER':>6}")
    print(f"{'─'*70}")

    for group, row in summary.iterrows():
        bias = "↑ over" if row["AVG_ERROR"] > 0 else "↓ under"
        print(
            f"  {str(group):<12} {int(row['N']):>4} "
            f"{row['MAE']:>6.2f} {row['RMSE']:>6.2f} "
            f"{row['AVG_ERROR']:>+8.2f} "
            f"{row['AVG_PRED']:>9.1f} {row['AVG_ACTUAL']:>8.1f} "
            f"{int(row['OVER_COUNT']):>5} {int(row['UNDER_COUNT']):>6}  {bias}"
        )

# ── B2B ───────────────────────────────────────────────────────────────────
situation_breakdown(analysis_sit, "IS_B2B", "Back-to-Back (IS_B2B)")

# ── Home / Away ───────────────────────────────────────────────────────────
situation_breakdown(analysis_sit, "IS_HOME", "Home vs Away (IS_HOME)")

# ── Rest Days ─────────────────────────────────────────────────────────────
# Cap rest days at 4+ to avoid tiny sample sizes for long rest outliers
analysis_sit["DAYS_REST_CAPPED"] = analysis_sit["DAYS_REST"].clip(upper=4).map(
    lambda x: f"{int(x)}+" if x == 4 else str(int(x))
)
situation_breakdown(analysis_sit, "DAYS_REST", "Rest Days (DAYS_REST)")
# Out:
# ======================================================================
#   Back-to-Back (IS_B2B)
# ======================================================================
#   GROUP           N    MAE   RMSE  AVG_ERR  AVG_PRED  AVG_ACT  OVER  UNDER
# ──────────────────────────────────────────────────────────────────────
#   0.0            17   3.27   4.27    -0.62      24.9     25.5     9      8  ↓ under
#   1.0             2   0.65   0.70    -0.27      30.9     31.1     1      1  ↓ under
#
# ======================================================================
#   Home vs Away (IS_HOME)
# ======================================================================
#   GROUP           N    MAE   RMSE  AVG_ERR  AVG_PRED  AVG_ACT  OVER  UNDER
# ──────────────────────────────────────────────────────────────────────
#   0.0            11   3.68   4.82    -0.85      26.8     27.7     5      6  ↓ under
#   1.0             8   2.05   2.63    -0.22      23.7     23.9     5      3  ↓ under
#
# ======================================================================
#   Rest Days (DAYS_REST)
# ======================================================================
#   GROUP           N    MAE   RMSE  AVG_ERR  AVG_PRED  AVG_ACT  OVER  UNDER
# ──────────────────────────────────────────────────────────────────────
#   1.0             2   0.65   0.70    -0.27      30.9     31.1     1      1  ↓ under
#   2.0            16   3.17   4.23    -0.35      24.6     25.0     9      7  ↓ under
#   4.0             1   4.88   4.88    -4.88      28.9     33.8     0      1  ↓ under

# %%
# ── 11. Prediction Ceiling Diagnosis ──────────────────────────────────────
import matplotlib.pyplot as plt

valid = analysis_sit.dropna(subset=["PRED_MIN", "ACTUAL_MIN"])

# ── A. Distribution of predictions vs actuals ─────────────────────────────
print("Prediction distribution:")
print(valid["PRED_MIN"].describe().round(2))
print("\nActual distribution:")
print(valid["ACTUAL_MIN"].describe().round(2))

# Key ceiling check
print(f"\nPlayers predicted > 32 min : {(valid['PRED_MIN'] > 32).sum()}")
print(f"Players actually  > 32 min : {(valid['ACTUAL_MIN'] > 32).sum()}")
print(f"Highest prediction         : {valid['PRED_MIN'].max():.1f}")
print(f"Highest actual             : {valid['ACTUAL_MIN'].max():.1f}")

# ── B. Binned error by actual minutes played ───────────────────────────────
# This shows exactly where the model breaks down
bins = [0, 15, 20, 25, 28, 30, 32, 35, 38, 50]
labels = ["0-15", "15-20", "20-25", "25-28", "28-30", "30-32", "32-35", "35-38", "38+"]

valid["ACTUAL_BIN"] = pd.cut(valid["ACTUAL_MIN"], bins=bins, labels=labels, right=False)

bin_summary = (
    valid.groupby("ACTUAL_BIN", observed=True)
    .agg(
        N          = ("PLAYER_NAME", "count"),
        AVG_PRED   = ("PRED_MIN",   "mean"),
        AVG_ACTUAL = ("ACTUAL_MIN", "mean"),
        AVG_ERROR  = ("ERROR",      "mean"),   # signed
        MAE        = ("ABS_ERROR",  "mean"),
    )
    .round(2)
)

print(f"\n{'='*65}")
print(f"  Error by Actual Minutes Bin (where is the model wrong?)")
print(f"{'='*65}")
print(f"  {'BIN':<10} {'N':>4} {'AVG_PRED':>9} {'AVG_ACT':>8} {'AVG_ERR':>8} {'MAE':>6}")
print(f"{'─'*65}")
for bin_label, row in bin_summary.iterrows():
    flag = "  ⚠ CEILING" if bin_label in ["32-35", "35-38", "38+"] else ""
    print(
        f"  {str(bin_label):<10} {int(row['N']):>4} "
        f"{row['AVG_PRED']:>9.1f} {row['AVG_ACTUAL']:>8.1f} "
        f"{row['AVG_ERROR']:>+8.2f} {row['MAE']:>6.2f}{flag}"
    )

# ── C. Check training data — does the ceiling exist there too? ─────────────
print(f"\n{'='*55}")
print(f"  Training data (hist) MIN distribution:")
print(f"{'='*55}")
print(hist["MIN"].describe().round(2))
print(f"\nRows with MIN > 32 in training: {(hist['MIN'] > 32).sum()} ({(hist['MIN'] > 32).mean()*100:.1f}%)")
print(f"Rows with MIN > 36 in training: {(hist['MIN'] > 36).sum()} ({(hist['MIN'] > 36).mean()*100:.1f}%)")
# Out:
# Prediction distribution:
# count    19.00
# mean     25.51
# std       6.33
# min      15.56
# 25%      19.54
# 50%      28.87
# 75%      31.11
# max      32.35
# Name: PRED_MIN, dtype: float64
#
# Actual distribution:
# count    19.00
# mean     26.09
# std       8.69
# min      12.62
# 25%      17.89
# 50%      28.97
# 75%      32.77
# max      38.58
# Name: ACTUAL_MIN, dtype: float64
#
# Players predicted > 32 min : 2
# Players actually  > 32 min : 6
# Highest prediction         : 32.3
# Highest actual             : 38.6
#
# =================================================================
#   Error by Actual Minutes Bin (where is the model wrong?)
# =================================================================
#   BIN           N  AVG_PRED  AVG_ACT  AVG_ERR    MAE
# ─────────────────────────────────────────────────────────────────
#   0-15          3      15.9     14.0    +1.87   1.87
#   15-20         3      20.7     17.3    +3.43   3.43
#   20-25         2      23.9     21.4    +2.52   3.28
#   25-28         1      20.2     26.2    -5.97   5.97
#   28-30         2      29.2     29.1    +0.07   0.31
#   30-32         2      31.2     30.8    +0.43   0.43
#   32-35         3      30.3     33.1    -2.78   2.78  ⚠ CEILING
#   35-38         1      31.3     36.9    -5.60   5.60  ⚠ CEILING
#   38+           2      32.0     38.5    -6.52   6.52  ⚠ CEILING
#
# =======================================================
#   Training data (hist) MIN distribution:
# =======================================================
# count    40614.00
# mean        25.27
# std          8.93
# min          0.00
# 25%         19.15
# 50%         26.00
# 75%         32.18
# max         53.17
# Name: MIN, dtype: float64
#
# Rows with MIN > 32 in training: 10423 (25.7%)
# Rows with MIN > 36 in training: 4444 (10.9%)
